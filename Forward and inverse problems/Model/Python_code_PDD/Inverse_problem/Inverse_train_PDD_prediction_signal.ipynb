# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import pywt
import torch.optim as optim
import glob
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

Main_path = 'D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'
Data_path = f'{Main_path}Data\\'
Save_path = f'{Main_path}Model\\Python_code_PDD\\Inverse_problem\\'
# Out:
# Using device: cuda:0

# %%
M = 9900
A = 1
data = []
labels = []
skipped_files = []  # 记录跳过的文件

# 拿到数据路径，方便后续读取
dir_path = f'{Data_path}Prediction_signal_PDD'
dataPaths = sorted(glob.glob(os.path.join(dir_path, '**', '*.csv'), recursive=True))
random.seed(42)
random.shuffle(dataPaths)

# 遍历读取数据
for dataPath in dataPaths:
    # 读取数据（先读取，后验证）
    data_1 = pd.read_csv(dataPath)
    
    # 检查第一列的每一行，找到第一个大于0的值的位置N
    N = 0
    for i in range(len(data_1)):
        if data_1.iloc[i, 1] != 0:
            N = i
            break
    
    # 【关键修复】先验证数据长度，不够就跳过整个文件
    if N >= len(data_1) - M + 1:
        filename = os.path.basename(dataPath)
        print(f"警告：跳过 {filename} - 数据不足(可用{len(data_1)-N}点，需要{M}点)")
        skipped_files.append(filename)
        continue  # 跳过这个文件，data和labels都不添加
    
    # 只有数据足够时，才提取数据和标签
    data.append(data_1.iloc[N:N+M, 1].values)
    
    # 提取标签（移到验证之后）
    filename = os.path.basename(dataPath)
    parts = filename.split('_')
    label1 = float(parts[2])
    label2 = float(parts[3])
    labels.append([label1, label2])

print(f"\n处理完成：成功{len(data)}个，跳过{len(skipped_files)}个")

# 转换为numpy数组
all_datas = np.array(data, dtype="float")
all_labels = np.array(labels)

# 划分数据集（现在不会报错了）
train_datas, temp_datas, train_labels, temp_labels = train_test_split(
    all_datas, all_labels, test_size=0.3, random_state=42
)

validation_datas, test_datas, validation_labels, test_labels = train_test_split(
    temp_datas, temp_labels, test_size=2/3, random_state=42
)

print("训练集数据形状:", train_datas.shape)
print("验证集数据形状:", validation_datas.shape)
print("测试集数据形状:", test_datas.shape)
# Out:
# 警告：跳过 70_240_14.61_0.46_120_18.csv - 数据不足(可用9899点，需要9900点)
#
# 处理完成：成功863个，跳过1个
# 训练集数据形状: (604, 9900)
# 验证集数据形状: (86, 9900)
# 测试集数据形状: (173, 9900)

# %%
train_datas = train_datas.reshape(-1,train_datas.shape[1],1)
validation_datas = validation_datas.reshape(-1,validation_datas.shape[1],1)

print(f'train_datas.shape:{train_datas.shape}')
print(f'validation_datas.shape:{validation_datas.shape}')
# Out:
# train_datas.shape:(604, 9900, 1)
# validation_datas.shape:(86, 9900, 1)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(train_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}train_signal.jpg', dpi=600, bbox_inches='tight')

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(validation_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}validation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
BATCH_SIZE = 32
input_size = M+39
hidden_size = 64
num_layers = 2
output_size = 2
learning_rate = 1e-3
EPOCH = 1000

# %%
# 准备数据
#torch.from_numpy将 NumPy 数组转换为 PyTorch 张量
#TensorDataset用于将张量数据和标签组合成一个数据集
#DataLoader用于从数据集中加载批次数据，并进行训练或测试

train_dataset = TensorDataset(torch.from_numpy(train_datas),torch.from_numpy(train_labels))
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset = TensorDataset(torch.from_numpy(validation_datas),torch.from_numpy(validation_labels))
validation_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ConvAutoencoderPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers,dropout_rate):
        super().__init__()

        # ---------- 卷积编码器 ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(input_size, hidden_size*4, 5, stride=2, padding=2),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.Conv1d(hidden_size*4, hidden_size*2, 3, stride=2, padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.Conv1d(hidden_size*2, hidden_size, 3, stride=1, padding=1),
            nn.BatchNorm1d(hidden_size), nn.ReLU(), nn.Dropout(dropout_rate),
        )

        # ---------- 卷积解码器 ----------
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(hidden_size, hidden_size*2, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.ConvTranspose1d(hidden_size*2, hidden_size*4, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.ConvTranspose1d(hidden_size*4, input_size, 5, stride=1, padding=2),
        )

        # ---------- 2 层双向 LSTM ----------
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            bidirectional=True,
                            dropout=dropout_rate if 2 > 1 else 0,
                            batch_first=False)

        # ---------- 回归头 ----------
        self.regressor = nn.Linear(2 * hidden_size, output_size)   # output_size=2: [force, HI]

    # ------------- 前向 -------------
    def forward(self, x):
        # 小波分解（同你原来写法）
        coeffs = pywt.wavedec(x.cpu().numpy(), 'db4', level=6)
        x3 = torch.cat([torch.from_numpy(c).to(x.device) for c in coeffs], dim=-1)
        x6 = x3.permute(0, 2, 1)                      # [B, C, L]  C=input_size

        # 卷积自编码
        encoded = self.encoder(x6)
        decoded = self.decoder(encoded)               # [B, C, L]

        # 给 LSTM：把 L 放到第一维，通道当特征
        lstm_in = decoded.permute(2, 0, 1)            # [L, B, C]

        # 双向 LSTM 全部时间步输出
        lstm_out, _ = self.lstm(lstm_in)              # [L, B, 2*hidden_size]

        # 取最后一个时间步
        last_step = lstm_out[-1]                      # [B, 2*hidden_size]

        # 回归
        out = self.regressor(last_step)               # [B, 2]
        return out

# %%
#模型实例化
model = ConvAutoencoderPredictor(input_size, hidden_size, output_size, num_layers,dropout_rate = 0)
model.to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
#两个空列表用于存储训练和验证中的损失值
train_loss_force_epoch = []
train_loss_HI_epoch = []

#两个空列表用于存储训练和验证中的损失值
validation_loss_force_epoch = []
validation_loss_HI_epoch = []

# %%
def train_and_validate(model, train_loader, validation_loader, optimizer, loss, device, EPOCH, A, patience=500):
    """
    训练和验证模型的函数

    参数:
    model: 要训练的模型
    train_loader: 训练数据加载器
    validation_loader: 验证数据加载器
    optimizer: 优化器
    loss: 损失函数
    device: 运行设备（如 'cuda' 或 'cpu')
    EPOCH: 训练的总轮数
    A: HI 损失的权重系数
    patience: 早停的耐心值，即在多少个epoch内验证损失没有改善时停止训练
    """
    # 添加学习率调度器 - 每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用总验证损失作为监控指标
    best_val_total_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    # 记录各项损失
    train_loss_force_epoch = []
    train_loss_HI_epoch = []
    validation_loss_force_epoch = []
    validation_loss_HI_epoch = []
    
    # 记录各个指标的列表
    train_force_losses = []
    train_HI_losses = []
    val_force_losses = []
    val_HI_losses = []
    
    for epoch in range(EPOCH):
        # 训练步骤开始
        model.train()
        train_force_epoch = 0.0
        train_HI_epoch = 0.0
        train_force_batch = 0.0
        train_HI_batch = 0.0
        
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()

            x1 = x.type(torch.FloatTensor)
            x2 = x1.permute(0, 2, 1)

            force1 = y[:, 0].type(torch.FloatTensor)
            HI1 = y[:, 1].type(torch.FloatTensor)

            x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

            force_hat = model(x3)[:, 0]
            HI_hat = model(x3)[:, 1]

            train_loss_force = loss(force_hat.flatten(), force2.flatten())
            train_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

            train_loss_force.backward()
            train_loss_HI.backward()

            optimizer.step()

            train_force_epoch += train_loss_force.item() * x3.size(0)
            train_HI_epoch += train_loss_HI.item() * x3.size(0)
            train_force_batch += train_loss_force.item()
            train_HI_batch += train_loss_HI.item()

        # 更新学习率
        scheduler.step()
        
        # 计算平均训练损失
        train_mean_force = train_force_epoch / len(train_loader.dataset)
        train_loss_force_epoch.append(train_mean_force)
        train_force_losses.append(train_force_batch / len(train_loader))

        train_mean_HI = train_HI_epoch / len(train_loader.dataset)
        train_loss_HI_epoch.append(train_mean_HI)
        train_HI_losses.append(train_HI_batch / len(train_loader))

        # 验证步骤开始
        model.eval()
        validation_force_epoch = 0.0
        validation_HI_epoch = 0.0
        val_force_batch = 0.0
        val_HI_batch = 0.0

        with torch.no_grad():
            for i, (x, y) in enumerate(validation_loader):
                x1 = x.type(torch.FloatTensor)
                x2 = x1.permute(0, 2, 1)

                force1 = y[:, 0].type(torch.FloatTensor)
                HI1 = y[:, 1].type(torch.FloatTensor)

                x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

                force_hat = model(x3)[:, 0]
                HI_hat = model(x3)[:, 1]

                validation_loss_force = loss(force_hat.flatten(), force2.flatten())
                validation_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

                validation_force_epoch += validation_loss_force.item() * x3.size(0)
                validation_HI_epoch += validation_loss_HI.item() * x3.size(0)
                val_force_batch += validation_loss_force.item()
                val_HI_batch += validation_loss_HI.item()

        # 计算平均验证损失
        validation_mean_force = validation_force_epoch / len(validation_loader.dataset)
        validation_loss_force_epoch.append(validation_mean_force)
        val_force_losses.append(val_force_batch / len(validation_loader))

        validation_mean_HI = validation_HI_epoch / len(validation_loader.dataset)
        validation_loss_HI_epoch.append(validation_mean_HI)
        val_HI_losses.append(val_HI_batch / len(validation_loader))
        
        # 计算总验证损失用于早停监控
        total_val_loss = validation_mean_force

        # 早停检查 - 使用总验证损失作为监控指标
        if total_val_loss < best_val_total_loss:
            best_val_total_loss = total_val_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            # 仅在验证损失改善时打印信息
            if epoch % (EPOCH//100) == 0:
                print(f"Epoch {epoch+1}: 验证总损失改善 ({total_val_loss:.4f} -> {best_val_total_loss:.4f})，保存最佳模型")
        else:
            patience_counter += 1
            
            # 检查是否触发早停
            if patience_counter >= patience:
                print(f"\n早停触发！连续 {patience} 个epoch验证总损失未改善")
                print(f"最佳验证总损失: {best_val_total_loss:.4f} (epoch {epoch+1-patience})")
                break

        # 每10个epoch打印一次训练信息
        if epoch % (EPOCH//100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"\nEpoch {epoch+1}/{EPOCH}, LR: {current_lr:.6f}")
            print(f"Train - Force Loss: {train_mean_force:.4f}, HI Loss: {train_mean_HI:.4f}")
            print(f"Valid - Force Loss: {validation_mean_force:.4f}, HI Loss: {validation_mean_HI:.4f}")
            print(f"Valid Total Loss: {total_val_loss:.4f}, Best: {best_val_total_loss:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控总验证损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成，加载最佳模型（验证总损失: {best_val_total_loss:.4f})")
    else:
        print("\n训练完成，但未找到最佳模型")
    
    return train_force_losses, train_HI_losses, val_force_losses, val_HI_losses

# %%
# 假设你已经定义了模型、数据加载器、优化器、损失函数、设备等
train_loss_force, train_loss_HI, validation_loss_force, validation_loss_HI = train_and_validate(
    model=model,
    train_loader = train_loader,
    validation_loader = validation_loader,
    optimizer = optimizer,
    loss = loss,
    device = device,
    EPOCH = EPOCH,
    A = A,
    patience = 500  # 早停耐心值设为500个epoch
)
# Out:
# Epoch 1: 验证总损失改善 (57.8460 -> 57.8460)，保存最佳模型
#
# Epoch 1/1000, LR: 0.001000
# Train - Force Loss: 98.4173, HI Loss: 0.1645
# Valid - Force Loss: 57.8460, HI Loss: 0.0769
# Valid Total Loss: 57.8460, Best: 57.8460
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 11: 验证总损失改善 (3.9046 -> 3.9046)，保存最佳模型
#
# Epoch 11/1000, LR: 0.001000
# Train - Force Loss: 4.7100, HI Loss: 0.0083
# Valid - Force Loss: 3.9046, HI Loss: 0.0067
# Valid Total Loss: 3.9046, Best: 3.9046
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 21: 验证总损失改善 (1.6811 -> 1.6811)，保存最佳模型
#
# Epoch 21/1000, LR: 0.001000
# Train - Force Loss: 2.8029, HI Loss: 0.0039
# Valid - Force Loss: 1.6811, HI Loss: 0.0022
# Valid Total Loss: 1.6811, Best: 1.6811
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 31/1000, LR: 0.001000
# Train - Force Loss: 2.3002, HI Loss: 0.0039
# Valid - Force Loss: 1.3485, HI Loss: 0.0020
# Valid Total Loss: 1.3485, Best: 1.1930
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 41/1000, LR: 0.001000
# Train - Force Loss: 2.6568, HI Loss: 0.0035
# Valid - Force Loss: 1.2129, HI Loss: 0.0025
# Valid Total Loss: 1.2129, Best: 1.0021
# 早停计数器: 9/500 (监控总验证损失)
#
# Epoch 51/1000, LR: 0.001000
# Train - Force Loss: 2.1383, HI Loss: 0.0028
# Valid - Force Loss: 1.6615, HI Loss: 0.0016
# Valid Total Loss: 1.6615, Best: 0.9554
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 61/1000, LR: 0.001000
# Train - Force Loss: 2.4783, HI Loss: 0.0029
# Valid - Force Loss: 1.9707, HI Loss: 0.0013
# Valid Total Loss: 1.9707, Best: 0.9554
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 71/1000, LR: 0.001000
# Train - Force Loss: 2.6200, HI Loss: 0.0027
# Valid - Force Loss: 8.2299, HI Loss: 0.0086
# Valid Total Loss: 8.2299, Best: 0.9554
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 81/1000, LR: 0.001000
# Train - Force Loss: 2.3834, HI Loss: 0.0030
# Valid - Force Loss: 1.3149, HI Loss: 0.0016
# Valid Total Loss: 1.3149, Best: 0.9554
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 91/1000, LR: 0.001000
# Train - Force Loss: 1.7841, HI Loss: 0.0020
# Valid - Force Loss: 3.3252, HI Loss: 0.0031
# Valid Total Loss: 3.3252, Best: 0.9554
# 早停计数器: 46/500 (监控总验证损失)
#
# Epoch 101/1000, LR: 0.000800
# Train - Force Loss: 1.9944, HI Loss: 0.0023
# Valid - Force Loss: 1.3769, HI Loss: 0.0013
# Valid Total Loss: 1.3769, Best: 0.9554
# 早停计数器: 56/500 (监控总验证损失)
#
# Epoch 111/1000, LR: 0.000800
# Train - Force Loss: 2.6455, HI Loss: 0.0030
# Valid - Force Loss: 1.8165, HI Loss: 0.0035
# Valid Total Loss: 1.8165, Best: 0.9554
# 早停计数器: 66/500 (监控总验证损失)
#
# Epoch 121/1000, LR: 0.000800
# Train - Force Loss: 2.1506, HI Loss: 0.0033
# Valid - Force Loss: 1.2472, HI Loss: 0.0047
# Valid Total Loss: 1.2472, Best: 0.9554
# 早停计数器: 76/500 (监控总验证损失)
#
# Epoch 131/1000, LR: 0.000800
# Train - Force Loss: 2.0338, HI Loss: 0.0035
# Valid - Force Loss: 2.7873, HI Loss: 0.0036
# Valid Total Loss: 2.7873, Best: 0.9554
# 早停计数器: 86/500 (监控总验证损失)
#
# Epoch 141/1000, LR: 0.000800
# Train - Force Loss: 2.5461, HI Loss: 0.0047
# Valid - Force Loss: 1.2565, HI Loss: 0.0019
# Valid Total Loss: 1.2565, Best: 0.9554
# 早停计数器: 96/500 (监控总验证损失)
#
# Epoch 151/1000, LR: 0.000800
# Train - Force Loss: 1.8729, HI Loss: 0.0022
# Valid - Force Loss: 1.2645, HI Loss: 0.0020
# Valid Total Loss: 1.2645, Best: 0.9554
# 早停计数器: 106/500 (监控总验证损失)
#
# Epoch 161/1000, LR: 0.000800
# Train - Force Loss: 1.5320, HI Loss: 0.0019
# Valid - Force Loss: 1.0918, HI Loss: 0.0012
# Valid Total Loss: 1.0918, Best: 0.9554
# 早停计数器: 116/500 (监控总验证损失)
#
# Epoch 171/1000, LR: 0.000800
# Train - Force Loss: 1.5880, HI Loss: 0.0024
# Valid - Force Loss: 0.9714, HI Loss: 0.0011
# Valid Total Loss: 0.9714, Best: 0.8395
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 181/1000, LR: 0.000800
# Train - Force Loss: 1.7400, HI Loss: 0.0024
# Valid - Force Loss: 1.1985, HI Loss: 0.0013
# Valid Total Loss: 1.1985, Best: 0.7962
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 191/1000, LR: 0.000800
# Train - Force Loss: 1.7312, HI Loss: 0.0020
# Valid - Force Loss: 1.3089, HI Loss: 0.0012
# Valid Total Loss: 1.3089, Best: 0.7962
# 早停计数器: 17/500 (监控总验证损失)
#
# Epoch 201/1000, LR: 0.000640
# Train - Force Loss: 1.8934, HI Loss: 0.0019
# Valid - Force Loss: 1.3159, HI Loss: 0.0020
# Valid Total Loss: 1.3159, Best: 0.7073
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 211/1000, LR: 0.000640
# Train - Force Loss: 2.0057, HI Loss: 0.0031
# Valid - Force Loss: 0.8780, HI Loss: 0.0013
# Valid Total Loss: 0.8780, Best: 0.7073
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 221/1000, LR: 0.000640
# Train - Force Loss: 1.8289, HI Loss: 0.0019
# Valid - Force Loss: 0.8723, HI Loss: 0.0013
# Valid Total Loss: 0.8723, Best: 0.7073
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 231/1000, LR: 0.000640
# Train - Force Loss: 1.1763, HI Loss: 0.0012
# Valid - Force Loss: 2.7996, HI Loss: 0.0020
# Valid Total Loss: 2.7996, Best: 0.7073
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 241/1000, LR: 0.000640
# Train - Force Loss: 1.5159, HI Loss: 0.0020
# Valid - Force Loss: 0.9344, HI Loss: 0.0011
# Valid Total Loss: 0.9344, Best: 0.7073
# 早停计数器: 46/500 (监控总验证损失)
#
# Epoch 251/1000, LR: 0.000640
# Train - Force Loss: 1.3706, HI Loss: 0.0016
# Valid - Force Loss: 0.8808, HI Loss: 0.0009
# Valid Total Loss: 0.8808, Best: 0.7038
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 261/1000, LR: 0.000640
# Train - Force Loss: 1.5469, HI Loss: 0.0017
# Valid - Force Loss: 1.0116, HI Loss: 0.0016
# Valid Total Loss: 1.0116, Best: 0.7038
# 早停计数器: 15/500 (监控总验证损失)
#
# Epoch 271/1000, LR: 0.000640
# Train - Force Loss: 1.7479, HI Loss: 0.0034
# Valid - Force Loss: 1.1725, HI Loss: 0.0009
# Valid Total Loss: 1.1725, Best: 0.7038
# 早停计数器: 25/500 (监控总验证损失)
#
# Epoch 281/1000, LR: 0.000640
# Train - Force Loss: 1.6440, HI Loss: 0.0017
# Valid - Force Loss: 0.8479, HI Loss: 0.0008
# Valid Total Loss: 0.8479, Best: 0.7038
# 早停计数器: 35/500 (监控总验证损失)
#
# Epoch 291/1000, LR: 0.000640
# Train - Force Loss: 1.3446, HI Loss: 0.0017
# Valid - Force Loss: 1.0132, HI Loss: 0.0009
# Valid Total Loss: 1.0132, Best: 0.7038
# 早停计数器: 45/500 (监控总验证损失)
#
# Epoch 301/1000, LR: 0.000512
# Train - Force Loss: 1.5713, HI Loss: 0.0029
# Valid - Force Loss: 0.9410, HI Loss: 0.0017
# Valid Total Loss: 0.9410, Best: 0.6928
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 311/1000, LR: 0.000512
# Train - Force Loss: 1.2017, HI Loss: 0.0013
# Valid - Force Loss: 0.9037, HI Loss: 0.0010
# Valid Total Loss: 0.9037, Best: 0.6273
# 早停计数器: 8/500 (监控总验证损失)
#
# Epoch 321/1000, LR: 0.000512
# Train - Force Loss: 0.9688, HI Loss: 0.0012
# Valid - Force Loss: 0.7946, HI Loss: 0.0007
# Valid Total Loss: 0.7946, Best: 0.6273
# 早停计数器: 18/500 (监控总验证损失)
#
# Epoch 331/1000, LR: 0.000512
# Train - Force Loss: 1.1040, HI Loss: 0.0012
# Valid - Force Loss: 0.8968, HI Loss: 0.0008
# Valid Total Loss: 0.8968, Best: 0.6263
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 341/1000, LR: 0.000512
# Train - Force Loss: 1.3607, HI Loss: 0.0023
# Valid - Force Loss: 0.7774, HI Loss: 0.0011
# Valid Total Loss: 0.7774, Best: 0.6240
# 早停计数器: 8/500 (监控总验证损失)
#
# Epoch 351/1000, LR: 0.000512
# Train - Force Loss: 1.2520, HI Loss: 0.0011
# Valid - Force Loss: 0.9714, HI Loss: 0.0008
# Valid Total Loss: 0.9714, Best: 0.6182
# 早停计数器: 8/500 (监控总验证损失)
#
# Epoch 361/1000, LR: 0.000512
# Train - Force Loss: 1.0985, HI Loss: 0.0013
# Valid - Force Loss: 0.6816, HI Loss: 0.0008
# Valid Total Loss: 0.6816, Best: 0.6182
# 早停计数器: 18/500 (监控总验证损失)
#
# Epoch 371/1000, LR: 0.000512
# Train - Force Loss: 1.0951, HI Loss: 0.0013
# Valid - Force Loss: 0.8886, HI Loss: 0.0007
# Valid Total Loss: 0.8886, Best: 0.5858
# 早停计数器: 4/500 (监控总验证损失)
#
# Epoch 381/1000, LR: 0.000512
# Train - Force Loss: 1.2799, HI Loss: 0.0017
# Valid - Force Loss: 0.6853, HI Loss: 0.0010
# Valid Total Loss: 0.6853, Best: 0.5416
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 391/1000, LR: 0.000512
# Train - Force Loss: 1.1635, HI Loss: 0.0014
# Valid - Force Loss: 0.6830, HI Loss: 0.0007
# Valid Total Loss: 0.6830, Best: 0.5416
# 早停计数器: 17/500 (监控总验证损失)
#
# Epoch 401/1000, LR: 0.000410
# Train - Force Loss: 1.1526, HI Loss: 0.0012
# Valid - Force Loss: 0.6765, HI Loss: 0.0007
# Valid Total Loss: 0.6765, Best: 0.5416
# 早停计数器: 27/500 (监控总验证损失)
#
# Epoch 411/1000, LR: 0.000410
# Train - Force Loss: 1.0309, HI Loss: 0.0015
# Valid - Force Loss: 0.7404, HI Loss: 0.0010
# Valid Total Loss: 0.7404, Best: 0.5416
# 早停计数器: 37/500 (监控总验证损失)
# Epoch 421: 验证总损失改善 (0.5245 -> 0.5245)，保存最佳模型
#
# Epoch 421/1000, LR: 0.000410
# Train - Force Loss: 0.8440, HI Loss: 0.0012
# Valid - Force Loss: 0.5245, HI Loss: 0.0008
# Valid Total Loss: 0.5245, Best: 0.5245
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 431/1000, LR: 0.000410
# Train - Force Loss: 0.7989, HI Loss: 0.0012
# Valid - Force Loss: 0.6055, HI Loss: 0.0007
# Valid Total Loss: 0.6055, Best: 0.5185
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 441/1000, LR: 0.000410
# Train - Force Loss: 0.8595, HI Loss: 0.0010
# Valid - Force Loss: 0.6519, HI Loss: 0.0009
# Valid Total Loss: 0.6519, Best: 0.5185
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 451/1000, LR: 0.000410
# Train - Force Loss: 1.0160, HI Loss: 0.0011
# Valid - Force Loss: 0.7612, HI Loss: 0.0010
# Valid Total Loss: 0.7612, Best: 0.4609
# 早停计数器: 4/500 (监控总验证损失)
#
# Epoch 461/1000, LR: 0.000410
# Train - Force Loss: 1.0928, HI Loss: 0.0014
# Valid - Force Loss: 0.5937, HI Loss: 0.0007
# Valid Total Loss: 0.5937, Best: 0.3866
# 早停计数器: 4/500 (监控总验证损失)
#
# Epoch 471/1000, LR: 0.000410
# Train - Force Loss: 0.9332, HI Loss: 0.0010
# Valid - Force Loss: 0.7215, HI Loss: 0.0015
# Valid Total Loss: 0.7215, Best: 0.3866
# 早停计数器: 14/500 (监控总验证损失)
#
# Epoch 481/1000, LR: 0.000410
# Train - Force Loss: 1.3641, HI Loss: 0.0014
# Valid - Force Loss: 1.4268, HI Loss: 0.0012
# Valid Total Loss: 1.4268, Best: 0.3866
# 早停计数器: 24/500 (监控总验证损失)
#
# Epoch 491/1000, LR: 0.000410
# Train - Force Loss: 1.2223, HI Loss: 0.0012
# Valid - Force Loss: 0.8235, HI Loss: 0.0008
# Valid Total Loss: 0.8235, Best: 0.3866
# 早停计数器: 34/500 (监控总验证损失)
#
# Epoch 501/1000, LR: 0.000328
# Train - Force Loss: 1.0148, HI Loss: 0.0015
# Valid - Force Loss: 0.6407, HI Loss: 0.0011
# Valid Total Loss: 0.6407, Best: 0.3866
# 早停计数器: 44/500 (监控总验证损失)
#
# Epoch 511/1000, LR: 0.000328
# Train - Force Loss: 1.1166, HI Loss: 0.0015
# Valid - Force Loss: 0.8636, HI Loss: 0.0010
# Valid Total Loss: 0.8636, Best: 0.3866
# 早停计数器: 54/500 (监控总验证损失)
#
# Epoch 521/1000, LR: 0.000328
# Train - Force Loss: 1.4759, HI Loss: 0.0016
# Valid - Force Loss: 0.8198, HI Loss: 0.0005
# Valid Total Loss: 0.8198, Best: 0.3866
# 早停计数器: 64/500 (监控总验证损失)
#
# Epoch 531/1000, LR: 0.000328
# Train - Force Loss: 0.8263, HI Loss: 0.0011
# Valid - Force Loss: 0.4945, HI Loss: 0.0005
# Valid Total Loss: 0.4945, Best: 0.3866
# 早停计数器: 74/500 (监控总验证损失)
#
# Epoch 541/1000, LR: 0.000328
# Train - Force Loss: 1.0475, HI Loss: 0.0011
# Valid - Force Loss: 0.6018, HI Loss: 0.0005
# Valid Total Loss: 0.6018, Best: 0.3866
# 早停计数器: 84/500 (监控总验证损失)
#
# Epoch 551/1000, LR: 0.000328
# Train - Force Loss: 1.1489, HI Loss: 0.0014
# Valid - Force Loss: 0.6667, HI Loss: 0.0006
# Valid Total Loss: 0.6667, Best: 0.3866
# 早停计数器: 94/500 (监控总验证损失)
#
# Epoch 561/1000, LR: 0.000328
# Train - Force Loss: 0.9287, HI Loss: 0.0011
# Valid - Force Loss: 0.6004, HI Loss: 0.0006
# Valid Total Loss: 0.6004, Best: 0.3866
# 早停计数器: 104/500 (监控总验证损失)
#
# Epoch 571/1000, LR: 0.000328
# Train - Force Loss: 2.3449, HI Loss: 0.0024
# Valid - Force Loss: 1.1072, HI Loss: 0.0018
# Valid Total Loss: 1.1072, Best: 0.3866
# 早停计数器: 114/500 (监控总验证损失)
#
# Epoch 581/1000, LR: 0.000328
# Train - Force Loss: 0.9119, HI Loss: 0.0012
# Valid - Force Loss: 0.6280, HI Loss: 0.0006
# Valid Total Loss: 0.6280, Best: 0.3866
# 早停计数器: 124/500 (监控总验证损失)
#
# Epoch 591/1000, LR: 0.000328
# Train - Force Loss: 0.8487, HI Loss: 0.0009
# Valid - Force Loss: 0.4942, HI Loss: 0.0007
# Valid Total Loss: 0.4942, Best: 0.3866
# 早停计数器: 134/500 (监控总验证损失)
#
# Epoch 601/1000, LR: 0.000262
# Train - Force Loss: 1.0077, HI Loss: 0.0012
# Valid - Force Loss: 0.6005, HI Loss: 0.0007
# Valid Total Loss: 0.6005, Best: 0.3866
# 早停计数器: 144/500 (监控总验证损失)
#
# Epoch 611/1000, LR: 0.000262
# Train - Force Loss: 0.9966, HI Loss: 0.0011
# Valid - Force Loss: 0.5665, HI Loss: 0.0007
# Valid Total Loss: 0.5665, Best: 0.3866
# 早停计数器: 154/500 (监控总验证损失)
#
# Epoch 621/1000, LR: 0.000262
# Train - Force Loss: 0.9893, HI Loss: 0.0011
# Valid - Force Loss: 1.0418, HI Loss: 0.0008
# Valid Total Loss: 1.0418, Best: 0.3866
# 早停计数器: 164/500 (监控总验证损失)
#
# Epoch 631/1000, LR: 0.000262
# Train - Force Loss: 0.8617, HI Loss: 0.0010
# Valid - Force Loss: 0.6169, HI Loss: 0.0007
# Valid Total Loss: 0.6169, Best: 0.3866
# 早停计数器: 174/500 (监控总验证损失)
#
# Epoch 641/1000, LR: 0.000262
# Train - Force Loss: 0.9205, HI Loss: 0.0012
# Valid - Force Loss: 0.5511, HI Loss: 0.0008
# Valid Total Loss: 0.5511, Best: 0.3866
# 早停计数器: 184/500 (监控总验证损失)
#
# Epoch 651/1000, LR: 0.000262
# Train - Force Loss: 0.8496, HI Loss: 0.0009
# Valid - Force Loss: 0.5787, HI Loss: 0.0008
# Valid Total Loss: 0.5787, Best: 0.3866
# 早停计数器: 194/500 (监控总验证损失)
#
# Epoch 661/1000, LR: 0.000262
# Train - Force Loss: 0.9307, HI Loss: 0.0009
# Valid - Force Loss: 0.6233, HI Loss: 0.0006
# Valid Total Loss: 0.6233, Best: 0.3866
# 早停计数器: 204/500 (监控总验证损失)
#
# Epoch 671/1000, LR: 0.000262
# Train - Force Loss: 0.7316, HI Loss: 0.0008
# Valid - Force Loss: 0.6244, HI Loss: 0.0006
# Valid Total Loss: 0.6244, Best: 0.3866
# 早停计数器: 214/500 (监控总验证损失)
#
# Epoch 681/1000, LR: 0.000262
# Train - Force Loss: 0.8533, HI Loss: 0.0009
# Valid - Force Loss: 0.5588, HI Loss: 0.0006
# Valid Total Loss: 0.5588, Best: 0.3866
# 早停计数器: 224/500 (监控总验证损失)
#
# Epoch 691/1000, LR: 0.000262
# Train - Force Loss: 0.7748, HI Loss: 0.0010
# Valid - Force Loss: 0.4953, HI Loss: 0.0007
# Valid Total Loss: 0.4953, Best: 0.3866
# 早停计数器: 234/500 (监控总验证损失)
#
# Epoch 701/1000, LR: 0.000210
# Train - Force Loss: 0.7858, HI Loss: 0.0008
# Valid - Force Loss: 0.5837, HI Loss: 0.0006
# Valid Total Loss: 0.5837, Best: 0.3866
# 早停计数器: 244/500 (监控总验证损失)
#
# Epoch 711/1000, LR: 0.000210
# Train - Force Loss: 1.0174, HI Loss: 0.0011
# Valid - Force Loss: 0.4679, HI Loss: 0.0004
# Valid Total Loss: 0.4679, Best: 0.3866
# 早停计数器: 254/500 (监控总验证损失)
#
# Epoch 721/1000, LR: 0.000210
# Train - Force Loss: 0.7248, HI Loss: 0.0008
# Valid - Force Loss: 0.4587, HI Loss: 0.0004
# Valid Total Loss: 0.4587, Best: 0.3866
# 早停计数器: 264/500 (监控总验证损失)
#
# Epoch 731/1000, LR: 0.000210
# Train - Force Loss: 0.5990, HI Loss: 0.0006
# Valid - Force Loss: 0.4721, HI Loss: 0.0005
# Valid Total Loss: 0.4721, Best: 0.3272
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 741/1000, LR: 0.000210
# Train - Force Loss: 0.9637, HI Loss: 0.0010
# Valid - Force Loss: 0.5222, HI Loss: 0.0006
# Valid Total Loss: 0.5222, Best: 0.3272
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 751/1000, LR: 0.000210
# Train - Force Loss: 0.8778, HI Loss: 0.0009
# Valid - Force Loss: 0.7280, HI Loss: 0.0006
# Valid Total Loss: 0.7280, Best: 0.3272
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 761/1000, LR: 0.000210
# Train - Force Loss: 0.7164, HI Loss: 0.0009
# Valid - Force Loss: 0.4125, HI Loss: 0.0004
# Valid Total Loss: 0.4125, Best: 0.3270
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 771/1000, LR: 0.000210
# Train - Force Loss: 0.6849, HI Loss: 0.0007
# Valid - Force Loss: 0.4249, HI Loss: 0.0004
# Valid Total Loss: 0.4249, Best: 0.3270
# 早停计数器: 17/500 (监控总验证损失)
#
# Epoch 781/1000, LR: 0.000210
# Train - Force Loss: 0.6659, HI Loss: 0.0007
# Valid - Force Loss: 0.4060, HI Loss: 0.0004
# Valid Total Loss: 0.4060, Best: 0.3270
# 早停计数器: 27/500 (监控总验证损失)
#
# Epoch 791/1000, LR: 0.000210
# Train - Force Loss: 0.6115, HI Loss: 0.0007
# Valid - Force Loss: 0.4376, HI Loss: 0.0003
# Valid Total Loss: 0.4376, Best: 0.3270
# 早停计数器: 37/500 (监控总验证损失)
#
# Epoch 801/1000, LR: 0.000168
# Train - Force Loss: 0.6906, HI Loss: 0.0007
# Valid - Force Loss: 0.5428, HI Loss: 0.0004
# Valid Total Loss: 0.5428, Best: 0.3182
# 早停计数器: 8/500 (监控总验证损失)
#
# Epoch 811/1000, LR: 0.000168
# Train - Force Loss: 0.8244, HI Loss: 0.0008
# Valid - Force Loss: 0.5275, HI Loss: 0.0005
# Valid Total Loss: 0.5275, Best: 0.3182
# 早停计数器: 18/500 (监控总验证损失)
#
# Epoch 821/1000, LR: 0.000168
# Train - Force Loss: 0.6218, HI Loss: 0.0006
# Valid - Force Loss: 0.5311, HI Loss: 0.0004
# Valid Total Loss: 0.5311, Best: 0.3182
# 早停计数器: 28/500 (监控总验证损失)
#
# Epoch 831/1000, LR: 0.000168
# Train - Force Loss: 0.7049, HI Loss: 0.0008
# Valid - Force Loss: 0.3758, HI Loss: 0.0004
# Valid Total Loss: 0.3758, Best: 0.3182
# 早停计数器: 38/500 (监控总验证损失)
#
# Epoch 841/1000, LR: 0.000168
# Train - Force Loss: 0.6031, HI Loss: 0.0007
# Valid - Force Loss: 0.3186, HI Loss: 0.0003
# Valid Total Loss: 0.3186, Best: 0.2987
# 早停计数器: 4/500 (监控总验证损失)
#
# Epoch 851/1000, LR: 0.000168
# Train - Force Loss: 0.5132, HI Loss: 0.0005
# Valid - Force Loss: 0.3828, HI Loss: 0.0004
# Valid Total Loss: 0.3828, Best: 0.2620
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 861/1000, LR: 0.000168
# Train - Force Loss: 0.7094, HI Loss: 0.0007
# Valid - Force Loss: 0.4932, HI Loss: 0.0005
# Valid Total Loss: 0.4932, Best: 0.2620
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 871/1000, LR: 0.000168
# Train - Force Loss: 0.6003, HI Loss: 0.0007
# Valid - Force Loss: 0.6657, HI Loss: 0.0004
# Valid Total Loss: 0.6657, Best: 0.2620
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 881/1000, LR: 0.000168
# Train - Force Loss: 0.6701, HI Loss: 0.0008
# Valid - Force Loss: 0.5644, HI Loss: 0.0005
# Valid Total Loss: 0.5644, Best: 0.2620
# 早停计数器: 31/500 (监控总验证损失)
#
# Epoch 891/1000, LR: 0.000168
# Train - Force Loss: 0.7163, HI Loss: 0.0008
# Valid - Force Loss: 0.3759, HI Loss: 0.0004
# Valid Total Loss: 0.3759, Best: 0.2620
# 早停计数器: 41/500 (监控总验证损失)
#
# Epoch 901/1000, LR: 0.000134
# Train - Force Loss: 0.6252, HI Loss: 0.0008
# Valid - Force Loss: 0.3135, HI Loss: 0.0004
# Valid Total Loss: 0.3135, Best: 0.2562
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 911/1000, LR: 0.000134
# Train - Force Loss: 0.5828, HI Loss: 0.0006
# Valid - Force Loss: 0.3328, HI Loss: 0.0004
# Valid Total Loss: 0.3328, Best: 0.2562
# 早停计数器: 12/500 (监控总验证损失)
#
# Epoch 921/1000, LR: 0.000134
# Train - Force Loss: 0.5552, HI Loss: 0.0007
# Valid - Force Loss: 0.4641, HI Loss: 0.0005
# Valid Total Loss: 0.4641, Best: 0.2562
# 早停计数器: 22/500 (监控总验证损失)
#
# Epoch 931/1000, LR: 0.000134
# Train - Force Loss: 0.5073, HI Loss: 0.0006
# Valid - Force Loss: 0.3467, HI Loss: 0.0004
# Valid Total Loss: 0.3467, Best: 0.2562
# 早停计数器: 32/500 (监控总验证损失)
#
# Epoch 941/1000, LR: 0.000134
# Train - Force Loss: 0.5713, HI Loss: 0.0006
# Valid - Force Loss: 0.2807, HI Loss: 0.0003
# Valid Total Loss: 0.2807, Best: 0.2562
# 早停计数器: 42/500 (监控总验证损失)
#
# Epoch 951/1000, LR: 0.000134
# Train - Force Loss: 0.4853, HI Loss: 0.0005
# Valid - Force Loss: 0.4795, HI Loss: 0.0004
# Valid Total Loss: 0.4795, Best: 0.2562
# 早停计数器: 52/500 (监控总验证损失)
#
# Epoch 961/1000, LR: 0.000134
# Train - Force Loss: 0.4590, HI Loss: 0.0005
# Valid - Force Loss: 0.3031, HI Loss: 0.0003
# Valid Total Loss: 0.3031, Best: 0.2562
# 早停计数器: 62/500 (监控总验证损失)
#
# Epoch 971/1000, LR: 0.000134
# Train - Force Loss: 0.4345, HI Loss: 0.0005
# Valid - Force Loss: 0.3095, HI Loss: 0.0003
# Valid Total Loss: 0.3095, Best: 0.1838
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 981/1000, LR: 0.000134
# Train - Force Loss: 0.4816, HI Loss: 0.0005
# Valid - Force Loss: 0.2817, HI Loss: 0.0003
# Valid Total Loss: 0.2817, Best: 0.1838
# 早停计数器: 15/500 (监控总验证损失)
#
# Epoch 991/1000, LR: 0.000134
# Train - Force Loss: 0.6165, HI Loss: 0.0007
# Valid - Force Loss: 0.3505, HI Loss: 0.0004
# Valid Total Loss: 0.3505, Best: 0.1838
# 早停计数器: 25/500 (监控总验证损失)
#
# 训练完成，加载最佳模型（验证总损失: 0.1838)

# %%
torch.save(model, f'{Save_path}Inverse_Model_PDD_Prediction_signal.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
plt.style.use('default')
plt.figure(figsize=(12, 8)) # 创建Figure对象，并指定尺寸
plt.rcParams['font.family'] = ['Times New Roman']

# 设置x轴刻度
epoch = np.arange(0, len(train_loss_force), len(train_loss_force) // 10)
plt.xticks(epoch)

# 创建第一个y轴
ax1 = plt.gca()
ax1.plot(train_loss_force, 'r-', linewidth=2.5)
ax1.plot(train_loss_force, marker='o', markersize=5, color='red', linestyle='None', label='Training loss for PF')
ax1.plot(validation_loss_force, 'r-', linewidth=2.5)
ax1.plot(validation_loss_force, marker='*', markersize=5, color='red', linestyle='None', label='Validation loss for PF')

ax1.set_xlabel('Epoch', fontdict={'weight': 'normal', 'size': 20})
ax1.set_ylabel('Loss for PF', fontdict={'weight': 'normal', 'size': 20}, color='red')

ax1.tick_params(axis='y', labelcolor='red')
ax1.tick_params(axis='both', which='major',labelcolor='black', labelsize=15)

# 添加图例
ax1.legend(loc='upper left', fontsize=20)


max_val_force = max(
    max(train_loss_force),
    max(validation_loss_force)
)

ax1.set_ylim(0, max_val_force)

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None', label='Training loss for HI')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None', label='Validation loss for HI')

ax2.set_ylabel('Loss for HI', fontdict={'weight': 'normal', 'size': 20}, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major',labelcolor='blue', labelsize=15)

max_val_HI = max(
    max(train_loss_HI),
    max(validation_loss_HI)
)

ax2.set_ylim(0.0, max_val_HI)
ax2.legend(loc='upper right', fontsize=20)

# 创建放大图的子图（inset）
x1 = int(len(train_loss_force)*0.7)
x2 = int(len(train_loss_force))

ax_inset = plt.axes([0.4, 0.25, 0.4, 0.4])  # [left, bottom, width, height]
ax_inset.plot(train_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(train_loss_force, marker='o', markersize=8, color='red', linestyle='None')
ax_inset.plot(validation_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(validation_loss_force, marker='*', markersize=8, color='red', linestyle='None')

max_val_force = max(
    max(train_loss_force[x1:x2]),
    max(validation_loss_force[x1:x2])
)

ax_inset.set_xlim(x1, x2)
ax_inset.set_ylim(0, max_val_force)
ax_inset.tick_params(axis='both', which='major',  labelcolor='red',labelsize=15)

ax2 = ax_inset.twinx()

ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None')

max_val_HI = max(
    max(train_loss_HI[x1:x2]),
    max(validation_loss_HI[x1:x2])
)

ax2.set_ylim(0.0, max_val_HI)

ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major', labelsize=15)

# 保存图像
plt.savefig(f'{Save_path}Inverse_Loss_MSE_prediciton_signal.jpg', dpi=600, bbox_inches='tight')
plt.show()
