# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import pywt
import torch.optim as optim
import glob
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
import torch.nn.functional as F

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

Main_path = 'D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'
Data_path = f'{Main_path}Data\\'
save_path = f'{Main_path}Model\\Original_Data_Inverse_problem\\'
# Out:
# Using device: cuda:0

# %%
M = 9900
A = 1
data = []
labels = []

# 拿到数据路径，方便后续读取
dir_path = f'{Data_path}Experiment_signal'
# 获取目录及其子目录下所有CSV文件的路径
dataPaths = sorted(glob.glob(os.path.join(dir_path, '**', '*.csv'), recursive=True))
random.seed(42)
random.shuffle(dataPaths)

# 遍历读取数据
for dataPath in dataPaths:
    # 从文件名中提取x, y, z, j, k标签
    filename = os.path.basename(dataPath)
    parts = filename.split('_')
    # 假设文件名格式为 "x_y_z_j_k.csv"
    k = int(parts[-1].split('.')[0])  # 提取文件名中最后一个部分（k），并去掉.csv扩展名

    # 读取数据
    data_1 = pd.read_csv(dataPath)
    # 提取标签
    label1_force = parts[2]
    label2_HI = parts[3]
    label1 = float(label1_force)
    label2 = float(label2_HI)
    labels.append([label1, label2])

    # 检查第一列的每一行，找到第一个大于0的值的位置N
    for N in range(len(data_1)):
        if data_1.iloc[N, 1] != 0:
            break

    # 如果找到了大于0的值，则从第二列的第N行开始，往后取M个点
    if N < len(data_1) - M + 1:  # 确保N+M不会超出索引范围
        data.append(data_1.iloc[N:N+M, 1].values)

# 将数据和标签转换为numpy数组
all_datas = np.array(data, dtype="float")
all_labels = np.array(labels)

# 直接按照7:2:1的比例划分
# 首先分出训练集（70%）和临时集（30%）
train_datas, temp_datas, train_labels, temp_labels = train_test_split(
    all_datas, all_labels, test_size = 0.3, random_state=42
)

# 然后将临时集按照2:1的比例划分为验证集和测试集
# 2:1相当于验证集占2/3，测试集占1/3
validation_datas, test_datas, validation_labels, test_labels = train_test_split(
    temp_datas, temp_labels, test_size=2/3, random_state=42
)

# 输出数据集的形状以确认
print("训练集数据形状:", train_datas.shape)
print("验证集数据形状:", validation_datas.shape)
print("测试集数据形状:", test_datas.shape)
# Out:
# 训练集数据形状: (604, 9900)
# 验证集数据形状: (86, 9900)
# 测试集数据形状: (174, 9900)

# %%
train_datas = train_datas.reshape(-1,train_datas.shape[1],1)
validation_datas = validation_datas.reshape(-1,validation_datas.shape[1],1)

print(f'train_datas.shape:{train_datas.shape}')
print(f'validation_datas.shape:{validation_datas.shape}')
# Out:
# train_datas.shape:(604, 9900, 1)
# validation_datas.shape:(86, 9900, 1)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(train_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{save_path}train_signal.jpg', dpi=600, bbox_inches='tight')

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(validation_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{save_path}validation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
BATCH_SIZE = 32
input_size = M+39
hidden_size = 64
num_layers = 2
output_size = 2
EPOCH = 1000
learning_rate = 1e-3

# %%
# 准备数据
#torch.from_numpy将 NumPy 数组转换为 PyTorch 张量
#TensorDataset用于将张量数据和标签组合成一个数据集
#DataLoader用于从数据集中加载批次数据，并进行训练或测试

train_dataset = TensorDataset(torch.from_numpy(train_datas),torch.from_numpy(train_labels))
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset = TensorDataset(torch.from_numpy(validation_datas),torch.from_numpy(validation_labels))
validation_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ConvAutoencoderPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers,dropout_rate):
        super().__init__()

        # ---------- 卷积编码器 ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(input_size, hidden_size*4, 5, stride=2, padding=2),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.Conv1d(hidden_size*4, hidden_size*2, 3, stride=2, padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.Conv1d(hidden_size*2, hidden_size, 3, stride=1, padding=1),
            nn.BatchNorm1d(hidden_size), nn.ReLU(), nn.Dropout(dropout_rate),
        )

        # ---------- 卷积解码器 ----------
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(hidden_size, hidden_size*2, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.ConvTranspose1d(hidden_size*2, hidden_size*4, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.ConvTranspose1d(hidden_size*4, input_size, 5, stride=1, padding=2),
        )

        # ---------- 2 层双向 LSTM ----------
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            bidirectional=True,
                            dropout=dropout_rate if 2 > 1 else 0,
                            batch_first=False)

        # ---------- 回归头 ----------
        self.regressor = nn.Linear(2 * hidden_size, output_size)   # output_size=2: [force, HI]

    # ------------- 前向 -------------
    def forward(self, x):
        # 小波分解（同你原来写法）
        coeffs = pywt.wavedec(x.cpu().numpy(), 'db4', level=6)
        x3 = torch.cat([torch.from_numpy(c).to(x.device) for c in coeffs], dim=-1)
        x6 = x3.permute(0, 2, 1)                      # [B, C, L]  C=input_size

        # 卷积自编码
        encoded = self.encoder(x6)
        decoded = self.decoder(encoded)               # [B, C, L]

        # 给 LSTM：把 L 放到第一维，通道当特征
        lstm_in = decoded.permute(2, 0, 1)            # [L, B, C]

        # 双向 LSTM 全部时间步输出
        lstm_out, _ = self.lstm(lstm_in)              # [L, B, 2*hidden_size]

        # 取最后一个时间步
        last_step = lstm_out[-1]                      # [B, 2*hidden_size]

        # 回归
        out = self.regressor(last_step)               # [B, 2]
        return out

# %%
#模型实例化
model = ConvAutoencoderPredictor(input_size, hidden_size, output_size, num_layers,dropout_rate = 0)
model.to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
#两个空列表用于存储训练和验证中的损失值
train_loss_force_epoch = []
train_loss_HI_epoch = []

#两个空列表用于存储训练和验证中的损失值
validation_loss_force_epoch = []
validation_loss_HI_epoch = []

# %%
def train_and_validate(model, train_loader, validation_loader, optimizer, loss, device, EPOCH, A, patience=500):
    """
    训练和验证模型的函数

    参数:
    model: 要训练的模型
    train_loader: 训练数据加载器
    validation_loader: 验证数据加载器
    optimizer: 优化器
    loss: 损失函数
    device: 运行设备（如 'cuda' 或 'cpu')
    EPOCH: 训练的总轮数
    A: HI 损失的权重系数
    patience: 早停的耐心值，即在多少个epoch内验证损失没有改善时停止训练
    """
    # 添加学习率调度器 - 每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用总验证损失作为监控指标
    best_val_total_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    # 记录各项损失
    train_loss_force_epoch = []
    train_loss_HI_epoch = []
    validation_loss_force_epoch = []
    validation_loss_HI_epoch = []
    
    # 记录各个指标的列表
    train_force_losses = []
    train_HI_losses = []
    val_force_losses = []
    val_HI_losses = []
    
    for epoch in range(EPOCH):
        # 训练步骤开始
        model.train()
        train_force_epoch = 0.0
        train_HI_epoch = 0.0
        train_force_batch = 0.0
        train_HI_batch = 0.0
        
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()

            x1 = x.type(torch.FloatTensor)
            x2 = x1.permute(0, 2, 1)

            force1 = y[:, 0].type(torch.FloatTensor)
            HI1 = y[:, 1].type(torch.FloatTensor)

            x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

            force_hat = model(x3)[:, 0]
            HI_hat = model(x3)[:, 1]

            train_loss_force = loss(force_hat.flatten(), force2.flatten())
            train_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

            train_loss_force.backward()
            train_loss_HI.backward()

            optimizer.step()

            train_force_epoch += train_loss_force.item() * x3.size(0)
            train_HI_epoch += train_loss_HI.item() * x3.size(0)
            train_force_batch += train_loss_force.item()
            train_HI_batch += train_loss_HI.item()

        # 更新学习率
        scheduler.step()
        
        # 计算平均训练损失
        train_mean_force = train_force_epoch / len(train_loader.dataset)
        train_loss_force_epoch.append(train_mean_force)
        train_force_losses.append(train_force_batch / len(train_loader))

        train_mean_HI = train_HI_epoch / len(train_loader.dataset)
        train_loss_HI_epoch.append(train_mean_HI)
        train_HI_losses.append(train_HI_batch / len(train_loader))

        # 验证步骤开始
        model.eval()
        validation_force_epoch = 0.0
        validation_HI_epoch = 0.0
        val_force_batch = 0.0
        val_HI_batch = 0.0

        with torch.no_grad():
            for i, (x, y) in enumerate(validation_loader):
                x1 = x.type(torch.FloatTensor)
                x2 = x1.permute(0, 2, 1)

                force1 = y[:, 0].type(torch.FloatTensor)
                HI1 = y[:, 1].type(torch.FloatTensor)

                x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

                force_hat = model(x3)[:, 0]
                HI_hat = model(x3)[:, 1]

                validation_loss_force = loss(force_hat.flatten(), force2.flatten())
                validation_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

                validation_force_epoch += validation_loss_force.item() * x3.size(0)
                validation_HI_epoch += validation_loss_HI.item() * x3.size(0)
                val_force_batch += validation_loss_force.item()
                val_HI_batch += validation_loss_HI.item()

        # 计算平均验证损失
        validation_mean_force = validation_force_epoch / len(validation_loader.dataset)
        validation_loss_force_epoch.append(validation_mean_force)
        val_force_losses.append(val_force_batch / len(validation_loader))

        validation_mean_HI = validation_HI_epoch / len(validation_loader.dataset)
        validation_loss_HI_epoch.append(validation_mean_HI)
        val_HI_losses.append(val_HI_batch / len(validation_loader))
        
        # 计算总验证损失用于早停监控
        total_val_loss = validation_mean_force

        # 早停检查 - 使用总验证损失作为监控指标
        if total_val_loss < best_val_total_loss:
            best_val_total_loss = total_val_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            # 仅在验证损失改善时打印信息
            if epoch % (EPOCH//100) == 0:
                print(f"Epoch {epoch+1}: 验证总损失改善 ({total_val_loss:.4f} -> {best_val_total_loss:.4f})，保存最佳模型")
        else:
            patience_counter += 1
            
            # 检查是否触发早停
            if patience_counter >= patience:
                print(f"\n早停触发！连续 {patience} 个epoch验证总损失未改善")
                print(f"最佳验证总损失: {best_val_total_loss:.4f} (epoch {epoch+1-patience})")
                break

        # 每10个epoch打印一次训练信息
        if epoch % (EPOCH//100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"\nEpoch {epoch+1}/{EPOCH}, LR: {current_lr:.6f}")
            print(f"Train - Force Loss: {train_mean_force:.4f}, HI Loss: {train_mean_HI:.4f}")
            print(f"Valid - Force Loss: {validation_mean_force:.4f}, HI Loss: {validation_mean_HI:.4f}")
            print(f"Valid Total Loss: {total_val_loss:.4f}, Best: {best_val_total_loss:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控总验证损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成，加载最佳模型（验证总损失: {best_val_total_loss:.4f})")
    else:
        print("\n训练完成，但未找到最佳模型")
    
    return train_force_losses, train_HI_losses, val_force_losses, val_HI_losses

# %%
# 假设你已经定义了模型、数据加载器、优化器、损失函数、设备等
train_loss_force, train_loss_HI, validation_loss_force, validation_loss_HI = train_and_validate(
    model=model,
    train_loader = train_loader,
    validation_loader = validation_loader,
    optimizer = optimizer,
    loss = loss,
    device = device,
    EPOCH = EPOCH,
    A = A,
    patience = 500  # 早停耐心值设为500个epoch
)
# Out:
# Epoch 1: 验证总损失改善 (107.4698 -> 107.4698)，保存最佳模型
#
# Epoch 1/1000, LR: 0.001000
# Train - Force Loss: 122.5100, HI Loss: 0.0440
# Valid - Force Loss: 107.4698, HI Loss: 0.0290
# Valid Total Loss: 107.4698, Best: 107.4698
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 11: 验证总损失改善 (23.9835 -> 23.9835)，保存最佳模型
#
# Epoch 11/1000, LR: 0.001000
# Train - Force Loss: 25.5832, HI Loss: 0.0258
# Valid - Force Loss: 23.9835, HI Loss: 0.0245
# Valid Total Loss: 23.9835, Best: 23.9835
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 21: 验证总损失改善 (23.6589 -> 23.6589)，保存最佳模型
#
# Epoch 21/1000, LR: 0.001000
# Train - Force Loss: 25.4530, HI Loss: 0.0258
# Valid - Force Loss: 23.6589, HI Loss: 0.0237
# Valid Total Loss: 23.6589, Best: 23.6589
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 31: 验证总损失改善 (7.5645 -> 7.5645)，保存最佳模型
#
# Epoch 31/1000, LR: 0.001000
# Train - Force Loss: 9.3237, HI Loss: 0.0095
# Valid - Force Loss: 7.5645, HI Loss: 0.0079
# Valid Total Loss: 7.5645, Best: 7.5645
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 41: 验证总损失改善 (2.2607 -> 2.2607)，保存最佳模型
#
# Epoch 41/1000, LR: 0.001000
# Train - Force Loss: 3.7654, HI Loss: 0.0043
# Valid - Force Loss: 2.2607, HI Loss: 0.0027
# Valid Total Loss: 2.2607, Best: 2.2607
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 51/1000, LR: 0.001000
# Train - Force Loss: 2.9874, HI Loss: 0.0046
# Valid - Force Loss: 1.9960, HI Loss: 0.0033
# Valid Total Loss: 1.9960, Best: 1.7256
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 61/1000, LR: 0.001000
# Train - Force Loss: 3.8032, HI Loss: 0.0101
# Valid - Force Loss: 1.8800, HI Loss: 0.0061
# Valid Total Loss: 1.8800, Best: 1.5466
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 71/1000, LR: 0.001000
# Train - Force Loss: 2.3516, HI Loss: 0.0034
# Valid - Force Loss: 1.6050, HI Loss: 0.0018
# Valid Total Loss: 1.6050, Best: 1.3113
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 81/1000, LR: 0.001000
# Train - Force Loss: 2.7838, HI Loss: 0.0034
# Valid - Force Loss: 1.6329, HI Loss: 0.0017
# Valid Total Loss: 1.6329, Best: 1.3113
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 91/1000, LR: 0.001000
# Train - Force Loss: 3.1472, HI Loss: 0.0042
# Valid - Force Loss: 1.6304, HI Loss: 0.0037
# Valid Total Loss: 1.6304, Best: 1.3113
# 早停计数器: 23/500 (监控总验证损失)
#
# Epoch 101/1000, LR: 0.000800
# Train - Force Loss: 2.7544, HI Loss: 0.0033
# Valid - Force Loss: 1.6126, HI Loss: 0.0018
# Valid Total Loss: 1.6126, Best: 1.3113
# 早停计数器: 33/500 (监控总验证损失)
#
# Epoch 111/1000, LR: 0.000800
# Train - Force Loss: 2.5935, HI Loss: 0.0029
# Valid - Force Loss: 1.7619, HI Loss: 0.0017
# Valid Total Loss: 1.7619, Best: 1.3113
# 早停计数器: 43/500 (监控总验证损失)
#
# Epoch 121/1000, LR: 0.000800
# Train - Force Loss: 2.3019, HI Loss: 0.0025
# Valid - Force Loss: 1.5610, HI Loss: 0.0016
# Valid Total Loss: 1.5610, Best: 1.3113
# 早停计数器: 53/500 (监控总验证损失)
#
# Epoch 131/1000, LR: 0.000800
# Train - Force Loss: 2.5022, HI Loss: 0.0025
# Valid - Force Loss: 1.4908, HI Loss: 0.0017
# Valid Total Loss: 1.4908, Best: 1.3113
# 早停计数器: 63/500 (监控总验证损失)
#
# Epoch 141/1000, LR: 0.000800
# Train - Force Loss: 2.3919, HI Loss: 0.0027
# Valid - Force Loss: 1.6305, HI Loss: 0.0021
# Valid Total Loss: 1.6305, Best: 1.2952
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 151/1000, LR: 0.000800
# Train - Force Loss: 2.7787, HI Loss: 0.0030
# Valid - Force Loss: 1.6376, HI Loss: 0.0021
# Valid Total Loss: 1.6376, Best: 1.2952
# 早停计数器: 15/500 (监控总验证损失)
#
# Epoch 161/1000, LR: 0.000800
# Train - Force Loss: 2.7055, HI Loss: 0.0030
# Valid - Force Loss: 1.6950, HI Loss: 0.0033
# Valid Total Loss: 1.6950, Best: 1.2746
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 171/1000, LR: 0.000800
# Train - Force Loss: 2.6918, HI Loss: 0.0029
# Valid - Force Loss: 1.6890, HI Loss: 0.0019
# Valid Total Loss: 1.6890, Best: 1.2746
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 181/1000, LR: 0.000800
# Train - Force Loss: 2.2268, HI Loss: 0.0024
# Valid - Force Loss: 1.7200, HI Loss: 0.0018
# Valid Total Loss: 1.7200, Best: 1.2746
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 191/1000, LR: 0.000800
# Train - Force Loss: 2.3587, HI Loss: 0.0026
# Valid - Force Loss: 1.4426, HI Loss: 0.0015
# Valid Total Loss: 1.4426, Best: 1.2746
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 201/1000, LR: 0.000640
# Train - Force Loss: 2.5688, HI Loss: 0.0026
# Valid - Force Loss: 2.4896, HI Loss: 0.0015
# Valid Total Loss: 2.4896, Best: 1.2686
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 211/1000, LR: 0.000640
# Train - Force Loss: 2.7471, HI Loss: 0.0041
# Valid - Force Loss: 1.6912, HI Loss: 0.0019
# Valid Total Loss: 1.6912, Best: 1.2488
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 221/1000, LR: 0.000640
# Train - Force Loss: 2.7841, HI Loss: 0.0028
# Valid - Force Loss: 1.3542, HI Loss: 0.0015
# Valid Total Loss: 1.3542, Best: 1.2488
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 231/1000, LR: 0.000640
# Train - Force Loss: 1.7698, HI Loss: 0.0020
# Valid - Force Loss: 1.3308, HI Loss: 0.0020
# Valid Total Loss: 1.3308, Best: 1.2488
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 241/1000, LR: 0.000640
# Train - Force Loss: 1.8634, HI Loss: 0.0027
# Valid - Force Loss: 1.4999, HI Loss: 0.0020
# Valid Total Loss: 1.4999, Best: 1.2488
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 251/1000, LR: 0.000640
# Train - Force Loss: 3.3499, HI Loss: 0.0034
# Valid - Force Loss: 2.4538, HI Loss: 0.0019
# Valid Total Loss: 2.4538, Best: 1.2488
# 早停计数器: 46/500 (监控总验证损失)
#
# Epoch 261/1000, LR: 0.000640
# Train - Force Loss: 2.4900, HI Loss: 0.0026
# Valid - Force Loss: 1.1861, HI Loss: 0.0016
# Valid Total Loss: 1.1861, Best: 1.1562
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 271/1000, LR: 0.000640
# Train - Force Loss: 3.0512, HI Loss: 0.0035
# Valid - Force Loss: 1.9891, HI Loss: 0.0017
# Valid Total Loss: 1.9891, Best: 1.1562
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 281/1000, LR: 0.000640
# Train - Force Loss: 2.9855, HI Loss: 0.0031
# Valid - Force Loss: 1.8248, HI Loss: 0.0019
# Valid Total Loss: 1.8248, Best: 1.1562
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 291/1000, LR: 0.000640
# Train - Force Loss: 3.7915, HI Loss: 0.0044
# Valid - Force Loss: 2.9755, HI Loss: 0.0036
# Valid Total Loss: 2.9755, Best: 1.1562
# 早停计数器: 31/500 (监控总验证损失)
#
# Epoch 301/1000, LR: 0.000512
# Train - Force Loss: 3.3179, HI Loss: 0.0036
# Valid - Force Loss: 2.1059, HI Loss: 0.0023
# Valid Total Loss: 2.1059, Best: 1.1562
# 早停计数器: 41/500 (监控总验证损失)
#
# Epoch 311/1000, LR: 0.000512
# Train - Force Loss: 2.8765, HI Loss: 0.0029
# Valid - Force Loss: 2.6877, HI Loss: 0.0039
# Valid Total Loss: 2.6877, Best: 1.1562
# 早停计数器: 51/500 (监控总验证损失)
#
# Epoch 321/1000, LR: 0.000512
# Train - Force Loss: 2.6583, HI Loss: 0.0031
# Valid - Force Loss: 1.6333, HI Loss: 0.0016
# Valid Total Loss: 1.6333, Best: 1.1562
# 早停计数器: 61/500 (监控总验证损失)
#
# Epoch 331/1000, LR: 0.000512
# Train - Force Loss: 3.1061, HI Loss: 0.0042
# Valid - Force Loss: 1.8051, HI Loss: 0.0018
# Valid Total Loss: 1.8051, Best: 1.1562
# 早停计数器: 71/500 (监控总验证损失)
#
# Epoch 341/1000, LR: 0.000512
# Train - Force Loss: 2.2870, HI Loss: 0.0025
# Valid - Force Loss: 1.9430, HI Loss: 0.0018
# Valid Total Loss: 1.9430, Best: 1.1562
# 早停计数器: 81/500 (监控总验证损失)
#
# Epoch 351/1000, LR: 0.000512
# Train - Force Loss: 3.0486, HI Loss: 0.0038
# Valid - Force Loss: 2.1351, HI Loss: 0.0032
# Valid Total Loss: 2.1351, Best: 1.1562
# 早停计数器: 91/500 (监控总验证损失)
#
# Epoch 361/1000, LR: 0.000512
# Train - Force Loss: 2.4570, HI Loss: 0.0023
# Valid - Force Loss: 1.8579, HI Loss: 0.0015
# Valid Total Loss: 1.8579, Best: 1.1562
# 早停计数器: 101/500 (监控总验证损失)
#
# Epoch 371/1000, LR: 0.000512
# Train - Force Loss: 2.3921, HI Loss: 0.0025
# Valid - Force Loss: 1.6450, HI Loss: 0.0015
# Valid Total Loss: 1.6450, Best: 1.1562
# 早停计数器: 111/500 (监控总验证损失)
#
# Epoch 381/1000, LR: 0.000512
# Train - Force Loss: 2.5616, HI Loss: 0.0029
# Valid - Force Loss: 1.4234, HI Loss: 0.0015
# Valid Total Loss: 1.4234, Best: 1.1562
# 早停计数器: 121/500 (监控总验证损失)
#
# Epoch 391/1000, LR: 0.000512
# Train - Force Loss: 2.3003, HI Loss: 0.0030
# Valid - Force Loss: 1.7460, HI Loss: 0.0019
# Valid Total Loss: 1.7460, Best: 1.1562
# 早停计数器: 131/500 (监控总验证损失)
#
# Epoch 401/1000, LR: 0.000410
# Train - Force Loss: 2.1484, HI Loss: 0.0026
# Valid - Force Loss: 1.4666, HI Loss: 0.0014
# Valid Total Loss: 1.4666, Best: 1.1562
# 早停计数器: 141/500 (监控总验证损失)
#
# Epoch 411/1000, LR: 0.000410
# Train - Force Loss: 2.1692, HI Loss: 0.0025
# Valid - Force Loss: 1.4024, HI Loss: 0.0019
# Valid Total Loss: 1.4024, Best: 1.1562
# 早停计数器: 151/500 (监控总验证损失)
#
# Epoch 421/1000, LR: 0.000410
# Train - Force Loss: 2.3041, HI Loss: 0.0026
# Valid - Force Loss: 1.2481, HI Loss: 0.0015
# Valid Total Loss: 1.2481, Best: 1.1562
# 早停计数器: 161/500 (监控总验证损失)
#
# Epoch 431/1000, LR: 0.000410
# Train - Force Loss: 1.8141, HI Loss: 0.0018
# Valid - Force Loss: 1.5324, HI Loss: 0.0015
# Valid Total Loss: 1.5324, Best: 1.1562
# 早停计数器: 171/500 (监控总验证损失)
#
# Epoch 441/1000, LR: 0.000410
# Train - Force Loss: 2.4393, HI Loss: 0.0028
# Valid - Force Loss: 1.6494, HI Loss: 0.0016
# Valid Total Loss: 1.6494, Best: 1.1562
# 早停计数器: 181/500 (监控总验证损失)
#
# Epoch 451/1000, LR: 0.000410
# Train - Force Loss: 1.9937, HI Loss: 0.0023
# Valid - Force Loss: 1.2586, HI Loss: 0.0013
# Valid Total Loss: 1.2586, Best: 1.1562
# 早停计数器: 191/500 (监控总验证损失)
#
# Epoch 461/1000, LR: 0.000410
# Train - Force Loss: 2.5817, HI Loss: 0.0029
# Valid - Force Loss: 1.5648, HI Loss: 0.0014
# Valid Total Loss: 1.5648, Best: 1.1562
# 早停计数器: 201/500 (监控总验证损失)
#
# Epoch 471/1000, LR: 0.000410
# Train - Force Loss: 1.9031, HI Loss: 0.0021
# Valid - Force Loss: 1.4782, HI Loss: 0.0015
# Valid Total Loss: 1.4782, Best: 1.1562
# 早停计数器: 211/500 (监控总验证损失)
#
# Epoch 481/1000, LR: 0.000410
# Train - Force Loss: 1.9563, HI Loss: 0.0023
# Valid - Force Loss: 1.6983, HI Loss: 0.0016
# Valid Total Loss: 1.6983, Best: 1.1562
# 早停计数器: 221/500 (监控总验证损失)
#
# Epoch 491/1000, LR: 0.000410
# Train - Force Loss: 2.2718, HI Loss: 0.0026
# Valid - Force Loss: 1.7590, HI Loss: 0.0017
# Valid Total Loss: 1.7590, Best: 1.1562
# 早停计数器: 231/500 (监控总验证损失)
#
# Epoch 501/1000, LR: 0.000328
# Train - Force Loss: 2.0282, HI Loss: 0.0021
# Valid - Force Loss: 1.2344, HI Loss: 0.0012
# Valid Total Loss: 1.2344, Best: 1.1562
# 早停计数器: 241/500 (监控总验证损失)
#
# Epoch 511/1000, LR: 0.000328
# Train - Force Loss: 2.6604, HI Loss: 0.0029
# Valid - Force Loss: 1.6577, HI Loss: 0.0018
# Valid Total Loss: 1.6577, Best: 1.1562
# 早停计数器: 251/500 (监控总验证损失)
#
# Epoch 521/1000, LR: 0.000328
# Train - Force Loss: 2.3586, HI Loss: 0.0028
# Valid - Force Loss: 1.2296, HI Loss: 0.0023
# Valid Total Loss: 1.2296, Best: 1.1562
# 早停计数器: 261/500 (监控总验证损失)
#
# Epoch 531/1000, LR: 0.000328
# Train - Force Loss: 2.0736, HI Loss: 0.0021
# Valid - Force Loss: 1.7897, HI Loss: 0.0019
# Valid Total Loss: 1.7897, Best: 1.1562
# 早停计数器: 271/500 (监控总验证损失)
#
# Epoch 541/1000, LR: 0.000328
# Train - Force Loss: 2.2378, HI Loss: 0.0026
# Valid - Force Loss: 1.8841, HI Loss: 0.0026
# Valid Total Loss: 1.8841, Best: 1.1562
# 早停计数器: 281/500 (监控总验证损失)
#
# Epoch 551/1000, LR: 0.000328
# Train - Force Loss: 2.2319, HI Loss: 0.0023
# Valid - Force Loss: 1.9313, HI Loss: 0.0017
# Valid Total Loss: 1.9313, Best: 1.1562
# 早停计数器: 291/500 (监控总验证损失)
#
# Epoch 561/1000, LR: 0.000328
# Train - Force Loss: 2.0466, HI Loss: 0.0020
# Valid - Force Loss: 1.8597, HI Loss: 0.0016
# Valid Total Loss: 1.8597, Best: 1.1562
# 早停计数器: 301/500 (监控总验证损失)
#
# Epoch 571/1000, LR: 0.000328
# Train - Force Loss: 2.0536, HI Loss: 0.0026
# Valid - Force Loss: 1.4024, HI Loss: 0.0020
# Valid Total Loss: 1.4024, Best: 1.1562
# 早停计数器: 311/500 (监控总验证损失)
#
# Epoch 581/1000, LR: 0.000328
# Train - Force Loss: 2.2781, HI Loss: 0.0025
# Valid - Force Loss: 1.5769, HI Loss: 0.0028
# Valid Total Loss: 1.5769, Best: 1.1562
# 早停计数器: 321/500 (监控总验证损失)
#
# Epoch 591/1000, LR: 0.000328
# Train - Force Loss: 2.3423, HI Loss: 0.0024
# Valid - Force Loss: 1.6241, HI Loss: 0.0015
# Valid Total Loss: 1.6241, Best: 1.1562
# 早停计数器: 331/500 (监控总验证损失)
#
# Epoch 601/1000, LR: 0.000262
# Train - Force Loss: 2.0271, HI Loss: 0.0020
# Valid - Force Loss: 1.3166, HI Loss: 0.0013
# Valid Total Loss: 1.3166, Best: 1.1562
# 早停计数器: 341/500 (监控总验证损失)
#
# Epoch 611/1000, LR: 0.000262
# Train - Force Loss: 1.5885, HI Loss: 0.0018
# Valid - Force Loss: 1.7097, HI Loss: 0.0015
# Valid Total Loss: 1.7097, Best: 1.1562
# 早停计数器: 351/500 (监控总验证损失)
#
# Epoch 621/1000, LR: 0.000262
# Train - Force Loss: 1.8754, HI Loss: 0.0019
# Valid - Force Loss: 1.4079, HI Loss: 0.0015
# Valid Total Loss: 1.4079, Best: 1.1562
# 早停计数器: 361/500 (监控总验证损失)
#
# Epoch 631/1000, LR: 0.000262
# Train - Force Loss: 2.4084, HI Loss: 0.0024
# Valid - Force Loss: 1.8259, HI Loss: 0.0014
# Valid Total Loss: 1.8259, Best: 1.1562
# 早停计数器: 371/500 (监控总验证损失)
#
# Epoch 641/1000, LR: 0.000262
# Train - Force Loss: 2.1172, HI Loss: 0.0022
# Valid - Force Loss: 1.4314, HI Loss: 0.0015
# Valid Total Loss: 1.4314, Best: 1.1562
# 早停计数器: 381/500 (监控总验证损失)
#
# Epoch 651/1000, LR: 0.000262
# Train - Force Loss: 2.2183, HI Loss: 0.0023
# Valid - Force Loss: 1.2777, HI Loss: 0.0014
# Valid Total Loss: 1.2777, Best: 1.1562
# 早停计数器: 391/500 (监控总验证损失)
#
# Epoch 661/1000, LR: 0.000262
# Train - Force Loss: 1.7647, HI Loss: 0.0018
# Valid - Force Loss: 1.3454, HI Loss: 0.0014
# Valid Total Loss: 1.3454, Best: 1.1562
# 早停计数器: 401/500 (监控总验证损失)
#
# Epoch 671/1000, LR: 0.000262
# Train - Force Loss: 2.2759, HI Loss: 0.0025
# Valid - Force Loss: 1.2763, HI Loss: 0.0014
# Valid Total Loss: 1.2763, Best: 1.1562
# 早停计数器: 411/500 (监控总验证损失)
#
# Epoch 681/1000, LR: 0.000262
# Train - Force Loss: 2.1496, HI Loss: 0.0026
# Valid - Force Loss: 1.6612, HI Loss: 0.0016
# Valid Total Loss: 1.6612, Best: 1.1562
# 早停计数器: 421/500 (监控总验证损失)
#
# Epoch 691/1000, LR: 0.000262
# Train - Force Loss: 1.8724, HI Loss: 0.0020
# Valid - Force Loss: 1.3837, HI Loss: 0.0017
# Valid Total Loss: 1.3837, Best: 1.1562
# 早停计数器: 431/500 (监控总验证损失)
#
# Epoch 701/1000, LR: 0.000210
# Train - Force Loss: 2.1368, HI Loss: 0.0022
# Valid - Force Loss: 1.3780, HI Loss: 0.0013
# Valid Total Loss: 1.3780, Best: 1.1562
# 早停计数器: 441/500 (监控总验证损失)
#
# Epoch 711/1000, LR: 0.000210
# Train - Force Loss: 1.6411, HI Loss: 0.0019
# Valid - Force Loss: 1.4191, HI Loss: 0.0014
# Valid Total Loss: 1.4191, Best: 1.1562
# 早停计数器: 451/500 (监控总验证损失)
#
# Epoch 721/1000, LR: 0.000210
# Train - Force Loss: 2.2038, HI Loss: 0.0022
# Valid - Force Loss: 1.4483, HI Loss: 0.0015
# Valid Total Loss: 1.4483, Best: 1.1562
# 早停计数器: 461/500 (监控总验证损失)
#
# Epoch 731/1000, LR: 0.000210
# Train - Force Loss: 2.0619, HI Loss: 0.0020
# Valid - Force Loss: 1.3551, HI Loss: 0.0013
# Valid Total Loss: 1.3551, Best: 1.1562
# 早停计数器: 471/500 (监控总验证损失)
#
# Epoch 741/1000, LR: 0.000210
# Train - Force Loss: 1.8019, HI Loss: 0.0021
# Valid - Force Loss: 1.4527, HI Loss: 0.0014
# Valid Total Loss: 1.4527, Best: 1.1562
# 早停计数器: 481/500 (监控总验证损失)
#
# Epoch 751/1000, LR: 0.000210
# Train - Force Loss: 2.0231, HI Loss: 0.0020
# Valid - Force Loss: 1.4066, HI Loss: 0.0013
# Valid Total Loss: 1.4066, Best: 1.1562
# 早停计数器: 491/500 (监控总验证损失)
#
# 早停触发！连续 500 个epoch验证总损失未改善
# 最佳验证总损失: 1.1562 (epoch 260)
#
# 训练完成，加载最佳模型（验证总损失: 1.1562)

# %%
torch.save(model, f'{save_path}Inverse_Model_MSE.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
plt.style.use('default')
plt.figure(figsize=(12, 8)) # 创建Figure对象，并指定尺寸
plt.rcParams['font.family'] = ['Times New Roman']

# 设置x轴刻度
epoch = np.arange(0, len(train_loss_force), len(train_loss_force) // 10)
plt.xticks(epoch)

# 创建第一个y轴
ax1 = plt.gca()
ax1.plot(train_loss_force, 'r-', linewidth=2.5)
ax1.plot(train_loss_force, marker='o', markersize=5, color='red', linestyle='None', label='Training loss for PF')
ax1.plot(validation_loss_force, 'r-', linewidth=2.5)
ax1.plot(validation_loss_force, marker='*', markersize=5, color='red', linestyle='None', label='Validation loss for PF')

ax1.set_xlabel('Epoch', fontdict={'weight': 'normal', 'size': 20})
ax1.set_ylabel('Loss for PF', fontdict={'weight': 'normal', 'size': 20}, color='red')

ax1.tick_params(axis='y', labelcolor='red')
ax1.tick_params(axis='both', which='major',labelcolor='red', labelsize=15)

# 添加图例
ax1.legend(loc='upper left', fontsize=20)

# 计算最大值
max_val_force = max(
    max(train_loss_force),
    max(validation_loss_force)
)

ax1.set_ylim(1, max_val_force)  # 直接使用浮点数，不要用 [0]

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None', label='Training loss for HI')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None', label='Validation loss for HI')

ax2.set_ylabel('Loss for HI', fontdict={'weight': 'normal', 'size': 20}, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major',labelcolor='blue', labelsize=15)

# 计算第二个轴的最大值
max_val_HI = max(
    max(train_loss_HI),
    max(validation_loss_HI)
)

ax2.set_ylim(0, max_val_HI)  # 直接使用浮点数，不要用 [0]
ax2.legend(loc='upper right', fontsize=20)

# 创建放大图的子图（inset）
x1 = int(len(train_loss_force)*0.7)
x2 = int(len(train_loss_force))

ax_inset = plt.axes([0.45, 0.25, 0.4, 0.4])  # [left, bottom, width, height]
ax_inset.plot(train_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(train_loss_force, marker='o', markersize=8, color='red', linestyle='None')
ax_inset.plot(validation_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(validation_loss_force, marker='*', markersize=8, color='red', linestyle='None')

# 计算放大图的最大值
max_val_force_inset = max(
    max(train_loss_force[x1:x2]),
    max(validation_loss_force[x1:x2])
)

ax_inset.set_xlim(x1, x2)
ax_inset.set_ylim(0, max_val_force_inset)  # 直接使用浮点数
ax_inset.tick_params(axis='both', which='major',  labelcolor='red',labelsize=15)

ax2_inset = ax_inset.twinx()

ax2_inset.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2_inset.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None')
ax2_inset.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2_inset.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None')

# 计算放大图第二个轴的最大值
max_val_HI_inset = max(
    max(train_loss_HI[x1:x2]),
    max(validation_loss_HI[x1:x2])
)

ax2_inset.set_ylim(0.001, max_val_HI_inset)  # 直接使用浮点数

ax2_inset.tick_params(axis='y', labelcolor='blue')
ax2_inset.tick_params(axis='both', which='major', labelsize=15)

# 保存图像
plt.savefig(f'{save_path}Inverse_problem_Loss.jpg', dpi=600, bbox_inches='tight')
plt.show()
