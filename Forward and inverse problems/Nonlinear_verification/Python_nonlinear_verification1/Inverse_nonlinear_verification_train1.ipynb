# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import pywt
import torch.optim as optim
import glob
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

Main_path = 'D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'
Data_path = f'{Main_path}Data\\'
Save_path = f'{Main_path}Nonlinear_verification\\Python_nonlinear_verification1\\'
# Out:
# Using device: cuda:0

# %%
M = 9900
A = 1
data = []
labels = []
skipped_files = []  # 记录跳过的文件

# 拿到数据路径，方便后续读取
dir_path = f'{Data_path}Experiment_signal'
dataPaths = sorted(glob.glob(os.path.join(dir_path, '**', '*.csv'), recursive=True))
random.seed(42)
random.shuffle(dataPaths)

# 遍历读取数据
for dataPath in dataPaths:
    # 读取数据（先读取，后验证）
    data_1 = pd.read_csv(dataPath)
    
    # 检查第一列的每一行，找到第一个大于0的值的位置N
    N = 0
    for i in range(len(data_1)):
        if data_1.iloc[i, 1] != 0:
            N = i
            break
    
    # 【关键修复】先验证数据长度，不够就跳过整个文件
    if N >= len(data_1) - M + 1:
        filename = os.path.basename(dataPath)
        print(f"警告：跳过 {filename} - 数据不足(可用{len(data_1)-N}点，需要{M}点)")
        skipped_files.append(filename)
        continue  # 跳过这个文件，data和labels都不添加
    
    # 只有数据足够时，才提取数据和标签
    data.append(data_1.iloc[N:N+M, 1].values)
    
    # 提取标签（移到验证之后）
    filename = os.path.basename(dataPath)
    parts = filename.split('_')
    label1 = float(parts[2])
    label2 = float(parts[3])
    labels.append([label1, label2])

print(f"\n处理完成：成功{len(data)}个，跳过{len(skipped_files)}个")

# 转换为numpy数组
all_datas = np.array(data, dtype="float")
all_labels = np.array(labels)

# 划分数据集（现在不会报错了）
train_datas, temp_datas, train_labels, temp_labels = train_test_split(
    all_datas, all_labels, test_size=0.3, random_state=42
)

validation_datas, test_datas, validation_labels, test_labels = train_test_split(
    temp_datas, temp_labels, test_size=2/3, random_state=42
)

print("训练集数据形状:", train_datas.shape)
print("验证集数据形状:", validation_datas.shape)
print("测试集数据形状:", test_datas.shape)
# Out:
# 处理完成：成功864个，跳过0个
# 训练集数据形状: (604, 9900)
# 验证集数据形状: (86, 9900)
# 测试集数据形状: (174, 9900)

# %%
train_datas = train_datas.reshape(-1,train_datas.shape[1],1)
validation_datas = validation_datas.reshape(-1,validation_datas.shape[1],1)

print(f'train_datas.shape:{train_datas.shape}')
print(f'validation_datas.shape:{validation_datas.shape}')
# Out:
# train_datas.shape:(604, 9900, 1)
# validation_datas.shape:(86, 9900, 1)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(train_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}train_signal.jpg', dpi=600, bbox_inches='tight')

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(validation_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}validation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
BATCH_SIZE = 32
input_size = 4953
hidden_size = 64
num_layers = 2
output_size = 2
EPOCH = 1000
learning_rate = 1e-3

# %%
# 准备数据
#torch.from_numpy将 NumPy 数组转换为 PyTorch 张量
#TensorDataset用于将张量数据和标签组合成一个数据集
#DataLoader用于从数据集中加载批次数据，并进行训练或测试

train_dataset = TensorDataset(torch.from_numpy(train_datas),torch.from_numpy(train_labels))
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset = TensorDataset(torch.from_numpy(validation_datas),torch.from_numpy(validation_labels))
validation_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ConvAutoencoderPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout_rate):
        super().__init__()
        
        # ---------- 卷积编码器 ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(input_size, hidden_size*4, 5, stride=2, padding=2),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Conv1d(hidden_size*4, hidden_size*2, 3, stride=2, padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Conv1d(hidden_size*2, hidden_size, 3, stride=1, padding=1),
            nn.BatchNorm1d(hidden_size), nn.ReLU(), nn.Dropout(dropout_rate),
        )

        # ---------- 卷积解码器 ----------
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(hidden_size, hidden_size*2, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(hidden_size*2, hidden_size*4, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(hidden_size*4, input_size, 5, stride=1, padding=2),
        )

        # ---------- 2 层双向 LSTM ----------
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            bidirectional=True,
                            dropout=dropout_rate if num_layers > 1 else 0,
                            batch_first=False)
        
        self.dropout_layer = nn.Dropout(dropout_rate)
        self.regressor = nn.Linear(2 * hidden_size, output_size)

    def forward(self, x):
        wavelet = 'db4'
        # 将张量移动至CPU上面
        x1 = x.cpu()

        # 将CPU张量转化为numpy
        x2 = x1.numpy()
        # 离散小波分解
        coeffs = pywt.wavedec(x2, wavelet, level=6)
        xh1 = coeffs[6]
        xh2 = coeffs[5]
        xh3 = coeffs[4]
        xh4 = coeffs[3]
        xh5 = coeffs[2]
        xh6 = coeffs[1]
        xl6 = coeffs[0]
        # 连接分解后的序列
        x3 = xh1

        x4 = torch.from_numpy(x3)
        x5 = x4.to(device)
        
        x_conv = x5.permute(0, 2, 1)
        encoded = self.encoder(x_conv)
        decoded = self.decoder(encoded)

        out = decoded.view(decoded.size(0), -1)
        out = out.view(out.size(0), -1, self.input_size)

        lstm_out, _ = self.lstm(out) 
        lstm_out = lstm_out[:, -1, :]

        out = self.dropout_layer(lstm_out)
        out = self.regressor(out)  
        return out

# %%
#模型实例化
model = ConvAutoencoderPredictor(input_size, hidden_size, output_size, num_layers,dropout_rate = 0.0)
model.to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
#两个空列表用于存储训练和验证中的损失值
train_loss_force_epoch = []
train_loss_HI_epoch = []

#两个空列表用于存储训练和验证中的损失值
validation_loss_force_epoch = []
validation_loss_HI_epoch = []

# %%
def train_and_validate(model, train_loader, validation_loader, optimizer, loss, device, EPOCH, A, patience=500):
    """
    训练和验证模型的函数

    参数:
    model: 要训练的模型
    train_loader: 训练数据加载器
    validation_loader: 验证数据加载器
    optimizer: 优化器
    loss: 损失函数
    device: 运行设备（如 'cuda' 或 'cpu')
    EPOCH: 训练的总轮数
    A: HI 损失的权重系数
    patience: 早停的耐心值，即在多少个epoch内验证损失没有改善时停止训练
    """
    # 添加学习率调度器 - 每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用总验证损失作为监控指标
    best_val_total_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    # 记录各项损失
    train_loss_force_epoch = []
    train_loss_HI_epoch = []
    validation_loss_force_epoch = []
    validation_loss_HI_epoch = []
    
    # 记录各个指标的列表
    train_force_losses = []
    train_HI_losses = []
    val_force_losses = []
    val_HI_losses = []
    
    for epoch in range(EPOCH):
        # 训练步骤开始
        model.train()
        train_force_epoch = 0.0
        train_HI_epoch = 0.0
        train_force_batch = 0.0
        train_HI_batch = 0.0
        
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()

            x1 = x.type(torch.FloatTensor)
            x2 = x1.permute(0, 2, 1)

            force1 = y[:, 0].type(torch.FloatTensor)
            HI1 = y[:, 1].type(torch.FloatTensor)

            x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

            force_hat = model(x3)[:, 0]
            HI_hat = model(x3)[:, 1]

            train_loss_force = loss(force_hat.flatten(), force2.flatten())
            train_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

            train_loss_force.backward()
            train_loss_HI.backward()

            optimizer.step()

            train_force_epoch += train_loss_force.item() * x3.size(0)
            train_HI_epoch += train_loss_HI.item() * x3.size(0)
            train_force_batch += train_loss_force.item()
            train_HI_batch += train_loss_HI.item()

        # 更新学习率
        scheduler.step()
        
        # 计算平均训练损失
        train_mean_force = train_force_epoch / len(train_loader.dataset)
        train_loss_force_epoch.append(train_mean_force)
        train_force_losses.append(train_force_batch / len(train_loader))

        train_mean_HI = train_HI_epoch / len(train_loader.dataset)
        train_loss_HI_epoch.append(train_mean_HI)
        train_HI_losses.append(train_HI_batch / len(train_loader))

        # 验证步骤开始
        model.eval()
        validation_force_epoch = 0.0
        validation_HI_epoch = 0.0
        val_force_batch = 0.0
        val_HI_batch = 0.0

        with torch.no_grad():
            for i, (x, y) in enumerate(validation_loader):
                x1 = x.type(torch.FloatTensor)
                x2 = x1.permute(0, 2, 1)

                force1 = y[:, 0].type(torch.FloatTensor)
                HI1 = y[:, 1].type(torch.FloatTensor)

                x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

                force_hat = model(x3)[:, 0]
                HI_hat = model(x3)[:, 1]

                validation_loss_force = loss(force_hat.flatten(), force2.flatten())
                validation_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

                validation_force_epoch += validation_loss_force.item() * x3.size(0)
                validation_HI_epoch += validation_loss_HI.item() * x3.size(0)
                val_force_batch += validation_loss_force.item()
                val_HI_batch += validation_loss_HI.item()

        # 计算平均验证损失
        validation_mean_force = validation_force_epoch / len(validation_loader.dataset)
        validation_loss_force_epoch.append(validation_mean_force)
        val_force_losses.append(val_force_batch / len(validation_loader))

        validation_mean_HI = validation_HI_epoch / len(validation_loader.dataset)
        validation_loss_HI_epoch.append(validation_mean_HI)
        val_HI_losses.append(val_HI_batch / len(validation_loader))
        
        # 计算总验证损失用于早停监控
        total_val_loss = validation_mean_force

        # 早停检查 - 使用总验证损失作为监控指标
        if total_val_loss < best_val_total_loss:
            best_val_total_loss = total_val_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            # 仅在验证损失改善时打印信息
            if epoch % (EPOCH//100) == 0:
                print(f"Epoch {epoch+1}: 验证总损失改善 ({total_val_loss:.4f} -> {best_val_total_loss:.4f})，保存最佳模型")
        else:
            patience_counter += 1
            
            # 检查是否触发早停
            if patience_counter >= patience:
                print(f"\n早停触发！连续 {patience} 个epoch验证总损失未改善")
                print(f"最佳验证总损失: {best_val_total_loss:.4f} (epoch {epoch+1-patience})")
                break

        # 每10个epoch打印一次训练信息
        if epoch % (EPOCH//100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"\nEpoch {epoch+1}/{EPOCH}, LR: {current_lr:.6f}")
            print(f"Train - Force Loss: {train_mean_force:.4f}, HI Loss: {train_mean_HI:.4f}")
            print(f"Valid - Force Loss: {validation_mean_force:.4f}, HI Loss: {validation_mean_HI:.4f}")
            print(f"Valid Total Loss: {total_val_loss:.4f}, Best: {best_val_total_loss:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控总验证损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成，加载最佳模型（验证总损失: {best_val_total_loss:.4f})")
    else:
        print("\n训练完成，但未找到最佳模型")
    
    return train_force_losses, train_HI_losses, val_force_losses, val_HI_losses

# %%
# 假设你已经定义了模型、数据加载器、优化器、损失函数、设备等
train_loss_force, train_loss_HI, validation_loss_force, validation_loss_HI = train_and_validate(
    model=model,
    train_loader = train_loader,
    validation_loader = validation_loader,
    optimizer = optimizer,
    loss = loss,
    device = device,
    EPOCH = EPOCH,
    A = A,
    patience = 500  # 早停耐心值设为500个epoch
)
# Out:
# Epoch 1: 验证总损失改善 (46.3927 -> 46.3927)，保存最佳模型
#
# Epoch 1/1000, LR: 0.001000
# Train - Force Loss: 82.6307, HI Loss: 0.0576
# Valid - Force Loss: 46.3927, HI Loss: 0.0552
# Valid Total Loss: 46.3927, Best: 46.3927
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 11/1000, LR: 0.001000
# Train - Force Loss: 25.8425, HI Loss: 0.0259
# Valid - Force Loss: 24.5337, HI Loss: 0.0243
# Valid Total Loss: 24.5337, Best: 24.4933
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 21/1000, LR: 0.001000
# Train - Force Loss: 25.5344, HI Loss: 0.0262
# Valid - Force Loss: 24.3673, HI Loss: 0.0253
# Valid Total Loss: 24.3673, Best: 24.3627
# 早停计数器: 1/500 (监控总验证损失)
# Epoch 31: 验证总损失改善 (24.3286 -> 24.3286)，保存最佳模型
#
# Epoch 31/1000, LR: 0.001000
# Train - Force Loss: 25.4124, HI Loss: 0.0255
# Valid - Force Loss: 24.3286, HI Loss: 0.0255
# Valid Total Loss: 24.3286, Best: 24.3286
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 41/1000, LR: 0.001000
# Train - Force Loss: 25.7678, HI Loss: 0.0255
# Valid - Force Loss: 24.3303, HI Loss: 0.0238
# Valid Total Loss: 24.3303, Best: 24.2310
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 51/1000, LR: 0.001000
# Train - Force Loss: 25.8445, HI Loss: 0.0283
# Valid - Force Loss: 24.3558, HI Loss: 0.0241
# Valid Total Loss: 24.3558, Best: 24.2237
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 61/1000, LR: 0.001000
# Train - Force Loss: 25.5808, HI Loss: 0.0261
# Valid - Force Loss: 24.1372, HI Loss: 0.0237
# Valid Total Loss: 24.1372, Best: 24.1358
# 早停计数器: 3/500 (监控总验证损失)
# Epoch 71: 验证总损失改善 (23.9495 -> 23.9495)，保存最佳模型
#
# Epoch 71/1000, LR: 0.001000
# Train - Force Loss: 25.5111, HI Loss: 0.0240
# Valid - Force Loss: 23.9495, HI Loss: 0.0336
# Valid Total Loss: 23.9495, Best: 23.9495
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 81: 验证总损失改善 (5.0851 -> 5.0851)，保存最佳模型
#
# Epoch 81/1000, LR: 0.001000
# Train - Force Loss: 7.4629, HI Loss: 0.0105
# Valid - Force Loss: 5.0851, HI Loss: 0.0064
# Valid Total Loss: 5.0851, Best: 5.0851
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 91: 验证总损失改善 (2.1011 -> 2.1011)，保存最佳模型
#
# Epoch 91/1000, LR: 0.001000
# Train - Force Loss: 4.0351, HI Loss: 0.0064
# Valid - Force Loss: 2.1011, HI Loss: 0.0069
# Valid Total Loss: 2.1011, Best: 2.1011
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 101: 验证总损失改善 (2.0500 -> 2.0500)，保存最佳模型
#
# Epoch 101/1000, LR: 0.000800
# Train - Force Loss: 3.8544, HI Loss: 0.0050
# Valid - Force Loss: 2.0500, HI Loss: 0.0032
# Valid Total Loss: 2.0500, Best: 2.0500
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 111/1000, LR: 0.000800
# Train - Force Loss: 3.4037, HI Loss: 0.0048
# Valid - Force Loss: 2.2781, HI Loss: 0.0027
# Valid Total Loss: 2.2781, Best: 1.5377
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 121/1000, LR: 0.000800
# Train - Force Loss: 2.9589, HI Loss: 0.0031
# Valid - Force Loss: 3.0764, HI Loss: 0.0031
# Valid Total Loss: 3.0764, Best: 1.5034
# 早停计数器: 9/500 (监控总验证损失)
#
# Epoch 131/1000, LR: 0.000800
# Train - Force Loss: 3.0727, HI Loss: 0.0044
# Valid - Force Loss: 1.8645, HI Loss: 0.0021
# Valid Total Loss: 1.8645, Best: 1.5034
# 早停计数器: 19/500 (监控总验证损失)
#
# Epoch 141/1000, LR: 0.000800
# Train - Force Loss: 2.4653, HI Loss: 0.0035
# Valid - Force Loss: 1.7431, HI Loss: 0.0023
# Valid Total Loss: 1.7431, Best: 1.5034
# 早停计数器: 29/500 (监控总验证损失)
#
# Epoch 151/1000, LR: 0.000800
# Train - Force Loss: 2.2656, HI Loss: 0.0031
# Valid - Force Loss: 1.7680, HI Loss: 0.0028
# Valid Total Loss: 1.7680, Best: 1.5034
# 早停计数器: 39/500 (监控总验证损失)
#
# Epoch 161/1000, LR: 0.000800
# Train - Force Loss: 2.7899, HI Loss: 0.0057
# Valid - Force Loss: 1.7370, HI Loss: 0.0046
# Valid Total Loss: 1.7370, Best: 1.5034
# 早停计数器: 49/500 (监控总验证损失)
#
# Epoch 171/1000, LR: 0.000800
# Train - Force Loss: 2.3580, HI Loss: 0.0028
# Valid - Force Loss: 1.5371, HI Loss: 0.0028
# Valid Total Loss: 1.5371, Best: 1.3879
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 181/1000, LR: 0.000800
# Train - Force Loss: 3.8650, HI Loss: 0.0039
# Valid - Force Loss: 3.1962, HI Loss: 0.0023
# Valid Total Loss: 3.1962, Best: 1.3879
# 早停计数器: 12/500 (监控总验证损失)
#
# Epoch 191/1000, LR: 0.000800
# Train - Force Loss: 2.7746, HI Loss: 0.0037
# Valid - Force Loss: 1.9688, HI Loss: 0.0038
# Valid Total Loss: 1.9688, Best: 1.3879
# 早停计数器: 22/500 (监控总验证损失)
#
# Epoch 201/1000, LR: 0.000640
# Train - Force Loss: 2.1389, HI Loss: 0.0023
# Valid - Force Loss: 1.6295, HI Loss: 0.0018
# Valid Total Loss: 1.6295, Best: 1.3879
# 早停计数器: 32/500 (监控总验证损失)
#
# Epoch 211/1000, LR: 0.000640
# Train - Force Loss: 2.1947, HI Loss: 0.0034
# Valid - Force Loss: 1.8566, HI Loss: 0.0026
# Valid Total Loss: 1.8566, Best: 1.3879
# 早停计数器: 42/500 (监控总验证损失)
#
# Epoch 221/1000, LR: 0.000640
# Train - Force Loss: 2.2281, HI Loss: 0.0032
# Valid - Force Loss: 1.5686, HI Loss: 0.0016
# Valid Total Loss: 1.5686, Best: 1.3879
# 早停计数器: 52/500 (监控总验证损失)
#
# Epoch 231/1000, LR: 0.000640
# Train - Force Loss: 2.9610, HI Loss: 0.0034
# Valid - Force Loss: 1.8072, HI Loss: 0.0019
# Valid Total Loss: 1.8072, Best: 1.3113
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 241/1000, LR: 0.000640
# Train - Force Loss: 2.2925, HI Loss: 0.0030
# Valid - Force Loss: 1.4059, HI Loss: 0.0018
# Valid Total Loss: 1.4059, Best: 1.3113
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 251/1000, LR: 0.000640
# Train - Force Loss: 2.6206, HI Loss: 0.0031
# Valid - Force Loss: 1.6790, HI Loss: 0.0016
# Valid Total Loss: 1.6790, Best: 1.3113
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 261/1000, LR: 0.000640
# Train - Force Loss: 2.7229, HI Loss: 0.0026
# Valid - Force Loss: 1.7986, HI Loss: 0.0026
# Valid Total Loss: 1.7986, Best: 1.3113
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 271/1000, LR: 0.000640
# Train - Force Loss: 2.8647, HI Loss: 0.0034
# Valid - Force Loss: 1.5691, HI Loss: 0.0024
# Valid Total Loss: 1.5691, Best: 1.2597
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 281/1000, LR: 0.000640
# Train - Force Loss: 2.1778, HI Loss: 0.0028
# Valid - Force Loss: 1.9508, HI Loss: 0.0024
# Valid Total Loss: 1.9508, Best: 1.2597
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 291/1000, LR: 0.000640
# Train - Force Loss: 2.3924, HI Loss: 0.0029
# Valid - Force Loss: 1.6103, HI Loss: 0.0017
# Valid Total Loss: 1.6103, Best: 1.2454
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 301/1000, LR: 0.000512
# Train - Force Loss: 2.3070, HI Loss: 0.0025
# Valid - Force Loss: 1.4951, HI Loss: 0.0016
# Valid Total Loss: 1.4951, Best: 1.2454
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 311/1000, LR: 0.000512
# Train - Force Loss: 2.1795, HI Loss: 0.0025
# Valid - Force Loss: 1.6756, HI Loss: 0.0020
# Valid Total Loss: 1.6756, Best: 1.2054
# 早停计数器: 8/500 (监控总验证损失)
#
# Epoch 321/1000, LR: 0.000512
# Train - Force Loss: 1.8718, HI Loss: 0.0020
# Valid - Force Loss: 1.4915, HI Loss: 0.0012
# Valid Total Loss: 1.4915, Best: 1.1304
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 331/1000, LR: 0.000512
# Train - Force Loss: 2.4596, HI Loss: 0.0031
# Valid - Force Loss: 1.4025, HI Loss: 0.0017
# Valid Total Loss: 1.4025, Best: 1.1304
# 早停计数器: 17/500 (监控总验证损失)
#
# Epoch 341/1000, LR: 0.000512
# Train - Force Loss: 2.1506, HI Loss: 0.0023
# Valid - Force Loss: 1.4550, HI Loss: 0.0014
# Valid Total Loss: 1.4550, Best: 1.1304
# 早停计数器: 27/500 (监控总验证损失)
#
# Epoch 351/1000, LR: 0.000512
# Train - Force Loss: 2.4161, HI Loss: 0.0028
# Valid - Force Loss: 1.3031, HI Loss: 0.0013
# Valid Total Loss: 1.3031, Best: 1.1304
# 早停计数器: 37/500 (监控总验证损失)
#
# Epoch 361/1000, LR: 0.000512
# Train - Force Loss: 1.9685, HI Loss: 0.0023
# Valid - Force Loss: 1.3272, HI Loss: 0.0014
# Valid Total Loss: 1.3272, Best: 1.1304
# 早停计数器: 47/500 (监控总验证损失)
#
# Epoch 371/1000, LR: 0.000512
# Train - Force Loss: 2.2182, HI Loss: 0.0024
# Valid - Force Loss: 1.6836, HI Loss: 0.0015
# Valid Total Loss: 1.6836, Best: 1.1304
# 早停计数器: 57/500 (监控总验证损失)
#
# Epoch 381/1000, LR: 0.000512
# Train - Force Loss: 2.3893, HI Loss: 0.0031
# Valid - Force Loss: 1.6314, HI Loss: 0.0024
# Valid Total Loss: 1.6314, Best: 1.1304
# 早停计数器: 67/500 (监控总验证损失)
#
# Epoch 391/1000, LR: 0.000512
# Train - Force Loss: 2.2424, HI Loss: 0.0024
# Valid - Force Loss: 1.4720, HI Loss: 0.0018
# Valid Total Loss: 1.4720, Best: 1.1304
# 早停计数器: 77/500 (监控总验证损失)
#
# Epoch 401/1000, LR: 0.000410
# Train - Force Loss: 2.4974, HI Loss: 0.0027
# Valid - Force Loss: 12.1771, HI Loss: 0.0105
# Valid Total Loss: 12.1771, Best: 1.1304
# 早停计数器: 87/500 (监控总验证损失)
#
# Epoch 411/1000, LR: 0.000410
# Train - Force Loss: 2.1605, HI Loss: 0.0026
# Valid - Force Loss: 1.3011, HI Loss: 0.0016
# Valid Total Loss: 1.3011, Best: 1.1304
# 早停计数器: 97/500 (监控总验证损失)
#
# Epoch 421/1000, LR: 0.000410
# Train - Force Loss: 3.1327, HI Loss: 0.0042
# Valid - Force Loss: 1.4450, HI Loss: 0.0063
# Valid Total Loss: 1.4450, Best: 1.1304
# 早停计数器: 107/500 (监控总验证损失)
#
# Epoch 431/1000, LR: 0.000410
# Train - Force Loss: 2.2634, HI Loss: 0.0026
# Valid - Force Loss: 1.7078, HI Loss: 0.0021
# Valid Total Loss: 1.7078, Best: 1.1304
# 早停计数器: 117/500 (监控总验证损失)
#
# Epoch 441/1000, LR: 0.000410
# Train - Force Loss: 2.1658, HI Loss: 0.0028
# Valid - Force Loss: 1.4013, HI Loss: 0.0027
# Valid Total Loss: 1.4013, Best: 1.1304
# 早停计数器: 127/500 (监控总验证损失)
#
# Epoch 451/1000, LR: 0.000410
# Train - Force Loss: 2.0589, HI Loss: 0.0027
# Valid - Force Loss: 1.3047, HI Loss: 0.0017
# Valid Total Loss: 1.3047, Best: 1.1304
# 早停计数器: 137/500 (监控总验证损失)
#
# Epoch 461/1000, LR: 0.000410
# Train - Force Loss: 1.8075, HI Loss: 0.0019
# Valid - Force Loss: 1.3033, HI Loss: 0.0014
# Valid Total Loss: 1.3033, Best: 1.1304
# 早停计数器: 147/500 (监控总验证损失)
#
# Epoch 471/1000, LR: 0.000410
# Train - Force Loss: 2.3071, HI Loss: 0.0033
# Valid - Force Loss: 1.4017, HI Loss: 0.0018
# Valid Total Loss: 1.4017, Best: 1.1304
# 早停计数器: 157/500 (监控总验证损失)
#
# Epoch 481/1000, LR: 0.000410
# Train - Force Loss: 2.1392, HI Loss: 0.0024
# Valid - Force Loss: 1.5083, HI Loss: 0.0015
# Valid Total Loss: 1.5083, Best: 1.1304
# 早停计数器: 167/500 (监控总验证损失)
#
# Epoch 491/1000, LR: 0.000410
# Train - Force Loss: 2.1516, HI Loss: 0.0024
# Valid - Force Loss: 1.2320, HI Loss: 0.0021
# Valid Total Loss: 1.2320, Best: 1.1304
# 早停计数器: 177/500 (监控总验证损失)
#
# Epoch 501/1000, LR: 0.000328
# Train - Force Loss: 2.1155, HI Loss: 0.0023
# Valid - Force Loss: 1.4609, HI Loss: 0.0014
# Valid Total Loss: 1.4609, Best: 1.1304
# 早停计数器: 187/500 (监控总验证损失)
#
# Epoch 511/1000, LR: 0.000328
# Train - Force Loss: 1.9575, HI Loss: 0.0023
# Valid - Force Loss: 1.4327, HI Loss: 0.0018
# Valid Total Loss: 1.4327, Best: 1.1304
# 早停计数器: 197/500 (监控总验证损失)
#
# Epoch 521/1000, LR: 0.000328
# Train - Force Loss: 2.3650, HI Loss: 0.0031
# Valid - Force Loss: 1.2933, HI Loss: 0.0029
# Valid Total Loss: 1.2933, Best: 1.1304
# 早停计数器: 207/500 (监控总验证损失)
#
# Epoch 531/1000, LR: 0.000328
# Train - Force Loss: 2.2597, HI Loss: 0.0027
# Valid - Force Loss: 1.7067, HI Loss: 0.0018
# Valid Total Loss: 1.7067, Best: 1.1304
# 早停计数器: 217/500 (监控总验证损失)
#
# Epoch 541/1000, LR: 0.000328
# Train - Force Loss: 2.9091, HI Loss: 0.0031
# Valid - Force Loss: 2.0436, HI Loss: 0.0018
# Valid Total Loss: 2.0436, Best: 1.1304
# 早停计数器: 227/500 (监控总验证损失)
#
# Epoch 551/1000, LR: 0.000328
# Train - Force Loss: 2.4479, HI Loss: 0.0025
# Valid - Force Loss: 1.5176, HI Loss: 0.0014
# Valid Total Loss: 1.5176, Best: 1.1304
# 早停计数器: 237/500 (监控总验证损失)
#
# Epoch 561/1000, LR: 0.000328
# Train - Force Loss: 2.3835, HI Loss: 0.0024
# Valid - Force Loss: 1.6662, HI Loss: 0.0019
# Valid Total Loss: 1.6662, Best: 1.1304
# 早停计数器: 247/500 (监控总验证损失)
#
# Epoch 571/1000, LR: 0.000328
# Train - Force Loss: 2.0705, HI Loss: 0.0021
# Valid - Force Loss: 1.6338, HI Loss: 0.0023
# Valid Total Loss: 1.6338, Best: 1.1304
# 早停计数器: 257/500 (监控总验证损失)
#
# Epoch 581/1000, LR: 0.000328
# Train - Force Loss: 2.0453, HI Loss: 0.0022
# Valid - Force Loss: 1.7193, HI Loss: 0.0016
# Valid Total Loss: 1.7193, Best: 1.1304
# 早停计数器: 267/500 (监控总验证损失)
#
# Epoch 591/1000, LR: 0.000328
# Train - Force Loss: 2.3971, HI Loss: 0.0029
# Valid - Force Loss: 1.6238, HI Loss: 0.0016
# Valid Total Loss: 1.6238, Best: 1.1304
# 早停计数器: 277/500 (监控总验证损失)
#
# Epoch 601/1000, LR: 0.000262
# Train - Force Loss: 2.2269, HI Loss: 0.0023
# Valid - Force Loss: 1.9510, HI Loss: 0.0014
# Valid Total Loss: 1.9510, Best: 1.1304
# 早停计数器: 287/500 (监控总验证损失)
#
# Epoch 611/1000, LR: 0.000262
# Train - Force Loss: 2.1510, HI Loss: 0.0024
# Valid - Force Loss: 2.0747, HI Loss: 0.0020
# Valid Total Loss: 2.0747, Best: 1.1304
# 早停计数器: 297/500 (监控总验证损失)
#
# Epoch 621/1000, LR: 0.000262
# Train - Force Loss: 2.2586, HI Loss: 0.0023
# Valid - Force Loss: 1.3768, HI Loss: 0.0015
# Valid Total Loss: 1.3768, Best: 1.1304
# 早停计数器: 307/500 (监控总验证损失)
#
# Epoch 631/1000, LR: 0.000262
# Train - Force Loss: 2.2343, HI Loss: 0.0024
# Valid - Force Loss: 1.5776, HI Loss: 0.0015
# Valid Total Loss: 1.5776, Best: 1.1304
# 早停计数器: 317/500 (监控总验证损失)
#
# Epoch 641/1000, LR: 0.000262
# Train - Force Loss: 2.5123, HI Loss: 0.0031
# Valid - Force Loss: 1.7205, HI Loss: 0.0026
# Valid Total Loss: 1.7205, Best: 1.1304
# 早停计数器: 327/500 (监控总验证损失)
#
# Epoch 651/1000, LR: 0.000262
# Train - Force Loss: 2.2367, HI Loss: 0.0025
# Valid - Force Loss: 1.4732, HI Loss: 0.0023
# Valid Total Loss: 1.4732, Best: 1.1304
# 早停计数器: 337/500 (监控总验证损失)
#
# Epoch 661/1000, LR: 0.000262
# Train - Force Loss: 1.8147, HI Loss: 0.0018
# Valid - Force Loss: 1.8566, HI Loss: 0.0029
# Valid Total Loss: 1.8566, Best: 1.1304
# 早停计数器: 347/500 (监控总验证损失)
#
# Epoch 671/1000, LR: 0.000262
# Train - Force Loss: 2.3690, HI Loss: 0.0027
# Valid - Force Loss: 1.3194, HI Loss: 0.0014
# Valid Total Loss: 1.3194, Best: 1.0687
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 681/1000, LR: 0.000262
# Train - Force Loss: 1.8162, HI Loss: 0.0019
# Valid - Force Loss: 1.5026, HI Loss: 0.0019
# Valid Total Loss: 1.5026, Best: 1.0687
# 早停计数器: 15/500 (监控总验证损失)
#
# Epoch 691/1000, LR: 0.000262
# Train - Force Loss: 2.2301, HI Loss: 0.0026
# Valid - Force Loss: 1.2565, HI Loss: 0.0015
# Valid Total Loss: 1.2565, Best: 1.0687
# 早停计数器: 25/500 (监控总验证损失)
#
# Epoch 701/1000, LR: 0.000210
# Train - Force Loss: 2.3763, HI Loss: 0.0025
# Valid - Force Loss: 1.5555, HI Loss: 0.0013
# Valid Total Loss: 1.5555, Best: 1.0687
# 早停计数器: 35/500 (监控总验证损失)
#
# Epoch 711/1000, LR: 0.000210
# Train - Force Loss: 1.7450, HI Loss: 0.0017
# Valid - Force Loss: 1.4614, HI Loss: 0.0017
# Valid Total Loss: 1.4614, Best: 1.0687
# 早停计数器: 45/500 (监控总验证损失)
#
# Epoch 721/1000, LR: 0.000210
# Train - Force Loss: 1.9232, HI Loss: 0.0022
# Valid - Force Loss: 1.4298, HI Loss: 0.0015
# Valid Total Loss: 1.4298, Best: 1.0687
# 早停计数器: 55/500 (监控总验证损失)
#
# Epoch 731/1000, LR: 0.000210
# Train - Force Loss: 2.0423, HI Loss: 0.0021
# Valid - Force Loss: 1.3007, HI Loss: 0.0014
# Valid Total Loss: 1.3007, Best: 1.0687
# 早停计数器: 65/500 (监控总验证损失)
#
# Epoch 741/1000, LR: 0.000210
# Train - Force Loss: 2.2344, HI Loss: 0.0023
# Valid - Force Loss: 1.6451, HI Loss: 0.0015
# Valid Total Loss: 1.6451, Best: 1.0687
# 早停计数器: 75/500 (监控总验证损失)
#
# Epoch 751/1000, LR: 0.000210
# Train - Force Loss: 2.2210, HI Loss: 0.0023
# Valid - Force Loss: 1.8646, HI Loss: 0.0014
# Valid Total Loss: 1.8646, Best: 1.0687
# 早停计数器: 85/500 (监控总验证损失)
#
# Epoch 761/1000, LR: 0.000210
# Train - Force Loss: 2.2958, HI Loss: 0.0024
# Valid - Force Loss: 1.4168, HI Loss: 0.0016
# Valid Total Loss: 1.4168, Best: 1.0687
# 早停计数器: 95/500 (监控总验证损失)
#
# Epoch 771/1000, LR: 0.000210
# Train - Force Loss: 1.8262, HI Loss: 0.0019
# Valid - Force Loss: 1.3602, HI Loss: 0.0014
# Valid Total Loss: 1.3602, Best: 1.0687
# 早停计数器: 105/500 (监控总验证损失)
#
# Epoch 781/1000, LR: 0.000210
# Train - Force Loss: 2.1764, HI Loss: 0.0026
# Valid - Force Loss: 1.4998, HI Loss: 0.0017
# Valid Total Loss: 1.4998, Best: 1.0687
# 早停计数器: 115/500 (监控总验证损失)
#
# Epoch 791/1000, LR: 0.000210
# Train - Force Loss: 1.8666, HI Loss: 0.0021
# Valid - Force Loss: 1.4238, HI Loss: 0.0015
# Valid Total Loss: 1.4238, Best: 1.0687
# 早停计数器: 125/500 (监控总验证损失)
#
# Epoch 801/1000, LR: 0.000168
# Train - Force Loss: 2.4145, HI Loss: 0.0024
# Valid - Force Loss: 1.5778, HI Loss: 0.0014
# Valid Total Loss: 1.5778, Best: 1.0687
# 早停计数器: 135/500 (监控总验证损失)
#
# Epoch 811/1000, LR: 0.000168
# Train - Force Loss: 1.7677, HI Loss: 0.0020
# Valid - Force Loss: 1.5196, HI Loss: 0.0020
# Valid Total Loss: 1.5196, Best: 1.0687
# 早停计数器: 145/500 (监控总验证损失)
#
# Epoch 821/1000, LR: 0.000168
# Train - Force Loss: 1.9208, HI Loss: 0.0022
# Valid - Force Loss: 1.9227, HI Loss: 0.0015
# Valid Total Loss: 1.9227, Best: 1.0687
# 早停计数器: 155/500 (监控总验证损失)
#
# Epoch 831/1000, LR: 0.000168
# Train - Force Loss: 1.8170, HI Loss: 0.0021
# Valid - Force Loss: 1.2685, HI Loss: 0.0015
# Valid Total Loss: 1.2685, Best: 1.0687
# 早停计数器: 165/500 (监控总验证损失)
#
# Epoch 841/1000, LR: 0.000168
# Train - Force Loss: 2.2779, HI Loss: 0.0024
# Valid - Force Loss: 1.5574, HI Loss: 0.0016
# Valid Total Loss: 1.5574, Best: 1.0687
# 早停计数器: 175/500 (监控总验证损失)
#
# Epoch 851/1000, LR: 0.000168
# Train - Force Loss: 2.1038, HI Loss: 0.0023
# Valid - Force Loss: 1.8569, HI Loss: 0.0017
# Valid Total Loss: 1.8569, Best: 1.0687
# 早停计数器: 185/500 (监控总验证损失)
#
# Epoch 861/1000, LR: 0.000168
# Train - Force Loss: 1.9731, HI Loss: 0.0021
# Valid - Force Loss: 1.1750, HI Loss: 0.0012
# Valid Total Loss: 1.1750, Best: 1.0687
# 早停计数器: 195/500 (监控总验证损失)
#
# Epoch 871/1000, LR: 0.000168
# Train - Force Loss: 1.7963, HI Loss: 0.0019
# Valid - Force Loss: 1.2596, HI Loss: 0.0015
# Valid Total Loss: 1.2596, Best: 1.0687
# 早停计数器: 205/500 (监控总验证损失)
#
# Epoch 881/1000, LR: 0.000168
# Train - Force Loss: 1.6680, HI Loss: 0.0017
# Valid - Force Loss: 1.2974, HI Loss: 0.0015
# Valid Total Loss: 1.2974, Best: 1.0687
# 早停计数器: 215/500 (监控总验证损失)
#
# Epoch 891/1000, LR: 0.000168
# Train - Force Loss: 2.2148, HI Loss: 0.0023
# Valid - Force Loss: 1.5671, HI Loss: 0.0017
# Valid Total Loss: 1.5671, Best: 1.0687
# 早停计数器: 225/500 (监控总验证损失)
#
# Epoch 901/1000, LR: 0.000134
# Train - Force Loss: 1.9084, HI Loss: 0.0020
# Valid - Force Loss: 1.3260, HI Loss: 0.0014
# Valid Total Loss: 1.3260, Best: 1.0687
# 早停计数器: 235/500 (监控总验证损失)
#
# Epoch 911/1000, LR: 0.000134
# Train - Force Loss: 2.2025, HI Loss: 0.0023
# Valid - Force Loss: 1.3210, HI Loss: 0.0014
# Valid Total Loss: 1.3210, Best: 1.0687
# 早停计数器: 245/500 (监控总验证损失)
#
# Epoch 921/1000, LR: 0.000134
# Train - Force Loss: 2.1323, HI Loss: 0.0024
# Valid - Force Loss: 1.3868, HI Loss: 0.0016
# Valid Total Loss: 1.3868, Best: 1.0687
# 早停计数器: 255/500 (监控总验证损失)
#
# Epoch 931/1000, LR: 0.000134
# Train - Force Loss: 2.0775, HI Loss: 0.0022
# Valid - Force Loss: 1.5608, HI Loss: 0.0014
# Valid Total Loss: 1.5608, Best: 1.0687
# 早停计数器: 265/500 (监控总验证损失)
#
# Epoch 941/1000, LR: 0.000134
# Train - Force Loss: 1.8247, HI Loss: 0.0019
# Valid - Force Loss: 1.4268, HI Loss: 0.0016
# Valid Total Loss: 1.4268, Best: 1.0687
# 早停计数器: 275/500 (监控总验证损失)
#
# Epoch 951/1000, LR: 0.000134
# Train - Force Loss: 1.7927, HI Loss: 0.0019
# Valid - Force Loss: 1.1571, HI Loss: 0.0013
# Valid Total Loss: 1.1571, Best: 1.0687
# 早停计数器: 285/500 (监控总验证损失)
#
# Epoch 961/1000, LR: 0.000134
# Train - Force Loss: 1.8089, HI Loss: 0.0019
# Valid - Force Loss: 1.4519, HI Loss: 0.0015
# Valid Total Loss: 1.4519, Best: 1.0687
# 早停计数器: 295/500 (监控总验证损失)
#
# Epoch 971/1000, LR: 0.000134
# Train - Force Loss: 1.7335, HI Loss: 0.0020
# Valid - Force Loss: 1.4565, HI Loss: 0.0014
# Valid Total Loss: 1.4565, Best: 1.0687
# 早停计数器: 305/500 (监控总验证损失)
#
# Epoch 981/1000, LR: 0.000134
# Train - Force Loss: 2.1081, HI Loss: 0.0022
# Valid - Force Loss: 1.4168, HI Loss: 0.0014
# Valid Total Loss: 1.4168, Best: 1.0687
# 早停计数器: 315/500 (监控总验证损失)
#
# Epoch 991/1000, LR: 0.000134
# Train - Force Loss: 1.9656, HI Loss: 0.0021
# Valid - Force Loss: 1.6204, HI Loss: 0.0012
# Valid Total Loss: 1.6204, Best: 1.0687
# 早停计数器: 325/500 (监控总验证损失)
#
# 训练完成，加载最佳模型（验证总损失: 1.0687)

# %%
torch.save(model, f'{Save_path}Inverse_Model_1.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
plt.style.use('default')
plt.figure(figsize=(12, 8)) # 创建Figure对象，并指定尺寸
plt.rcParams['font.family'] = ['Times New Roman']

# 设置x轴刻度
epoch = np.arange(0, len(train_loss_force), len(train_loss_force) // 10)
plt.xticks(epoch)

# 创建第一个y轴
ax1 = plt.gca()
ax1.plot(train_loss_force, 'r-', linewidth=2.5)
ax1.plot(train_loss_force, marker='o', markersize=5, color='red', linestyle='None', label='Training loss for PF')
ax1.plot(validation_loss_force, 'r-', linewidth=2.5)
ax1.plot(validation_loss_force, marker='*', markersize=5, color='red', linestyle='None', label='Validation loss for PF')

ax1.set_xlabel('Epoch', fontdict={'weight': 'normal', 'size': 20})
ax1.set_ylabel('Loss for PF', fontdict={'weight': 'normal', 'size': 20}, color='red')

ax1.tick_params(axis='y', labelcolor='red')
ax1.tick_params(axis='both', which='major',labelcolor='black', labelsize=15)

# 添加图例
ax1.legend(loc='upper left', fontsize=20)


max_val = max(
    max(train_loss_force),
    max(validation_loss_force)
)

ax1.set_ylim(0, max_val)

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None', label='Training loss for HI')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None', label='Validation loss for HI')

ax2.set_ylabel('Loss for HI', fontdict={'weight': 'normal', 'size': 20}, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major',labelcolor='blue', labelsize=15)

max_val = max(
    max(train_loss_HI),
    max(validation_loss_HI)
)

ax2.set_ylim(0, max_val)
ax2.legend(loc='upper right', fontsize=20)

# 创建放大图的子图（inset）
x1 = int(len(train_loss_force)*0.7)
x2 = int(len(train_loss_force))

ax_inset = plt.axes([0.45, 0.25, 0.4, 0.4])  # [left, bottom, width, height]
ax_inset.plot(train_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(train_loss_force, marker='o', markersize=8, color='red', linestyle='None')
ax_inset.plot(validation_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(validation_loss_force, marker='*', markersize=8, color='red', linestyle='None')

max_val = max(
    max(train_loss_force[x1:x2]),
    max(validation_loss_force[x1:x2])
)

ax_inset.set_xlim(x1, x2)
ax_inset.set_ylim(0, max_val)
ax_inset.tick_params(axis='both', which='major',  labelcolor='red',labelsize=15)

ax2 = ax_inset.twinx()

ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None')

max_val = max(
    max(train_loss_HI[x1:x2]),
    max(validation_loss_HI[x1:x2])
)

ax2.set_ylim(0, max_val)

ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major', labelsize=15)

# 保存图像
plt.savefig(f'{Save_path}Inverse_problem_Loss.jpg', dpi=600, bbox_inches='tight')
plt.show()
