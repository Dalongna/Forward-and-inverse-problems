# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import pywt
import torch.optim as optim
import glob
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

Main_path = 'D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'

Data_path = f'{Main_path}Data\\'
save_path = f'{Main_path}Model\\Python_code_FFT_Complex\\'
# Out:
# Using device: cuda:0

# %%
M = 9900
A = 1
data = []
labels = []

# 拿到数据路径，方便后续读取
dir_path = f'{Data_path}Prediction_signal_FFT_Complex'
# 获取目录及其子目录下所有CSV文件的路径
dataPaths = sorted(glob.glob(os.path.join(dir_path, '**', '*.csv'), recursive=True))
random.seed(42)
random.shuffle(dataPaths)

# 遍历读取数据
for dataPath in dataPaths:
    # 从文件名中提取x, y, z, j, k标签
    filename = os.path.basename(dataPath)
    parts = filename.split('_')
    # 假设文件名格式为 "x_y_z_j_k.csv"
    k = int(parts[-1].split('.')[0])  # 提取文件名中最后一个部分（k），并去掉.csv扩展名

    # 读取数据
    data_1 = pd.read_csv(dataPath)
    # 提取标签
    label1_force = parts[2]
    label2_HI = parts[3]
    label1 = float(label1_force)
    label2 = float(label2_HI)
    labels.append([label1, label2])

    # 检查第一列的每一行，找到第一个大于0的值的位置N
    for N in range(len(data_1)):
        if data_1.iloc[N, 1] != 0:
            break

    # 如果找到了大于0的值，则从第二列的第N行开始，往后取M个点
    if N < len(data_1) - M + 1:  # 确保N+M不会超出索引范围
        data.append(data_1.iloc[N:N+M, 1].values)

# 将数据和标签转换为numpy数组
all_datas = np.array(data, dtype="float")
all_labels = np.array(labels)

# 直接按照7:2:1的比例划分
# 首先分出训练集（70%）和临时集（30%）
train_datas, temp_datas, train_labels, temp_labels = train_test_split(
    all_datas, all_labels, test_size = 0.3, random_state=42
)

# 然后将临时集按照2:1的比例划分为验证集和测试集
# 2:1相当于验证集占2/3，测试集占1/3
validation_datas, test_datas, validation_labels, test_labels = train_test_split(
    temp_datas, temp_labels, test_size=2/3, random_state=42
)

# 输出数据集的形状以确认
print("训练集数据形状:", train_datas.shape)
print("验证集数据形状:", validation_datas.shape)
print("测试集数据形状:", test_datas.shape)
# Out:
# 训练集数据形状: (604, 9900)
# 验证集数据形状: (86, 9900)
# 测试集数据形状: (173, 9900)

# %%
train_datas = train_datas.reshape(-1,train_datas.shape[1],1)
validation_datas = validation_datas.reshape(-1,validation_datas.shape[1],1)

print(f'train_datas.shape:{train_datas.shape}')
print(f'validation_datas.shape:{validation_datas.shape}')
# Out:
# train_datas.shape:(604, 9900, 1)
# validation_datas.shape:(86, 9900, 1)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(train_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{save_path}Inverse_problem\\train_signal.jpg', dpi=600, bbox_inches='tight')

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(validation_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{save_path}Inverse_problem\\validation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
BATCH_SIZE = 32
input_size = M+39
hidden_size = 64
num_layers = 2
output_size = 2
learning_rate = 1e-3
EPOCH = 1000

# %%
# 准备数据
#torch.from_numpy将 NumPy 数组转换为 PyTorch 张量
#TensorDataset用于将张量数据和标签组合成一个数据集
#DataLoader用于从数据集中加载批次数据，并进行训练或测试

train_dataset = TensorDataset(torch.from_numpy(train_datas),torch.from_numpy(train_labels))
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset = TensorDataset(torch.from_numpy(validation_datas),torch.from_numpy(validation_labels))
validation_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ConvAutoencoderPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers,dropout_rate):
        super().__init__()

        # ---------- 卷积编码器 ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(input_size, hidden_size*4, 5, stride=2, padding=2),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.Conv1d(hidden_size*4, hidden_size*2, 3, stride=2, padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.Conv1d(hidden_size*2, hidden_size, 3, stride=1, padding=1),
            nn.BatchNorm1d(hidden_size), nn.ReLU(), nn.Dropout(dropout_rate),
        )

        # ---------- 卷积解码器 ----------
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(hidden_size, hidden_size*2, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.ConvTranspose1d(hidden_size*2, hidden_size*4, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),

            nn.ConvTranspose1d(hidden_size*4, input_size, 5, stride=1, padding=2),
        )

        # ---------- 2 层双向 LSTM ----------
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            bidirectional=True,
                            dropout=dropout_rate if 2 > 1 else 0,
                            batch_first=False)

        # ---------- 回归头 ----------
        self.regressor = nn.Linear(2 * hidden_size, output_size)   # output_size=2: [force, HI]

    # ------------- 前向 -------------
    def forward(self, x):
        # 小波分解（同你原来写法）
        coeffs = pywt.wavedec(x.cpu().numpy(), 'db4', level=6)
        x3 = torch.cat([torch.from_numpy(c).to(x.device) for c in coeffs], dim=-1)
        x6 = x3.permute(0, 2, 1)                      # [B, C, L]  C=input_size

        # 卷积自编码
        encoded = self.encoder(x6)
        decoded = self.decoder(encoded)               # [B, C, L]

        # 给 LSTM：把 L 放到第一维，通道当特征
        lstm_in = decoded.permute(2, 0, 1)            # [L, B, C]

        # 双向 LSTM 全部时间步输出
        lstm_out, _ = self.lstm(lstm_in)              # [L, B, 2*hidden_size]

        # 取最后一个时间步
        last_step = lstm_out[-1]                      # [B, 2*hidden_size]

        # 回归
        out = self.regressor(last_step)               # [B, 2]
        return out

# %%
#模型实例化
model = ConvAutoencoderPredictor(input_size, hidden_size, output_size, num_layers,dropout_rate = 0)
model.to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
#两个空列表用于存储训练和验证中的损失值
train_loss_force_epoch = []
train_loss_HI_epoch = []

#两个空列表用于存储训练和验证中的损失值
validation_loss_force_epoch = []
validation_loss_HI_epoch = []

# %%
def train_and_validate(model, train_loader, validation_loader, optimizer, loss, device, EPOCH, A, patience=500):
    """
    训练和验证模型的函数

    参数:
    model: 要训练的模型
    train_loader: 训练数据加载器
    validation_loader: 验证数据加载器
    optimizer: 优化器
    loss: 损失函数
    device: 运行设备（如 'cuda' 或 'cpu')
    EPOCH: 训练的总轮数
    A: HI 损失的权重系数
    patience: 早停的耐心值，即在多少个epoch内验证损失没有改善时停止训练
    """
    # 添加学习率调度器 - 每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用总验证损失作为监控指标
    best_val_total_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    # 记录各项损失
    train_loss_force_epoch = []
    train_loss_HI_epoch = []
    validation_loss_force_epoch = []
    validation_loss_HI_epoch = []
    
    # 记录各个指标的列表
    train_force_losses = []
    train_HI_losses = []
    val_force_losses = []
    val_HI_losses = []
    
    for epoch in range(EPOCH):
        # 训练步骤开始
        model.train()
        train_force_epoch = 0.0
        train_HI_epoch = 0.0
        train_force_batch = 0.0
        train_HI_batch = 0.0
        
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()

            x1 = x.type(torch.FloatTensor)
            x2 = x1.permute(0, 2, 1)

            force1 = y[:, 0].type(torch.FloatTensor)
            HI1 = y[:, 1].type(torch.FloatTensor)

            x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

            force_hat = model(x3)[:, 0]
            HI_hat = model(x3)[:, 1]

            train_loss_force = loss(force_hat.flatten(), force2.flatten())
            train_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

            train_loss_force.backward()
            train_loss_HI.backward()

            optimizer.step()

            train_force_epoch += train_loss_force.item() * x3.size(0)
            train_HI_epoch += train_loss_HI.item() * x3.size(0)
            train_force_batch += train_loss_force.item()
            train_HI_batch += train_loss_HI.item()

        # 更新学习率
        scheduler.step()
        
        # 计算平均训练损失
        train_mean_force = train_force_epoch / len(train_loader.dataset)
        train_loss_force_epoch.append(train_mean_force)
        train_force_losses.append(train_force_batch / len(train_loader))

        train_mean_HI = train_HI_epoch / len(train_loader.dataset)
        train_loss_HI_epoch.append(train_mean_HI)
        train_HI_losses.append(train_HI_batch / len(train_loader))

        # 验证步骤开始
        model.eval()
        validation_force_epoch = 0.0
        validation_HI_epoch = 0.0
        val_force_batch = 0.0
        val_HI_batch = 0.0

        with torch.no_grad():
            for i, (x, y) in enumerate(validation_loader):
                x1 = x.type(torch.FloatTensor)
                x2 = x1.permute(0, 2, 1)

                force1 = y[:, 0].type(torch.FloatTensor)
                HI1 = y[:, 1].type(torch.FloatTensor)

                x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

                force_hat = model(x3)[:, 0]
                HI_hat = model(x3)[:, 1]

                validation_loss_force = loss(force_hat.flatten(), force2.flatten())
                validation_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

                validation_force_epoch += validation_loss_force.item() * x3.size(0)
                validation_HI_epoch += validation_loss_HI.item() * x3.size(0)
                val_force_batch += validation_loss_force.item()
                val_HI_batch += validation_loss_HI.item()

        # 计算平均验证损失
        validation_mean_force = validation_force_epoch / len(validation_loader.dataset)
        validation_loss_force_epoch.append(validation_mean_force)
        val_force_losses.append(val_force_batch / len(validation_loader))

        validation_mean_HI = validation_HI_epoch / len(validation_loader.dataset)
        validation_loss_HI_epoch.append(validation_mean_HI)
        val_HI_losses.append(val_HI_batch / len(validation_loader))
        
        # 计算总验证损失用于早停监控
        total_val_loss = validation_mean_force

        # 早停检查 - 使用总验证损失作为监控指标
        if total_val_loss < best_val_total_loss:
            best_val_total_loss = total_val_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            # 仅在验证损失改善时打印信息
            if epoch % (EPOCH//100) == 0:
                print(f"Epoch {epoch+1}: 验证总损失改善 ({total_val_loss:.4f} -> {best_val_total_loss:.4f})，保存最佳模型")
        else:
            patience_counter += 1
            
            # 检查是否触发早停
            if patience_counter >= patience:
                print(f"\n早停触发！连续 {patience} 个epoch验证总损失未改善")
                print(f"最佳验证总损失: {best_val_total_loss:.4f} (epoch {epoch+1-patience})")
                break

        # 每10个epoch打印一次训练信息
        if epoch % (EPOCH//100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"\nEpoch {epoch+1}/{EPOCH}, LR: {current_lr:.6f}")
            print(f"Train - Force Loss: {train_mean_force:.4f}, HI Loss: {train_mean_HI:.4f}")
            print(f"Valid - Force Loss: {validation_mean_force:.4f}, HI Loss: {validation_mean_HI:.4f}")
            print(f"Valid Total Loss: {total_val_loss:.4f}, Best: {best_val_total_loss:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控总验证损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成，加载最佳模型（验证总损失: {best_val_total_loss:.4f})")
    else:
        print("\n训练完成，但未找到最佳模型")
    
    return train_force_losses, train_HI_losses, val_force_losses, val_HI_losses

# %%
# 假设你已经定义了模型、数据加载器、优化器、损失函数、设备等
train_loss_force, train_loss_HI, validation_loss_force, validation_loss_HI = train_and_validate(
    model=model,
    train_loader = train_loader,
    validation_loader = validation_loader,
    optimizer = optimizer,
    loss = loss,
    device = device,
    EPOCH = EPOCH,
    A = A,
    patience = 500  # 早停耐心值设为500个epoch
)
# Out:
# Epoch 1: 验证总损失改善 (72.6468 -> 72.6468)，保存最佳模型
#
# Epoch 1/1000, LR: 0.001000
# Train - Force Loss: 93.1471, HI Loss: 0.0589
# Valid - Force Loss: 72.6468, HI Loss: 0.0257
# Valid Total Loss: 72.6468, Best: 72.6468
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 11: 验证总损失改善 (5.1777 -> 5.1777)，保存最佳模型
#
# Epoch 11/1000, LR: 0.001000
# Train - Force Loss: 4.9269, HI Loss: 0.0053
# Valid - Force Loss: 5.1777, HI Loss: 0.0044
# Valid Total Loss: 5.1777, Best: 5.1777
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 21/1000, LR: 0.001000
# Train - Force Loss: 2.4719, HI Loss: 0.0038
# Valid - Force Loss: 1.8573, HI Loss: 0.0031
# Valid Total Loss: 1.8573, Best: 1.6365
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 31/1000, LR: 0.001000
# Train - Force Loss: 1.9482, HI Loss: 0.0039
# Valid - Force Loss: 2.0144, HI Loss: 0.0029
# Valid Total Loss: 2.0144, Best: 1.3564
# 早停计数器: 3/500 (监控总验证损失)
# Epoch 41: 验证总损失改善 (0.9856 -> 0.9856)，保存最佳模型
#
# Epoch 41/1000, LR: 0.001000
# Train - Force Loss: 1.6275, HI Loss: 0.0021
# Valid - Force Loss: 0.9856, HI Loss: 0.0015
# Valid Total Loss: 0.9856, Best: 0.9856
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 51/1000, LR: 0.001000
# Train - Force Loss: 1.4199, HI Loss: 0.0022
# Valid - Force Loss: 1.3487, HI Loss: 0.0024
# Valid Total Loss: 1.3487, Best: 0.9856
# 早停计数器: 10/500 (监控总验证损失)
#
# Epoch 61/1000, LR: 0.001000
# Train - Force Loss: 0.9925, HI Loss: 0.0017
# Valid - Force Loss: 1.0750, HI Loss: 0.0012
# Valid Total Loss: 1.0750, Best: 0.9856
# 早停计数器: 20/500 (监控总验证损失)
#
# Epoch 71/1000, LR: 0.001000
# Train - Force Loss: 1.8409, HI Loss: 0.0030
# Valid - Force Loss: 8.4468, HI Loss: 0.0145
# Valid Total Loss: 8.4468, Best: 0.9018
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 81/1000, LR: 0.001000
# Train - Force Loss: 1.3254, HI Loss: 0.0019
# Valid - Force Loss: 2.1330, HI Loss: 0.0051
# Valid Total Loss: 2.1330, Best: 0.8771
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 91/1000, LR: 0.001000
# Train - Force Loss: 1.4822, HI Loss: 0.0040
# Valid - Force Loss: 0.9443, HI Loss: 0.0032
# Valid Total Loss: 0.9443, Best: 0.8771
# 早停计数器: 17/500 (监控总验证损失)
#
# Epoch 101/1000, LR: 0.000800
# Train - Force Loss: 0.8908, HI Loss: 0.0014
# Valid - Force Loss: 1.0891, HI Loss: 0.0017
# Valid Total Loss: 1.0891, Best: 0.8440
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 111/1000, LR: 0.000800
# Train - Force Loss: 1.2704, HI Loss: 0.0014
# Valid - Force Loss: 0.8911, HI Loss: 0.0009
# Valid Total Loss: 0.8911, Best: 0.7541
# 早停计数器: 9/500 (监控总验证损失)
#
# Epoch 121/1000, LR: 0.000800
# Train - Force Loss: 1.0497, HI Loss: 0.0012
# Valid - Force Loss: 1.0462, HI Loss: 0.0018
# Valid Total Loss: 1.0462, Best: 0.7541
# 早停计数器: 19/500 (监控总验证损失)
#
# Epoch 131/1000, LR: 0.000800
# Train - Force Loss: 0.8576, HI Loss: 0.0012
# Valid - Force Loss: 0.8789, HI Loss: 0.0012
# Valid Total Loss: 0.8789, Best: 0.7541
# 早停计数器: 29/500 (监控总验证损失)
#
# Epoch 141/1000, LR: 0.000800
# Train - Force Loss: 0.8685, HI Loss: 0.0015
# Valid - Force Loss: 1.6752, HI Loss: 0.0023
# Valid Total Loss: 1.6752, Best: 0.7472
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 151/1000, LR: 0.000800
# Train - Force Loss: 0.7661, HI Loss: 0.0012
# Valid - Force Loss: 1.5364, HI Loss: 0.0015
# Valid Total Loss: 1.5364, Best: 0.7472
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 161/1000, LR: 0.000800
# Train - Force Loss: 1.0196, HI Loss: 0.0018
# Valid - Force Loss: 1.0718, HI Loss: 0.0012
# Valid Total Loss: 1.0718, Best: 0.7472
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 171/1000, LR: 0.000800
# Train - Force Loss: 0.8920, HI Loss: 0.0010
# Valid - Force Loss: 1.0916, HI Loss: 0.0016
# Valid Total Loss: 1.0916, Best: 0.7472
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 181/1000, LR: 0.000800
# Train - Force Loss: 0.7979, HI Loss: 0.0010
# Valid - Force Loss: 0.9280, HI Loss: 0.0011
# Valid Total Loss: 0.9280, Best: 0.6973
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 191/1000, LR: 0.000800
# Train - Force Loss: 0.9320, HI Loss: 0.0010
# Valid - Force Loss: 0.8599, HI Loss: 0.0013
# Valid Total Loss: 0.8599, Best: 0.6973
# 早停计数器: 12/500 (监控总验证损失)
#
# Epoch 201/1000, LR: 0.000640
# Train - Force Loss: 0.8287, HI Loss: 0.0010
# Valid - Force Loss: 0.7267, HI Loss: 0.0008
# Valid Total Loss: 0.7267, Best: 0.6973
# 早停计数器: 22/500 (监控总验证损失)
#
# Epoch 211/1000, LR: 0.000640
# Train - Force Loss: 0.8061, HI Loss: 0.0010
# Valid - Force Loss: 1.2876, HI Loss: 0.0014
# Valid Total Loss: 1.2876, Best: 0.6973
# 早停计数器: 32/500 (监控总验证损失)
#
# Epoch 221/1000, LR: 0.000640
# Train - Force Loss: 0.7568, HI Loss: 0.0010
# Valid - Force Loss: 0.7058, HI Loss: 0.0007
# Valid Total Loss: 0.7058, Best: 0.6924
# 早停计数器: 2/500 (监控总验证损失)
# Epoch 231: 验证总损失改善 (0.6147 -> 0.6147)，保存最佳模型
#
# Epoch 231/1000, LR: 0.000640
# Train - Force Loss: 0.6192, HI Loss: 0.0007
# Valid - Force Loss: 0.6147, HI Loss: 0.0007
# Valid Total Loss: 0.6147, Best: 0.6147
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 241/1000, LR: 0.000640
# Train - Force Loss: 0.6801, HI Loss: 0.0009
# Valid - Force Loss: 0.8891, HI Loss: 0.0009
# Valid Total Loss: 0.8891, Best: 0.6147
# 早停计数器: 10/500 (监控总验证损失)
#
# Epoch 251/1000, LR: 0.000640
# Train - Force Loss: 0.7318, HI Loss: 0.0009
# Valid - Force Loss: 0.8511, HI Loss: 0.0006
# Valid Total Loss: 0.8511, Best: 0.6147
# 早停计数器: 20/500 (监控总验证损失)
#
# Epoch 261/1000, LR: 0.000640
# Train - Force Loss: 0.7083, HI Loss: 0.0008
# Valid - Force Loss: 1.1399, HI Loss: 0.0012
# Valid Total Loss: 1.1399, Best: 0.6147
# 早停计数器: 30/500 (监控总验证损失)
# Epoch 271: 验证总损失改善 (0.5966 -> 0.5966)，保存最佳模型
#
# Epoch 271/1000, LR: 0.000640
# Train - Force Loss: 0.6766, HI Loss: 0.0008
# Valid - Force Loss: 0.5966, HI Loss: 0.0008
# Valid Total Loss: 0.5966, Best: 0.5966
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 281/1000, LR: 0.000640
# Train - Force Loss: 0.7833, HI Loss: 0.0010
# Valid - Force Loss: 0.8757, HI Loss: 0.0010
# Valid Total Loss: 0.8757, Best: 0.5966
# 早停计数器: 10/500 (监控总验证损失)
#
# Epoch 291/1000, LR: 0.000640
# Train - Force Loss: 0.5363, HI Loss: 0.0008
# Valid - Force Loss: 3.5774, HI Loss: 0.0020
# Valid Total Loss: 3.5774, Best: 0.5966
# 早停计数器: 20/500 (监控总验证损失)
#
# Epoch 301/1000, LR: 0.000512
# Train - Force Loss: 0.6510, HI Loss: 0.0007
# Valid - Force Loss: 0.6886, HI Loss: 0.0008
# Valid Total Loss: 0.6886, Best: 0.5966
# 早停计数器: 30/500 (监控总验证损失)
#
# Epoch 311/1000, LR: 0.000512
# Train - Force Loss: 0.6418, HI Loss: 0.0007
# Valid - Force Loss: 4.2206, HI Loss: 0.0046
# Valid Total Loss: 4.2206, Best: 0.5966
# 早停计数器: 40/500 (监控总验证损失)
#
# Epoch 321/1000, LR: 0.000512
# Train - Force Loss: 0.6069, HI Loss: 0.0008
# Valid - Force Loss: 0.5635, HI Loss: 0.0007
# Valid Total Loss: 0.5635, Best: 0.5176
# 早停计数器: 8/500 (监控总验证损失)
#
# Epoch 331/1000, LR: 0.000512
# Train - Force Loss: 1.1533, HI Loss: 0.0012
# Valid - Force Loss: 1.2028, HI Loss: 0.0015
# Valid Total Loss: 1.2028, Best: 0.5176
# 早停计数器: 18/500 (监控总验证损失)
#
# Epoch 341/1000, LR: 0.000512
# Train - Force Loss: 0.6017, HI Loss: 0.0009
# Valid - Force Loss: 0.6567, HI Loss: 0.0006
# Valid Total Loss: 0.6567, Best: 0.4870
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 351/1000, LR: 0.000512
# Train - Force Loss: 0.6296, HI Loss: 0.0009
# Valid - Force Loss: 0.6690, HI Loss: 0.0007
# Valid Total Loss: 0.6690, Best: 0.4870
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 361/1000, LR: 0.000512
# Train - Force Loss: 0.5349, HI Loss: 0.0006
# Valid - Force Loss: 1.6954, HI Loss: 0.0016
# Valid Total Loss: 1.6954, Best: 0.4870
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 371/1000, LR: 0.000512
# Train - Force Loss: 0.7743, HI Loss: 0.0013
# Valid - Force Loss: 0.6913, HI Loss: 0.0007
# Valid Total Loss: 0.6913, Best: 0.4870
# 早停计数器: 31/500 (监控总验证损失)
#
# Epoch 381/1000, LR: 0.000512
# Train - Force Loss: 0.7501, HI Loss: 0.0010
# Valid - Force Loss: 0.7574, HI Loss: 0.0008
# Valid Total Loss: 0.7574, Best: 0.4870
# 早停计数器: 41/500 (监控总验证损失)
#
# Epoch 391/1000, LR: 0.000512
# Train - Force Loss: 0.5403, HI Loss: 0.0007
# Valid - Force Loss: 0.6612, HI Loss: 0.0006
# Valid Total Loss: 0.6612, Best: 0.4870
# 早停计数器: 51/500 (监控总验证损失)
#
# Epoch 401/1000, LR: 0.000410
# Train - Force Loss: 0.6646, HI Loss: 0.0007
# Valid - Force Loss: 0.5979, HI Loss: 0.0006
# Valid Total Loss: 0.5979, Best: 0.4870
# 早停计数器: 61/500 (监控总验证损失)
#
# Epoch 411/1000, LR: 0.000410
# Train - Force Loss: 0.5280, HI Loss: 0.0006
# Valid - Force Loss: 0.6290, HI Loss: 0.0006
# Valid Total Loss: 0.6290, Best: 0.4681
# 早停计数器: 7/500 (监控总验证损失)
# Epoch 421: 验证总损失改善 (0.4338 -> 0.4338)，保存最佳模型
#
# Epoch 421/1000, LR: 0.000410
# Train - Force Loss: 0.3750, HI Loss: 0.0004
# Valid - Force Loss: 0.4338, HI Loss: 0.0004
# Valid Total Loss: 0.4338, Best: 0.4338
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 431/1000, LR: 0.000410
# Train - Force Loss: 0.3397, HI Loss: 0.0004
# Valid - Force Loss: 2.1179, HI Loss: 0.0022
# Valid Total Loss: 2.1179, Best: 0.3565
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 441/1000, LR: 0.000410
# Train - Force Loss: 0.3029, HI Loss: 0.0003
# Valid - Force Loss: 1.8941, HI Loss: 0.0018
# Valid Total Loss: 1.8941, Best: 0.3051
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 451/1000, LR: 0.000410
# Train - Force Loss: 0.6542, HI Loss: 0.0009
# Valid - Force Loss: 0.5294, HI Loss: 0.0006
# Valid Total Loss: 0.5294, Best: 0.2322
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 461/1000, LR: 0.000410
# Train - Force Loss: 0.4637, HI Loss: 0.0005
# Valid - Force Loss: 0.6048, HI Loss: 0.0006
# Valid Total Loss: 0.6048, Best: 0.2322
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 471/1000, LR: 0.000410
# Train - Force Loss: 0.3395, HI Loss: 0.0004
# Valid - Force Loss: 0.4403, HI Loss: 0.0005
# Valid Total Loss: 0.4403, Best: 0.2322
# 早停计数器: 23/500 (监控总验证损失)
#
# Epoch 481/1000, LR: 0.000410
# Train - Force Loss: 0.5817, HI Loss: 0.0008
# Valid - Force Loss: 1.2912, HI Loss: 0.0007
# Valid Total Loss: 1.2912, Best: 0.2322
# 早停计数器: 33/500 (监控总验证损失)
#
# Epoch 491/1000, LR: 0.000410
# Train - Force Loss: 0.3714, HI Loss: 0.0004
# Valid - Force Loss: 0.2996, HI Loss: 0.0003
# Valid Total Loss: 0.2996, Best: 0.2322
# 早停计数器: 43/500 (监控总验证损失)
#
# Epoch 501/1000, LR: 0.000328
# Train - Force Loss: 0.2804, HI Loss: 0.0004
# Valid - Force Loss: 0.2675, HI Loss: 0.0003
# Valid Total Loss: 0.2675, Best: 0.2322
# 早停计数器: 53/500 (监控总验证损失)
#
# Epoch 511/1000, LR: 0.000328
# Train - Force Loss: 0.3496, HI Loss: 0.0004
# Valid - Force Loss: 0.3916, HI Loss: 0.0004
# Valid Total Loss: 0.3916, Best: 0.1746
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 521/1000, LR: 0.000328
# Train - Force Loss: 0.3163, HI Loss: 0.0004
# Valid - Force Loss: 0.3673, HI Loss: 0.0004
# Valid Total Loss: 0.3673, Best: 0.1746
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 531/1000, LR: 0.000328
# Train - Force Loss: 0.2357, HI Loss: 0.0003
# Valid - Force Loss: 0.4653, HI Loss: 0.0004
# Valid Total Loss: 0.4653, Best: 0.0917
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 541/1000, LR: 0.000328
# Train - Force Loss: 0.3106, HI Loss: 0.0004
# Valid - Force Loss: 0.4750, HI Loss: 0.0004
# Valid Total Loss: 0.4750, Best: 0.0785
# 早停计数器: 9/500 (监控总验证损失)
#
# Epoch 551/1000, LR: 0.000328
# Train - Force Loss: 0.2249, HI Loss: 0.0003
# Valid - Force Loss: 0.2334, HI Loss: 0.0003
# Valid Total Loss: 0.2334, Best: 0.0785
# 早停计数器: 19/500 (监控总验证损失)
#
# Epoch 561/1000, LR: 0.000328
# Train - Force Loss: 0.4134, HI Loss: 0.0006
# Valid - Force Loss: 0.3854, HI Loss: 0.0006
# Valid Total Loss: 0.3854, Best: 0.0785
# 早停计数器: 29/500 (监控总验证损失)
#
# Epoch 571/1000, LR: 0.000328
# Train - Force Loss: 0.2232, HI Loss: 0.0003
# Valid - Force Loss: 0.1650, HI Loss: 0.0002
# Valid Total Loss: 0.1650, Best: 0.0785
# 早停计数器: 39/500 (监控总验证损失)
#
# Epoch 581/1000, LR: 0.000328
# Train - Force Loss: 0.3445, HI Loss: 0.0004
# Valid - Force Loss: 0.2775, HI Loss: 0.0004
# Valid Total Loss: 0.2775, Best: 0.0785
# 早停计数器: 49/500 (监控总验证损失)
#
# Epoch 591/1000, LR: 0.000328
# Train - Force Loss: 0.2065, HI Loss: 0.0002
# Valid - Force Loss: 0.4840, HI Loss: 0.0003
# Valid Total Loss: 0.4840, Best: 0.0785
# 早停计数器: 59/500 (监控总验证损失)
#
# Epoch 601/1000, LR: 0.000262
# Train - Force Loss: 0.2373, HI Loss: 0.0003
# Valid - Force Loss: 0.1531, HI Loss: 0.0002
# Valid Total Loss: 0.1531, Best: 0.0785
# 早停计数器: 69/500 (监控总验证损失)
# Epoch 611: 验证总损失改善 (0.0741 -> 0.0741)，保存最佳模型
#
# Epoch 611/1000, LR: 0.000262
# Train - Force Loss: 0.1568, HI Loss: 0.0002
# Valid - Force Loss: 0.0741, HI Loss: 0.0001
# Valid Total Loss: 0.0741, Best: 0.0741
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 621/1000, LR: 0.000262
# Train - Force Loss: 0.1800, HI Loss: 0.0003
# Valid - Force Loss: 0.3221, HI Loss: 0.0003
# Valid Total Loss: 0.3221, Best: 0.0741
# 早停计数器: 10/500 (监控总验证损失)
#
# Epoch 631/1000, LR: 0.000262
# Train - Force Loss: 0.2418, HI Loss: 0.0003
# Valid - Force Loss: 0.1059, HI Loss: 0.0001
# Valid Total Loss: 0.1059, Best: 0.0741
# 早停计数器: 20/500 (监控总验证损失)
#
# Epoch 641/1000, LR: 0.000262
# Train - Force Loss: 0.1780, HI Loss: 0.0002
# Valid - Force Loss: 0.4000, HI Loss: 0.0002
# Valid Total Loss: 0.4000, Best: 0.0741
# 早停计数器: 30/500 (监控总验证损失)
#
# Epoch 651/1000, LR: 0.000262
# Train - Force Loss: 0.2211, HI Loss: 0.0003
# Valid - Force Loss: 0.8816, HI Loss: 0.0013
# Valid Total Loss: 0.8816, Best: 0.0741
# 早停计数器: 40/500 (监控总验证损失)
#
# Epoch 661/1000, LR: 0.000262
# Train - Force Loss: 0.1880, HI Loss: 0.0002
# Valid - Force Loss: 0.2523, HI Loss: 0.0002
# Valid Total Loss: 0.2523, Best: 0.0741
# 早停计数器: 50/500 (监控总验证损失)
#
# Epoch 671/1000, LR: 0.000262
# Train - Force Loss: 0.1372, HI Loss: 0.0002
# Valid - Force Loss: 0.7728, HI Loss: 0.0006
# Valid Total Loss: 0.7728, Best: 0.0711
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 681/1000, LR: 0.000262
# Train - Force Loss: 0.0929, HI Loss: 0.0001
# Valid - Force Loss: 0.1704, HI Loss: 0.0002
# Valid Total Loss: 0.1704, Best: 0.0711
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 691/1000, LR: 0.000262
# Train - Force Loss: 0.1819, HI Loss: 0.0002
# Valid - Force Loss: 0.7133, HI Loss: 0.0005
# Valid Total Loss: 0.7133, Best: 0.0711
# 早停计数器: 23/500 (监控总验证损失)
#
# Epoch 701/1000, LR: 0.000210
# Train - Force Loss: 0.1588, HI Loss: 0.0002
# Valid - Force Loss: 0.1852, HI Loss: 0.0002
# Valid Total Loss: 0.1852, Best: 0.0700
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 711/1000, LR: 0.000210
# Train - Force Loss: 0.1491, HI Loss: 0.0002
# Valid - Force Loss: 0.2532, HI Loss: 0.0003
# Valid Total Loss: 0.2532, Best: 0.0700
# 早停计数器: 12/500 (监控总验证损失)
#
# Epoch 721/1000, LR: 0.000210
# Train - Force Loss: 0.1107, HI Loss: 0.0002
# Valid - Force Loss: 0.0717, HI Loss: 0.0002
# Valid Total Loss: 0.0717, Best: 0.0550
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 731/1000, LR: 0.000210
# Train - Force Loss: 0.7818, HI Loss: 0.0008
# Valid - Force Loss: 6.5233, HI Loss: 0.0042
# Valid Total Loss: 6.5233, Best: 0.0396
# 早停计数器: 4/500 (监控总验证损失)
#
# Epoch 741/1000, LR: 0.000210
# Train - Force Loss: 0.1837, HI Loss: 0.0002
# Valid - Force Loss: 0.2668, HI Loss: 0.0003
# Valid Total Loss: 0.2668, Best: 0.0396
# 早停计数器: 14/500 (监控总验证损失)
#
# Epoch 751/1000, LR: 0.000210
# Train - Force Loss: 0.0948, HI Loss: 0.0001
# Valid - Force Loss: 0.0687, HI Loss: 0.0001
# Valid Total Loss: 0.0687, Best: 0.0396
# 早停计数器: 24/500 (监控总验证损失)
#
# Epoch 761/1000, LR: 0.000210
# Train - Force Loss: 0.1011, HI Loss: 0.0001
# Valid - Force Loss: 0.0643, HI Loss: 0.0001
# Valid Total Loss: 0.0643, Best: 0.0396
# 早停计数器: 34/500 (监控总验证损失)
#
# Epoch 771/1000, LR: 0.000210
# Train - Force Loss: 0.0759, HI Loss: 0.0001
# Valid - Force Loss: 0.0825, HI Loss: 0.0001
# Valid Total Loss: 0.0825, Best: 0.0396
# 早停计数器: 44/500 (监控总验证损失)
#
# Epoch 781/1000, LR: 0.000210
# Train - Force Loss: 0.0955, HI Loss: 0.0001
# Valid - Force Loss: 0.0591, HI Loss: 0.0001
# Valid Total Loss: 0.0591, Best: 0.0396
# 早停计数器: 54/500 (监控总验证损失)
#
# Epoch 791/1000, LR: 0.000210
# Train - Force Loss: 0.1073, HI Loss: 0.0001
# Valid - Force Loss: 0.2731, HI Loss: 0.0003
# Valid Total Loss: 0.2731, Best: 0.0396
# 早停计数器: 64/500 (监控总验证损失)
#
# Epoch 801/1000, LR: 0.000168
# Train - Force Loss: 0.1417, HI Loss: 0.0002
# Valid - Force Loss: 0.0786, HI Loss: 0.0002
# Valid Total Loss: 0.0786, Best: 0.0396
# 早停计数器: 74/500 (监控总验证损失)
#
# Epoch 811/1000, LR: 0.000168
# Train - Force Loss: 0.0959, HI Loss: 0.0001
# Valid - Force Loss: 0.2122, HI Loss: 0.0002
# Valid Total Loss: 0.2122, Best: 0.0396
# 早停计数器: 84/500 (监控总验证损失)
#
# Epoch 821/1000, LR: 0.000168
# Train - Force Loss: 0.0900, HI Loss: 0.0001
# Valid - Force Loss: 0.0739, HI Loss: 0.0001
# Valid Total Loss: 0.0739, Best: 0.0396
# 早停计数器: 94/500 (监控总验证损失)
#
# Epoch 831/1000, LR: 0.000168
# Train - Force Loss: 0.1072, HI Loss: 0.0001
# Valid - Force Loss: 0.2811, HI Loss: 0.0004
# Valid Total Loss: 0.2811, Best: 0.0396
# 早停计数器: 104/500 (监控总验证损失)
#
# Epoch 841/1000, LR: 0.000168
# Train - Force Loss: 0.1232, HI Loss: 0.0002
# Valid - Force Loss: 0.0930, HI Loss: 0.0001
# Valid Total Loss: 0.0930, Best: 0.0396
# 早停计数器: 114/500 (监控总验证损失)
#
# Epoch 851/1000, LR: 0.000168
# Train - Force Loss: 0.1318, HI Loss: 0.0002
# Valid - Force Loss: 0.0881, HI Loss: 0.0001
# Valid Total Loss: 0.0881, Best: 0.0396
# 早停计数器: 124/500 (监控总验证损失)
#
# Epoch 861/1000, LR: 0.000168
# Train - Force Loss: 0.1045, HI Loss: 0.0001
# Valid - Force Loss: 0.0739, HI Loss: 0.0001
# Valid Total Loss: 0.0739, Best: 0.0396
# 早停计数器: 134/500 (监控总验证损失)
#
# Epoch 871/1000, LR: 0.000168
# Train - Force Loss: 0.0916, HI Loss: 0.0001
# Valid - Force Loss: 0.1733, HI Loss: 0.0002
# Valid Total Loss: 0.1733, Best: 0.0283
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 881/1000, LR: 0.000168
# Train - Force Loss: 0.1204, HI Loss: 0.0002
# Valid - Force Loss: 0.0820, HI Loss: 0.0001
# Valid Total Loss: 0.0820, Best: 0.0283
# 早停计数器: 15/500 (监控总验证损失)
#
# Epoch 891/1000, LR: 0.000168
# Train - Force Loss: 0.1120, HI Loss: 0.0002
# Valid - Force Loss: 0.0644, HI Loss: 0.0001
# Valid Total Loss: 0.0644, Best: 0.0283
# 早停计数器: 25/500 (监控总验证损失)
#
# Epoch 901/1000, LR: 0.000134
# Train - Force Loss: 0.0932, HI Loss: 0.0002
# Valid - Force Loss: 0.1553, HI Loss: 0.0002
# Valid Total Loss: 0.1553, Best: 0.0283
# 早停计数器: 35/500 (监控总验证损失)
#
# Epoch 911/1000, LR: 0.000134
# Train - Force Loss: 0.0698, HI Loss: 0.0001
# Valid - Force Loss: 0.0468, HI Loss: 0.0001
# Valid Total Loss: 0.0468, Best: 0.0270
# 早停计数器: 9/500 (监控总验证损失)
#
# Epoch 921/1000, LR: 0.000134
# Train - Force Loss: 0.1078, HI Loss: 0.0002
# Valid - Force Loss: 0.9570, HI Loss: 0.0012
# Valid Total Loss: 0.9570, Best: 0.0270
# 早停计数器: 19/500 (监控总验证损失)
#
# Epoch 931/1000, LR: 0.000134
# Train - Force Loss: 0.0719, HI Loss: 0.0001
# Valid - Force Loss: 0.0361, HI Loss: 0.0001
# Valid Total Loss: 0.0361, Best: 0.0270
# 早停计数器: 29/500 (监控总验证损失)
#
# Epoch 941/1000, LR: 0.000134
# Train - Force Loss: 0.0661, HI Loss: 0.0001
# Valid - Force Loss: 0.0317, HI Loss: 0.0001
# Valid Total Loss: 0.0317, Best: 0.0207
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 951/1000, LR: 0.000134
# Train - Force Loss: 0.0864, HI Loss: 0.0001
# Valid - Force Loss: 0.0369, HI Loss: 0.0001
# Valid Total Loss: 0.0369, Best: 0.0207
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 961/1000, LR: 0.000134
# Train - Force Loss: 0.0976, HI Loss: 0.0001
# Valid - Force Loss: 0.0294, HI Loss: 0.0001
# Valid Total Loss: 0.0294, Best: 0.0207
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 971/1000, LR: 0.000134
# Train - Force Loss: 0.0647, HI Loss: 0.0001
# Valid - Force Loss: 0.0260, HI Loss: 0.0001
# Valid Total Loss: 0.0260, Best: 0.0206
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 981/1000, LR: 0.000134
# Train - Force Loss: 0.0732, HI Loss: 0.0001
# Valid - Force Loss: 0.0656, HI Loss: 0.0001
# Valid Total Loss: 0.0656, Best: 0.0147
# 早停计数器: 2/500 (监控总验证损失)
#
# Epoch 991/1000, LR: 0.000134
# Train - Force Loss: 0.0674, HI Loss: 0.0001
# Valid - Force Loss: 0.0525, HI Loss: 0.0001
# Valid Total Loss: 0.0525, Best: 0.0147
# 早停计数器: 12/500 (监控总验证损失)
#
# 训练完成，加载最佳模型（验证总损失: 0.0147)

# %%
torch.save(model, f'{save_path}Inverse_problem\\Inverse_Model_FFT_Complex_prediction_signal.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
plt.style.use('default')
plt.figure(figsize=(12, 8)) # 创建Figure对象，并指定尺寸
plt.rcParams['font.family'] = ['Times New Roman']

# 设置x轴刻度
epoch = np.arange(0, len(train_loss_force), len(train_loss_force) // 10)
plt.xticks(epoch)

# 创建第一个y轴
ax1 = plt.gca()
ax1.plot(train_loss_force, 'r-', linewidth=2.5)
ax1.plot(train_loss_force, marker='o', markersize=5, color='red', linestyle='None', label='Training loss for PF')
ax1.plot(validation_loss_force, 'r-', linewidth=2.5)
ax1.plot(validation_loss_force, marker='*', markersize=5, color='red', linestyle='None', label='Validation loss for PF')

ax1.set_xlabel('Epoch', fontdict={'weight': 'normal', 'size': 20})
ax1.set_ylabel('Loss for PF', fontdict={'weight': 'normal', 'size': 20}, color='red')

ax1.tick_params(axis='y', labelcolor='red')
ax1.tick_params(axis='both', which='major',labelcolor='black', labelsize=15)

# 添加图例
ax1.legend(loc='upper left', fontsize=20)


max_val_force = max(
    max(train_loss_force),
    max(validation_loss_force)
)

ax1.set_ylim(0, max_val_force)

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None', label='Training loss for HI')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None', label='Validation loss for HI')

ax2.set_ylabel('Loss for HI', fontdict={'weight': 'normal', 'size': 20}, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major',labelcolor='blue', labelsize=15)

max_val_HI = max(
    max(train_loss_HI),
    max(validation_loss_HI)
)

ax2.set_ylim(0, max_val_HI)
ax2.legend(loc='upper right', fontsize=20)

# 创建放大图的子图（inset）
x1 = int(len(train_loss_force)*0.7)
x2 = int(len(train_loss_force))

ax_inset = plt.axes([0.4, 0.25, 0.4, 0.4])  # [left, bottom, width, height]
ax_inset.plot(train_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(train_loss_force, marker='o', markersize=8, color='red', linestyle='None')
ax_inset.plot(validation_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(validation_loss_force, marker='*', markersize=8, color='red', linestyle='None')

max_val_force = max(
    max(train_loss_force[x1:x2]),
    max(validation_loss_force[x1:x2])
)

ax_inset.set_xlim(x1, x2)
ax_inset.set_ylim(0, max_val_force)
ax_inset.tick_params(axis='both', which='major',  labelcolor='red',labelsize=15)

ax2 = ax_inset.twinx()

ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None')

max_val_HI = max(
    max(train_loss_HI[x1:x2]),
    max(validation_loss_HI[x1:x2])
)

ax2.set_ylim(0, max_val_HI)

ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major', labelsize=15)

# 保存图像
plt.savefig(f'{save_path}Inverse_problem\\Inverse_Loss_using_prediciton_signal.jpg', dpi=600, bbox_inches='tight')
plt.show()
