# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import pywt
import torch.optim as optim
import glob
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

Main_path = 'D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'
Data_path = f'{Main_path}Data\\'
Save_path = f'{Main_path}Nonlinear_verification\\Python_nonlinear_verification3\\'
# Out:
# Using device: cuda:0

# %%
M = 9900
A = 1
data = []
labels = []
skipped_files = []  # 记录跳过的文件

# 拿到数据路径，方便后续读取
dir_path = f'{Data_path}Experiment_signal'
dataPaths = sorted(glob.glob(os.path.join(dir_path, '**', '*.csv'), recursive=True))
random.seed(42)
random.shuffle(dataPaths)

# 遍历读取数据
for dataPath in dataPaths:
    # 读取数据（先读取，后验证）
    data_1 = pd.read_csv(dataPath)
    
    # 检查第一列的每一行，找到第一个大于0的值的位置N
    N = 0
    for i in range(len(data_1)):
        if data_1.iloc[i, 1] != 0:
            N = i
            break
    
    # 【关键修复】先验证数据长度，不够就跳过整个文件
    if N >= len(data_1) - M + 1:
        filename = os.path.basename(dataPath)
        print(f"警告：跳过 {filename} - 数据不足(可用{len(data_1)-N}点，需要{M}点)")
        skipped_files.append(filename)
        continue  # 跳过这个文件，data和labels都不添加
    
    # 只有数据足够时，才提取数据和标签
    data.append(data_1.iloc[N:N+M, 1].values)
    
    # 提取标签（移到验证之后）
    filename = os.path.basename(dataPath)
    parts = filename.split('_')
    label1 = float(parts[2])
    label2 = float(parts[3])
    labels.append([label1, label2])

print(f"\n处理完成：成功{len(data)}个，跳过{len(skipped_files)}个")

# 转换为numpy数组
all_datas = np.array(data, dtype="float")
all_labels = np.array(labels)

# 划分数据集（现在不会报错了）
train_datas, temp_datas, train_labels, temp_labels = train_test_split(
    all_datas, all_labels, test_size=0.3, random_state=42
)

validation_datas, test_datas, validation_labels, test_labels = train_test_split(
    temp_datas, temp_labels, test_size=2/3, random_state=42
)

print("训练集数据形状:", train_datas.shape)
print("验证集数据形状:", validation_datas.shape)
print("测试集数据形状:", test_datas.shape)
# Out:
# 处理完成：成功864个，跳过0个
# 训练集数据形状: (604, 9900)
# 验证集数据形状: (86, 9900)
# 测试集数据形状: (174, 9900)

# %%
train_datas = train_datas.reshape(-1,train_datas.shape[1],1)
validation_datas = validation_datas.reshape(-1,validation_datas.shape[1],1)

print(f'train_datas.shape:{train_datas.shape}')
print(f'validation_datas.shape:{validation_datas.shape}')
# Out:
# train_datas.shape:(604, 9900, 1)
# validation_datas.shape:(86, 9900, 1)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(train_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}train_signal.jpg', dpi=600, bbox_inches='tight')

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(validation_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}validation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
BATCH_SIZE = 32
input_size = 1243
hidden_size = 64
num_layers = 2
output_size = 2
EPOCH = 1000
learning_rate = 1e-3

# %%
# 准备数据
#torch.from_numpy将 NumPy 数组转换为 PyTorch 张量
#TensorDataset用于将张量数据和标签组合成一个数据集
#DataLoader用于从数据集中加载批次数据，并进行训练或测试

train_dataset = TensorDataset(torch.from_numpy(train_datas),torch.from_numpy(train_labels))
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset = TensorDataset(torch.from_numpy(validation_datas),torch.from_numpy(validation_labels))
validation_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ConvAutoencoderPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout_rate):
        super().__init__()
        self.input_size = input_size
        self.device = device
        
        # ---------- 卷积编码器 ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(input_size, hidden_size*4, 5, stride=2, padding=2),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Conv1d(hidden_size*4, hidden_size*2, 3, stride=2, padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Conv1d(hidden_size*2, hidden_size, 3, stride=1, padding=1),
            nn.BatchNorm1d(hidden_size), nn.ReLU(), nn.Dropout(dropout_rate),
        )

        # ---------- 卷积解码器 ----------
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(hidden_size, hidden_size*2, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(hidden_size*2, hidden_size*4, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(hidden_size*4, input_size, 5, stride=1, padding=2),
        )

        # ---------- 2 层双向 LSTM ----------
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            bidirectional=True,
                            dropout=dropout_rate if num_layers > 1 else 0,
                            batch_first=False)
        
        self.dropout_layer = nn.Dropout(dropout_rate)
        self.regressor = nn.Linear(2 * hidden_size, output_size)

    def forward(self, x):
        wavelet = 'db4'
        # 将张量移动至CPU上面
        x1 = x.cpu()

        # 将CPU张量转化为numpy
        x2 = x1.numpy()
        # 离散小波分解
        coeffs = pywt.wavedec(x2, wavelet, level=6)
        xh1 = coeffs[6]
        xh2 = coeffs[5]
        xh3 = coeffs[4]
        xh4 = coeffs[3]
        xh5 = coeffs[2]
        xh6 = coeffs[1]
        xl6 = coeffs[0]
        # 连接分解后的序列
        x3 =  xh3

        x4 = torch.from_numpy(x3)
        x5 = x4.to(device)
        
        x_conv = x5.permute(0, 2, 1)
        encoded = self.encoder(x_conv)
        decoded = self.decoder(encoded)

        out = decoded.view(decoded.size(0), -1)
        out = out.view(out.size(0), -1, self.input_size)

        lstm_out, _ = self.lstm(out) 
        lstm_out = lstm_out[:, -1, :]

        out = self.dropout_layer(lstm_out)
        out = self.regressor(out)  
        return out

# %%
#模型实例化
model = ConvAutoencoderPredictor(input_size, hidden_size, output_size, num_layers,dropout_rate=0.0)
model.to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
#两个空列表用于存储训练和验证中的损失值
train_loss_force_epoch = []
train_loss_HI_epoch = []

#两个空列表用于存储训练和验证中的损失值
validation_loss_force_epoch = []
validation_loss_HI_epoch = []

# %%
def train_and_validate(model, train_loader, validation_loader, optimizer, loss, device, EPOCH, A, patience=500):
    """
    训练和验证模型的函数

    参数:
    model: 要训练的模型
    train_loader: 训练数据加载器
    validation_loader: 验证数据加载器
    optimizer: 优化器
    loss: 损失函数
    device: 运行设备（如 'cuda' 或 'cpu')
    EPOCH: 训练的总轮数
    A: HI 损失的权重系数
    patience: 早停的耐心值，即在多少个epoch内验证损失没有改善时停止训练
    """
    # 添加学习率调度器 - 每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用总验证损失作为监控指标
    best_val_total_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    # 记录各项损失
    train_loss_force_epoch = []
    train_loss_HI_epoch = []
    validation_loss_force_epoch = []
    validation_loss_HI_epoch = []
    
    # 记录各个指标的列表
    train_force_losses = []
    train_HI_losses = []
    val_force_losses = []
    val_HI_losses = []
    
    for epoch in range(EPOCH):
        # 训练步骤开始
        model.train()
        train_force_epoch = 0.0
        train_HI_epoch = 0.0
        train_force_batch = 0.0
        train_HI_batch = 0.0
        
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()

            x1 = x.type(torch.FloatTensor)
            x2 = x1.permute(0, 2, 1)

            force1 = y[:, 0].type(torch.FloatTensor)
            HI1 = y[:, 1].type(torch.FloatTensor)

            x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

            force_hat = model(x3)[:, 0]
            HI_hat = model(x3)[:, 1]

            train_loss_force = loss(force_hat.flatten(), force2.flatten())
            train_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

            train_loss_force.backward()
            train_loss_HI.backward()

            optimizer.step()

            train_force_epoch += train_loss_force.item() * x3.size(0)
            train_HI_epoch += train_loss_HI.item() * x3.size(0)
            train_force_batch += train_loss_force.item()
            train_HI_batch += train_loss_HI.item()

        # 更新学习率
        scheduler.step()
        
        # 计算平均训练损失
        train_mean_force = train_force_epoch / len(train_loader.dataset)
        train_loss_force_epoch.append(train_mean_force)
        train_force_losses.append(train_force_batch / len(train_loader))

        train_mean_HI = train_HI_epoch / len(train_loader.dataset)
        train_loss_HI_epoch.append(train_mean_HI)
        train_HI_losses.append(train_HI_batch / len(train_loader))

        # 验证步骤开始
        model.eval()
        validation_force_epoch = 0.0
        validation_HI_epoch = 0.0
        val_force_batch = 0.0
        val_HI_batch = 0.0

        with torch.no_grad():
            for i, (x, y) in enumerate(validation_loader):
                x1 = x.type(torch.FloatTensor)
                x2 = x1.permute(0, 2, 1)

                force1 = y[:, 0].type(torch.FloatTensor)
                HI1 = y[:, 1].type(torch.FloatTensor)

                x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

                force_hat = model(x3)[:, 0]
                HI_hat = model(x3)[:, 1]

                validation_loss_force = loss(force_hat.flatten(), force2.flatten())
                validation_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

                validation_force_epoch += validation_loss_force.item() * x3.size(0)
                validation_HI_epoch += validation_loss_HI.item() * x3.size(0)
                val_force_batch += validation_loss_force.item()
                val_HI_batch += validation_loss_HI.item()

        # 计算平均验证损失
        validation_mean_force = validation_force_epoch / len(validation_loader.dataset)
        validation_loss_force_epoch.append(validation_mean_force)
        val_force_losses.append(val_force_batch / len(validation_loader))

        validation_mean_HI = validation_HI_epoch / len(validation_loader.dataset)
        validation_loss_HI_epoch.append(validation_mean_HI)
        val_HI_losses.append(val_HI_batch / len(validation_loader))
        
        # 计算总验证损失用于早停监控
        total_val_loss = validation_mean_force

        # 早停检查 - 使用总验证损失作为监控指标
        if total_val_loss < best_val_total_loss:
            best_val_total_loss = total_val_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            # 仅在验证损失改善时打印信息
            if epoch % (EPOCH//100) == 0:
                print(f"Epoch {epoch+1}: 验证总损失改善 ({total_val_loss:.4f} -> {best_val_total_loss:.4f})，保存最佳模型")
        else:
            patience_counter += 1
            
            # 检查是否触发早停
            if patience_counter >= patience:
                print(f"\n早停触发！连续 {patience} 个epoch验证总损失未改善")
                print(f"最佳验证总损失: {best_val_total_loss:.4f} (epoch {epoch+1-patience})")
                break

        # 每10个epoch打印一次训练信息
        if epoch % (EPOCH//100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"\nEpoch {epoch+1}/{EPOCH}, LR: {current_lr:.6f}")
            print(f"Train - Force Loss: {train_mean_force:.4f}, HI Loss: {train_mean_HI:.4f}")
            print(f"Valid - Force Loss: {validation_mean_force:.4f}, HI Loss: {validation_mean_HI:.4f}")
            print(f"Valid Total Loss: {total_val_loss:.4f}, Best: {best_val_total_loss:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控总验证损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成，加载最佳模型（验证总损失: {best_val_total_loss:.4f})")
    else:
        print("\n训练完成，但未找到最佳模型")
    
    return train_force_losses, train_HI_losses, val_force_losses, val_HI_losses

# %%
# 假设你已经定义了模型、数据加载器、优化器、损失函数、设备等
train_loss_force, train_loss_HI, validation_loss_force, validation_loss_HI = train_and_validate(
    model=model,
    train_loader = train_loader,
    validation_loader = validation_loader,
    optimizer = optimizer,
    loss = loss,
    device = device,
    EPOCH = EPOCH,
    A = A,
    patience = 500  # 早停耐心值设为500个epoch
)
# Out:
# Epoch 1: 验证总损失改善 (44.7155 -> 44.7155)，保存最佳模型
#
# Epoch 1/1000, LR: 0.001000
# Train - Force Loss: 81.2946, HI Loss: 0.0510
# Valid - Force Loss: 44.7155, HI Loss: 0.0262
# Valid Total Loss: 44.7155, Best: 44.7155
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 11: 验证总损失改善 (24.3029 -> 24.3029)，保存最佳模型
#
# Epoch 11/1000, LR: 0.001000
# Train - Force Loss: 25.5039, HI Loss: 0.0255
# Valid - Force Loss: 24.3029, HI Loss: 0.0257
# Valid Total Loss: 24.3029, Best: 24.3029
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 21/1000, LR: 0.001000
# Train - Force Loss: 6.6946, HI Loss: 0.0117
# Valid - Force Loss: 8.7087, HI Loss: 0.0080
# Valid Total Loss: 8.7087, Best: 8.0424
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 31/1000, LR: 0.001000
# Train - Force Loss: 2.9920, HI Loss: 0.0047
# Valid - Force Loss: 8.6759, HI Loss: 0.0085
# Valid Total Loss: 8.6759, Best: 3.4813
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 41/1000, LR: 0.001000
# Train - Force Loss: 2.9805, HI Loss: 0.0031
# Valid - Force Loss: 4.1369, HI Loss: 0.0026
# Valid Total Loss: 4.1369, Best: 1.8066
# 早停计数器: 4/500 (监控总验证损失)
#
# Epoch 51/1000, LR: 0.001000
# Train - Force Loss: 2.3314, HI Loss: 0.0053
# Valid - Force Loss: 2.2008, HI Loss: 0.0021
# Valid Total Loss: 2.2008, Best: 1.4135
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 61/1000, LR: 0.001000
# Train - Force Loss: 2.3840, HI Loss: 0.0030
# Valid - Force Loss: 4.3163, HI Loss: 0.0045
# Valid Total Loss: 4.3163, Best: 1.4135
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 71/1000, LR: 0.001000
# Train - Force Loss: 2.3706, HI Loss: 0.0047
# Valid - Force Loss: 2.4532, HI Loss: 0.0023
# Valid Total Loss: 2.4532, Best: 1.3987
# 早停计数器: 1/500 (监控总验证损失)
# Epoch 81: 验证总损失改善 (1.3527 -> 1.3527)，保存最佳模型
#
# Epoch 81/1000, LR: 0.001000
# Train - Force Loss: 2.0216, HI Loss: 0.0031
# Valid - Force Loss: 1.3527, HI Loss: 0.0017
# Valid Total Loss: 1.3527, Best: 1.3527
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 91/1000, LR: 0.001000
# Train - Force Loss: 2.3912, HI Loss: 0.0027
# Valid - Force Loss: 1.5984, HI Loss: 0.0023
# Valid Total Loss: 1.5984, Best: 1.2754
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 101/1000, LR: 0.000800
# Train - Force Loss: 2.3893, HI Loss: 0.0034
# Valid - Force Loss: 2.0978, HI Loss: 0.0020
# Valid Total Loss: 2.0978, Best: 1.2754
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 111/1000, LR: 0.000800
# Train - Force Loss: 1.8985, HI Loss: 0.0024
# Valid - Force Loss: 1.3413, HI Loss: 0.0015
# Valid Total Loss: 1.3413, Best: 1.2754
# 早停计数器: 23/500 (监控总验证损失)
#
# Epoch 121/1000, LR: 0.000800
# Train - Force Loss: 2.2498, HI Loss: 0.0030
# Valid - Force Loss: 1.9813, HI Loss: 0.0033
# Valid Total Loss: 1.9813, Best: 1.1873
# 早停计数器: 5/500 (监控总验证损失)
#
# Epoch 131/1000, LR: 0.000800
# Train - Force Loss: 2.2768, HI Loss: 0.0029
# Valid - Force Loss: 2.1098, HI Loss: 0.0021
# Valid Total Loss: 2.1098, Best: 1.1873
# 早停计数器: 15/500 (监控总验证损失)
#
# Epoch 141/1000, LR: 0.000800
# Train - Force Loss: 2.3948, HI Loss: 0.0029
# Valid - Force Loss: 1.7002, HI Loss: 0.0023
# Valid Total Loss: 1.7002, Best: 1.1873
# 早停计数器: 25/500 (监控总验证损失)
#
# Epoch 151/1000, LR: 0.000800
# Train - Force Loss: 2.0678, HI Loss: 0.0023
# Valid - Force Loss: 1.8633, HI Loss: 0.0028
# Valid Total Loss: 1.8633, Best: 1.1873
# 早停计数器: 35/500 (监控总验证损失)
#
# Epoch 161/1000, LR: 0.000800
# Train - Force Loss: 2.2956, HI Loss: 0.0023
# Valid - Force Loss: 1.7602, HI Loss: 0.0012
# Valid Total Loss: 1.7602, Best: 1.1572
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 171/1000, LR: 0.000800
# Train - Force Loss: 2.4633, HI Loss: 0.0030
# Valid - Force Loss: 2.1032, HI Loss: 0.0018
# Valid Total Loss: 2.1032, Best: 1.1572
# 早停计数器: 13/500 (监控总验证损失)
#
# Epoch 181/1000, LR: 0.000800
# Train - Force Loss: 2.5376, HI Loss: 0.0030
# Valid - Force Loss: 1.3905, HI Loss: 0.0014
# Valid Total Loss: 1.3905, Best: 1.1572
# 早停计数器: 23/500 (监控总验证损失)
#
# Epoch 191/1000, LR: 0.000800
# Train - Force Loss: 3.2534, HI Loss: 0.0054
# Valid - Force Loss: 2.3110, HI Loss: 0.0021
# Valid Total Loss: 2.3110, Best: 1.1572
# 早停计数器: 33/500 (监控总验证损失)
#
# Epoch 201/1000, LR: 0.000640
# Train - Force Loss: 1.8345, HI Loss: 0.0021
# Valid - Force Loss: 1.4886, HI Loss: 0.0019
# Valid Total Loss: 1.4886, Best: 1.1572
# 早停计数器: 43/500 (监控总验证损失)
#
# Epoch 211/1000, LR: 0.000640
# Train - Force Loss: 2.0317, HI Loss: 0.0027
# Valid - Force Loss: 1.5400, HI Loss: 0.0020
# Valid Total Loss: 1.5400, Best: 1.1572
# 早停计数器: 53/500 (监控总验证损失)
#
# Epoch 221/1000, LR: 0.000640
# Train - Force Loss: 2.1271, HI Loss: 0.0028
# Valid - Force Loss: 1.4526, HI Loss: 0.0014
# Valid Total Loss: 1.4526, Best: 1.1572
# 早停计数器: 63/500 (监控总验证损失)
#
# Epoch 231/1000, LR: 0.000640
# Train - Force Loss: 2.1302, HI Loss: 0.0047
# Valid - Force Loss: 1.7268, HI Loss: 0.0013
# Valid Total Loss: 1.7268, Best: 1.1572
# 早停计数器: 73/500 (监控总验证损失)
#
# Epoch 241/1000, LR: 0.000640
# Train - Force Loss: 2.0928, HI Loss: 0.0024
# Valid - Force Loss: 1.4369, HI Loss: 0.0017
# Valid Total Loss: 1.4369, Best: 1.1572
# 早停计数器: 83/500 (监控总验证损失)
#
# Epoch 251/1000, LR: 0.000640
# Train - Force Loss: 1.8395, HI Loss: 0.0021
# Valid - Force Loss: 1.3431, HI Loss: 0.0014
# Valid Total Loss: 1.3431, Best: 1.1572
# 早停计数器: 93/500 (监控总验证损失)
#
# Epoch 261/1000, LR: 0.000640
# Train - Force Loss: 1.8135, HI Loss: 0.0021
# Valid - Force Loss: 1.6089, HI Loss: 0.0017
# Valid Total Loss: 1.6089, Best: 1.1572
# 早停计数器: 103/500 (监控总验证损失)
#
# Epoch 271/1000, LR: 0.000640
# Train - Force Loss: 1.8194, HI Loss: 0.0023
# Valid - Force Loss: 1.2081, HI Loss: 0.0012
# Valid Total Loss: 1.2081, Best: 1.1572
# 早停计数器: 113/500 (监控总验证损失)
#
# Epoch 281/1000, LR: 0.000640
# Train - Force Loss: 1.7927, HI Loss: 0.0020
# Valid - Force Loss: 1.6571, HI Loss: 0.0017
# Valid Total Loss: 1.6571, Best: 1.1044
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 291/1000, LR: 0.000640
# Train - Force Loss: 2.1054, HI Loss: 0.0028
# Valid - Force Loss: 1.1122, HI Loss: 0.0034
# Valid Total Loss: 1.1122, Best: 1.1044
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 301/1000, LR: 0.000512
# Train - Force Loss: 1.8991, HI Loss: 0.0020
# Valid - Force Loss: 1.4614, HI Loss: 0.0018
# Valid Total Loss: 1.4614, Best: 1.1044
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 311/1000, LR: 0.000512
# Train - Force Loss: 1.9704, HI Loss: 0.0025
# Valid - Force Loss: 1.5452, HI Loss: 0.0032
# Valid Total Loss: 1.5452, Best: 1.0877
# 早停计数器: 7/500 (监控总验证损失)
#
# Epoch 321/1000, LR: 0.000512
# Train - Force Loss: 2.0217, HI Loss: 0.0030
# Valid - Force Loss: 1.3610, HI Loss: 0.0014
# Valid Total Loss: 1.3610, Best: 1.0877
# 早停计数器: 17/500 (监控总验证损失)
#
# Epoch 331/1000, LR: 0.000512
# Train - Force Loss: 1.9160, HI Loss: 0.0025
# Valid - Force Loss: 1.1797, HI Loss: 0.0012
# Valid Total Loss: 1.1797, Best: 1.0877
# 早停计数器: 27/500 (监控总验证损失)
#
# Epoch 341/1000, LR: 0.000512
# Train - Force Loss: 2.1591, HI Loss: 0.0024
# Valid - Force Loss: 1.5330, HI Loss: 0.0016
# Valid Total Loss: 1.5330, Best: 1.0877
# 早停计数器: 37/500 (监控总验证损失)
#
# Epoch 351/1000, LR: 0.000512
# Train - Force Loss: 2.0220, HI Loss: 0.0023
# Valid - Force Loss: 1.2597, HI Loss: 0.0013
# Valid Total Loss: 1.2597, Best: 1.0877
# 早停计数器: 47/500 (监控总验证损失)
#
# Epoch 361/1000, LR: 0.000512
# Train - Force Loss: 2.2131, HI Loss: 0.0022
# Valid - Force Loss: 2.0492, HI Loss: 0.0012
# Valid Total Loss: 2.0492, Best: 1.0877
# 早停计数器: 57/500 (监控总验证损失)
#
# Epoch 371/1000, LR: 0.000512
# Train - Force Loss: 2.0595, HI Loss: 0.0021
# Valid - Force Loss: 1.4521, HI Loss: 0.0015
# Valid Total Loss: 1.4521, Best: 1.0877
# 早停计数器: 67/500 (监控总验证损失)
#
# Epoch 381/1000, LR: 0.000512
# Train - Force Loss: 1.9069, HI Loss: 0.0022
# Valid - Force Loss: 1.2717, HI Loss: 0.0015
# Valid Total Loss: 1.2717, Best: 1.0877
# 早停计数器: 77/500 (监控总验证损失)
#
# Epoch 391/1000, LR: 0.000512
# Train - Force Loss: 2.3835, HI Loss: 0.0028
# Valid - Force Loss: 2.6328, HI Loss: 0.0015
# Valid Total Loss: 2.6328, Best: 1.0877
# 早停计数器: 87/500 (监控总验证损失)
#
# Epoch 401/1000, LR: 0.000410
# Train - Force Loss: 1.9424, HI Loss: 0.0022
# Valid - Force Loss: 1.3233, HI Loss: 0.0014
# Valid Total Loss: 1.3233, Best: 1.0877
# 早停计数器: 97/500 (监控总验证损失)
#
# Epoch 411/1000, LR: 0.000410
# Train - Force Loss: 2.5238, HI Loss: 0.0029
# Valid - Force Loss: 1.4568, HI Loss: 0.0012
# Valid Total Loss: 1.4568, Best: 1.0877
# 早停计数器: 107/500 (监控总验证损失)
# Epoch 421: 验证总损失改善 (1.0700 -> 1.0700)，保存最佳模型
#
# Epoch 421/1000, LR: 0.000410
# Train - Force Loss: 1.9333, HI Loss: 0.0023
# Valid - Force Loss: 1.0700, HI Loss: 0.0014
# Valid Total Loss: 1.0700, Best: 1.0700
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 431/1000, LR: 0.000410
# Train - Force Loss: 1.6748, HI Loss: 0.0018
# Valid - Force Loss: 1.3494, HI Loss: 0.0014
# Valid Total Loss: 1.3494, Best: 1.0700
# 早停计数器: 10/500 (监控总验证损失)
#
# Epoch 441/1000, LR: 0.000410
# Train - Force Loss: 2.4022, HI Loss: 0.0030
# Valid - Force Loss: 1.3085, HI Loss: 0.0013
# Valid Total Loss: 1.3085, Best: 1.0700
# 早停计数器: 20/500 (监控总验证损失)
#
# Epoch 451/1000, LR: 0.000410
# Train - Force Loss: 2.0076, HI Loss: 0.0023
# Valid - Force Loss: 1.3270, HI Loss: 0.0014
# Valid Total Loss: 1.3270, Best: 1.0700
# 早停计数器: 30/500 (监控总验证损失)
#
# Epoch 461/1000, LR: 0.000410
# Train - Force Loss: 2.1352, HI Loss: 0.0021
# Valid - Force Loss: 1.3563, HI Loss: 0.0021
# Valid Total Loss: 1.3563, Best: 1.0700
# 早停计数器: 40/500 (监控总验证损失)
#
# Epoch 471/1000, LR: 0.000410
# Train - Force Loss: 2.1573, HI Loss: 0.0028
# Valid - Force Loss: 1.5770, HI Loss: 0.0017
# Valid Total Loss: 1.5770, Best: 1.0700
# 早停计数器: 50/500 (监控总验证损失)
#
# Epoch 481/1000, LR: 0.000410
# Train - Force Loss: 1.9028, HI Loss: 0.0021
# Valid - Force Loss: 1.2112, HI Loss: 0.0012
# Valid Total Loss: 1.2112, Best: 1.0700
# 早停计数器: 60/500 (监控总验证损失)
#
# Epoch 491/1000, LR: 0.000410
# Train - Force Loss: 1.9376, HI Loss: 0.0020
# Valid - Force Loss: 1.5328, HI Loss: 0.0015
# Valid Total Loss: 1.5328, Best: 1.0700
# 早停计数器: 70/500 (监控总验证损失)
#
# Epoch 501/1000, LR: 0.000328
# Train - Force Loss: 2.0528, HI Loss: 0.0023
# Valid - Force Loss: 1.8331, HI Loss: 0.0017
# Valid Total Loss: 1.8331, Best: 1.0700
# 早停计数器: 80/500 (监控总验证损失)
#
# Epoch 511/1000, LR: 0.000328
# Train - Force Loss: 2.0391, HI Loss: 0.0027
# Valid - Force Loss: 1.3303, HI Loss: 0.0013
# Valid Total Loss: 1.3303, Best: 1.0700
# 早停计数器: 90/500 (监控总验证损失)
#
# Epoch 521/1000, LR: 0.000328
# Train - Force Loss: 1.6689, HI Loss: 0.0019
# Valid - Force Loss: 1.2629, HI Loss: 0.0014
# Valid Total Loss: 1.2629, Best: 1.0700
# 早停计数器: 100/500 (监控总验证损失)
#
# Epoch 531/1000, LR: 0.000328
# Train - Force Loss: 1.7360, HI Loss: 0.0019
# Valid - Force Loss: 1.2224, HI Loss: 0.0020
# Valid Total Loss: 1.2224, Best: 1.0700
# 早停计数器: 110/500 (监控总验证损失)
#
# Epoch 541/1000, LR: 0.000328
# Train - Force Loss: 1.9397, HI Loss: 0.0022
# Valid - Force Loss: 1.3308, HI Loss: 0.0013
# Valid Total Loss: 1.3308, Best: 1.0700
# 早停计数器: 120/500 (监控总验证损失)
#
# Epoch 551/1000, LR: 0.000328
# Train - Force Loss: 2.1091, HI Loss: 0.0026
# Valid - Force Loss: 1.3187, HI Loss: 0.0015
# Valid Total Loss: 1.3187, Best: 1.0700
# 早停计数器: 130/500 (监控总验证损失)
#
# Epoch 561/1000, LR: 0.000328
# Train - Force Loss: 1.9337, HI Loss: 0.0032
# Valid - Force Loss: 1.3760, HI Loss: 0.0015
# Valid Total Loss: 1.3760, Best: 1.0700
# 早停计数器: 140/500 (监控总验证损失)
#
# Epoch 571/1000, LR: 0.000328
# Train - Force Loss: 1.8695, HI Loss: 0.0021
# Valid - Force Loss: 1.4425, HI Loss: 0.0015
# Valid Total Loss: 1.4425, Best: 1.0700
# 早停计数器: 150/500 (监控总验证损失)
#
# Epoch 581/1000, LR: 0.000328
# Train - Force Loss: 1.8896, HI Loss: 0.0022
# Valid - Force Loss: 1.4237, HI Loss: 0.0014
# Valid Total Loss: 1.4237, Best: 1.0700
# 早停计数器: 160/500 (监控总验证损失)
#
# Epoch 591/1000, LR: 0.000328
# Train - Force Loss: 1.7334, HI Loss: 0.0019
# Valid - Force Loss: 1.4143, HI Loss: 0.0017
# Valid Total Loss: 1.4143, Best: 1.0700
# 早停计数器: 170/500 (监控总验证损失)
#
# Epoch 601/1000, LR: 0.000262
# Train - Force Loss: 2.0099, HI Loss: 0.0023
# Valid - Force Loss: 1.3524, HI Loss: 0.0015
# Valid Total Loss: 1.3524, Best: 1.0700
# 早停计数器: 180/500 (监控总验证损失)
#
# Epoch 611/1000, LR: 0.000262
# Train - Force Loss: 1.8303, HI Loss: 0.0021
# Valid - Force Loss: 1.4631, HI Loss: 0.0021
# Valid Total Loss: 1.4631, Best: 1.0700
# 早停计数器: 190/500 (监控总验证损失)
#
# Epoch 621/1000, LR: 0.000262
# Train - Force Loss: 1.7552, HI Loss: 0.0017
# Valid - Force Loss: 1.2601, HI Loss: 0.0014
# Valid Total Loss: 1.2601, Best: 1.0700
# 早停计数器: 200/500 (监控总验证损失)
#
# Epoch 631/1000, LR: 0.000262
# Train - Force Loss: 2.0881, HI Loss: 0.0023
# Valid - Force Loss: 1.4754, HI Loss: 0.0021
# Valid Total Loss: 1.4754, Best: 1.0700
# 早停计数器: 210/500 (监控总验证损失)
#
# Epoch 641/1000, LR: 0.000262
# Train - Force Loss: 1.6578, HI Loss: 0.0017
# Valid - Force Loss: 1.3814, HI Loss: 0.0014
# Valid Total Loss: 1.3814, Best: 1.0700
# 早停计数器: 220/500 (监控总验证损失)
#
# Epoch 651/1000, LR: 0.000262
# Train - Force Loss: 1.6136, HI Loss: 0.0016
# Valid - Force Loss: 1.5086, HI Loss: 0.0014
# Valid Total Loss: 1.5086, Best: 1.0700
# 早停计数器: 230/500 (监控总验证损失)
#
# Epoch 661/1000, LR: 0.000262
# Train - Force Loss: 1.6972, HI Loss: 0.0018
# Valid - Force Loss: 1.4603, HI Loss: 0.0014
# Valid Total Loss: 1.4603, Best: 1.0700
# 早停计数器: 240/500 (监控总验证损失)
#
# Epoch 671/1000, LR: 0.000262
# Train - Force Loss: 1.8775, HI Loss: 0.0020
# Valid - Force Loss: 1.2319, HI Loss: 0.0013
# Valid Total Loss: 1.2319, Best: 1.0700
# 早停计数器: 250/500 (监控总验证损失)
#
# Epoch 681/1000, LR: 0.000262
# Train - Force Loss: 2.0762, HI Loss: 0.0029
# Valid - Force Loss: 1.4963, HI Loss: 0.0015
# Valid Total Loss: 1.4963, Best: 1.0700
# 早停计数器: 260/500 (监控总验证损失)
#
# Epoch 691/1000, LR: 0.000262
# Train - Force Loss: 1.9150, HI Loss: 0.0020
# Valid - Force Loss: 1.1995, HI Loss: 0.0018
# Valid Total Loss: 1.1995, Best: 1.0700
# 早停计数器: 270/500 (监控总验证损失)
#
# Epoch 701/1000, LR: 0.000210
# Train - Force Loss: 2.1258, HI Loss: 0.0022
# Valid - Force Loss: 1.6926, HI Loss: 0.0015
# Valid Total Loss: 1.6926, Best: 1.0700
# 早停计数器: 280/500 (监控总验证损失)
#
# Epoch 711/1000, LR: 0.000210
# Train - Force Loss: 1.6776, HI Loss: 0.0018
# Valid - Force Loss: 1.8335, HI Loss: 0.0016
# Valid Total Loss: 1.8335, Best: 1.0700
# 早停计数器: 290/500 (监控总验证损失)
#
# Epoch 721/1000, LR: 0.000210
# Train - Force Loss: 1.5777, HI Loss: 0.0017
# Valid - Force Loss: 1.4856, HI Loss: 0.0015
# Valid Total Loss: 1.4856, Best: 1.0700
# 早停计数器: 300/500 (监控总验证损失)
#
# Epoch 731/1000, LR: 0.000210
# Train - Force Loss: 2.1074, HI Loss: 0.0022
# Valid - Force Loss: 1.4204, HI Loss: 0.0013
# Valid Total Loss: 1.4204, Best: 1.0700
# 早停计数器: 310/500 (监控总验证损失)
#
# Epoch 741/1000, LR: 0.000210
# Train - Force Loss: 2.3492, HI Loss: 0.0025
# Valid - Force Loss: 1.3536, HI Loss: 0.0013
# Valid Total Loss: 1.3536, Best: 1.0700
# 早停计数器: 320/500 (监控总验证损失)
#
# Epoch 751/1000, LR: 0.000210
# Train - Force Loss: 2.0336, HI Loss: 0.0022
# Valid - Force Loss: 1.4930, HI Loss: 0.0012
# Valid Total Loss: 1.4930, Best: 1.0700
# 早停计数器: 330/500 (监控总验证损失)
#
# Epoch 761/1000, LR: 0.000210
# Train - Force Loss: 1.9268, HI Loss: 0.0020
# Valid - Force Loss: 1.3745, HI Loss: 0.0013
# Valid Total Loss: 1.3745, Best: 1.0700
# 早停计数器: 340/500 (监控总验证损失)
#
# Epoch 771/1000, LR: 0.000210
# Train - Force Loss: 1.7832, HI Loss: 0.0019
# Valid - Force Loss: 1.4133, HI Loss: 0.0020
# Valid Total Loss: 1.4133, Best: 1.0700
# 早停计数器: 350/500 (监控总验证损失)
#
# Epoch 781/1000, LR: 0.000210
# Train - Force Loss: 2.2473, HI Loss: 0.0023
# Valid - Force Loss: 1.5145, HI Loss: 0.0016
# Valid Total Loss: 1.5145, Best: 1.0700
# 早停计数器: 360/500 (监控总验证损失)
#
# Epoch 791/1000, LR: 0.000210
# Train - Force Loss: 1.8422, HI Loss: 0.0020
# Valid - Force Loss: 1.7606, HI Loss: 0.0023
# Valid Total Loss: 1.7606, Best: 1.0700
# 早停计数器: 370/500 (监控总验证损失)
#
# Epoch 801/1000, LR: 0.000168
# Train - Force Loss: 1.9954, HI Loss: 0.0020
# Valid - Force Loss: 1.3673, HI Loss: 0.0016
# Valid Total Loss: 1.3673, Best: 1.0700
# 早停计数器: 380/500 (监控总验证损失)
#
# Epoch 811/1000, LR: 0.000168
# Train - Force Loss: 1.8359, HI Loss: 0.0019
# Valid - Force Loss: 1.6620, HI Loss: 0.0015
# Valid Total Loss: 1.6620, Best: 1.0700
# 早停计数器: 390/500 (监控总验证损失)
#
# Epoch 821/1000, LR: 0.000168
# Train - Force Loss: 1.7365, HI Loss: 0.0018
# Valid - Force Loss: 2.1756, HI Loss: 0.0015
# Valid Total Loss: 2.1756, Best: 1.0700
# 早停计数器: 400/500 (监控总验证损失)
#
# Epoch 831/1000, LR: 0.000168
# Train - Force Loss: 1.6305, HI Loss: 0.0018
# Valid - Force Loss: 1.4287, HI Loss: 0.0014
# Valid Total Loss: 1.4287, Best: 1.0700
# 早停计数器: 410/500 (监控总验证损失)
#
# Epoch 841/1000, LR: 0.000168
# Train - Force Loss: 1.5289, HI Loss: 0.0017
# Valid - Force Loss: 1.4869, HI Loss: 0.0014
# Valid Total Loss: 1.4869, Best: 1.0700
# 早停计数器: 420/500 (监控总验证损失)
#
# Epoch 851/1000, LR: 0.000168
# Train - Force Loss: 1.7773, HI Loss: 0.0020
# Valid - Force Loss: 1.7662, HI Loss: 0.0013
# Valid Total Loss: 1.7662, Best: 1.0700
# 早停计数器: 430/500 (监控总验证损失)
#
# Epoch 861/1000, LR: 0.000168
# Train - Force Loss: 1.6056, HI Loss: 0.0018
# Valid - Force Loss: 1.2817, HI Loss: 0.0015
# Valid Total Loss: 1.2817, Best: 1.0700
# 早停计数器: 440/500 (监控总验证损失)
#
# Epoch 871/1000, LR: 0.000168
# Train - Force Loss: 1.8557, HI Loss: 0.0019
# Valid - Force Loss: 1.2768, HI Loss: 0.0014
# Valid Total Loss: 1.2768, Best: 1.0700
# 早停计数器: 450/500 (监控总验证损失)
#
# Epoch 881/1000, LR: 0.000168
# Train - Force Loss: 2.0953, HI Loss: 0.0023
# Valid - Force Loss: 1.2908, HI Loss: 0.0013
# Valid Total Loss: 1.2908, Best: 1.0700
# 早停计数器: 460/500 (监控总验证损失)
#
# Epoch 891/1000, LR: 0.000168
# Train - Force Loss: 2.0614, HI Loss: 0.0021
# Valid - Force Loss: 1.3300, HI Loss: 0.0014
# Valid Total Loss: 1.3300, Best: 1.0700
# 早停计数器: 470/500 (监控总验证损失)
#
# Epoch 901/1000, LR: 0.000134
# Train - Force Loss: 1.4909, HI Loss: 0.0015
# Valid - Force Loss: 1.3584, HI Loss: 0.0014
# Valid Total Loss: 1.3584, Best: 1.0700
# 早停计数器: 480/500 (监控总验证损失)
#
# Epoch 911/1000, LR: 0.000134
# Train - Force Loss: 1.7859, HI Loss: 0.0018
# Valid - Force Loss: 1.3596, HI Loss: 0.0013
# Valid Total Loss: 1.3596, Best: 1.0700
# 早停计数器: 490/500 (监控总验证损失)
#
# 早停触发！连续 500 个epoch验证总损失未改善
# 最佳验证总损失: 1.0700 (epoch 421)
#
# 训练完成，加载最佳模型（验证总损失: 1.0700)

# %%
torch.save(model, f'{Save_path}Inverse_Model_3.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
plt.style.use('default')
plt.figure(figsize=(12, 8)) # 创建Figure对象，并指定尺寸
plt.rcParams['font.family'] = ['Times New Roman']

# 设置x轴刻度
epoch = np.arange(0, len(train_loss_force), len(train_loss_force) // 10)
plt.xticks(epoch)

# 创建第一个y轴
ax1 = plt.gca()
ax1.plot(train_loss_force, 'r-', linewidth=2.5)
ax1.plot(train_loss_force, marker='o', markersize=5, color='red', linestyle='None', label='Training loss for PF')
ax1.plot(validation_loss_force, 'r-', linewidth=2.5)
ax1.plot(validation_loss_force, marker='*', markersize=5, color='red', linestyle='None', label='Validation loss for PF')

ax1.set_xlabel('Epoch', fontdict={'weight': 'normal', 'size': 20})
ax1.set_ylabel('Loss for PF', fontdict={'weight': 'normal', 'size': 20}, color='red')

ax1.tick_params(axis='y', labelcolor='red')
ax1.tick_params(axis='both', which='major',labelcolor='black', labelsize=15)

# 添加图例
ax1.legend(loc='upper left', fontsize=20)


max_val = max(
    max(train_loss_force),
    max(validation_loss_force)
)

ax1.set_ylim(0, max_val)

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None', label='Training loss for HI')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None', label='Validation loss for HI')

ax2.set_ylabel('Loss for HI', fontdict={'weight': 'normal', 'size': 20}, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major',labelcolor='blue', labelsize=15)

max_val = max(
    max(train_loss_HI),
    max(validation_loss_HI)
)

ax2.set_ylim(0, max_val)
ax2.legend(loc='upper right', fontsize=20)

# 创建放大图的子图（inset）
x1 = int(len(train_loss_force)*0.7)
x2 = int(len(train_loss_force))

ax_inset = plt.axes([0.45, 0.25, 0.4, 0.4])  # [left, bottom, width, height]
ax_inset.plot(train_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(train_loss_force, marker='o', markersize=8, color='red', linestyle='None')
ax_inset.plot(validation_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(validation_loss_force, marker='*', markersize=8, color='red', linestyle='None')

max_val = max(
    max(train_loss_force[x1:x2]),
    max(validation_loss_force[x1:x2])
)

ax_inset.set_xlim(x1, x2)
ax_inset.set_ylim(0, max_val)
ax_inset.tick_params(axis='both', which='major',  labelcolor='red',labelsize=15)

ax2 = ax_inset.twinx()

ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None')

max_val = max(
    max(train_loss_HI[x1:x2]),
    max(validation_loss_HI[x1:x2])
)

ax2.set_ylim(0, max_val)

ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major', labelsize=15)

# 保存图像
plt.savefig(f'{Save_path}Inverse_problem_Loss.jpg', dpi=600, bbox_inches='tight')
plt.show()
