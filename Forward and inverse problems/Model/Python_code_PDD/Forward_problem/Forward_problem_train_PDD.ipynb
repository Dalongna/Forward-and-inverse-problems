# %%
# 导入必要的库
import os
import glob
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import random
import torch.nn.functional as F

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

random.seed(42)
Main_path='D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'

save_path = f'{Main_path}Model\\Python_code_PDD\\Forward_problem\\'

Excitation_signal_path = f'{Main_path}Data\\Hanning_Excitation_signal'
experimental_signal_path = f'{Main_path}Data\\Experiment_signal'
# Out:
# Using device: cuda:0

# %%
M = 9900
batch_size = 32
label_dim = 3

criterion = nn.MSELoss().to(device)

# 定义数据集类
class SignalDataset(Dataset):
    def __init__(self, Excitation_signals, labels, experimental_signal):
        self.Excitation_signals = torch.tensor(Excitation_signals, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.float32)
        self.experimental_signal = torch.tensor(experimental_signal, dtype=torch.float32)

    def __len__(self):
        return len(self.Excitation_signals)

    def __getitem__(self, idx):
        return {
            'Excitation_signal': self.Excitation_signals[idx],
            'labels': self.labels[idx],
            'experimental_signal': self.experimental_signal[idx]
        }

# %%
class ConvAutoencoder(nn.Module):
    def __init__(self, signal_length, label_dim, hidden_dim, dropout):
        super().__init__()
        self.signal_length = signal_length
        self.label_dim = label_dim
        
        # 标签投影网络（7层）
        self.label_projection = nn.Sequential(
            nn.Linear(label_dim, hidden_dim * 4),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 4, hidden_dim * 8),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 8, hidden_dim * 16),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 16, hidden_dim * 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 32, hidden_dim * 64),  # 第5层
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 64, hidden_dim * 128), # 第6层
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 128, hidden_dim * 64) # 第7层
        )
        
        # 7层编码器
        self.encoder = nn.Sequential(
            # Layer 1
            nn.Conv1d(1, hidden_dim, kernel_size=7, stride=2, padding=3),
            nn.ReLU(),
            
            # Layer 2
            nn.Conv1d(hidden_dim, hidden_dim*2, kernel_size=5, stride=2, padding=2),
            nn.ReLU(),
            
            # Layer 3
            nn.Conv1d(hidden_dim*2, hidden_dim*4, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            
            # Layer 4
            nn.Conv1d(hidden_dim*4, hidden_dim*8, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            
            # Layer 5 - 修改
            nn.Conv1d(hidden_dim*8, hidden_dim*16, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            
            # Layer 6 - 修改
            nn.Conv1d(hidden_dim*16, hidden_dim*32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            
            # Layer 7 - 修改
            nn.Conv1d(hidden_dim*32, hidden_dim*64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )
        
        # 7层解码器
        self.decoder = nn.Sequential(
            # Layer 1: 融合
            nn.ConvTranspose1d(hidden_dim*64 + hidden_dim*64, hidden_dim*32,  # 标签特征改为64维
                              kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            
            # Layer 2
            nn.ConvTranspose1d(hidden_dim*32, hidden_dim*16, 
                              kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            
            # Layer 3
            nn.ConvTranspose1d(hidden_dim*16, hidden_dim*8, 
                              kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            
            # Layer 4
            nn.ConvTranspose1d(hidden_dim*8, hidden_dim*4, 
                              kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            
            # Layer 5
            nn.ConvTranspose1d(hidden_dim*4, hidden_dim*2, 
                              kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            
            # Layer 6
            nn.ConvTranspose1d(hidden_dim*2, hidden_dim, 
                              kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.ReLU(),
            
            # Layer 7
            nn.ConvTranspose1d(hidden_dim, 1, 
                              kernel_size=7, stride=2, padding=3, output_padding=1),
        )
        
        # 计算编码输出长度
        with torch.no_grad():
            test_input = torch.randn(1, 1, signal_length)
            encoded = self.encoder(test_input)
            self.encoder_output_len = encoded.shape[-1]

    def forward(self, x, labels):
        # 编码
        encoded = self.encoder(x)
        
        # 标签特征
        label_features = self.label_projection(labels)
        label_features = label_features.unsqueeze(-1).expand(-1, -1, self.encoder_output_len)
        
        # 融合和解码
        combined = torch.cat([encoded, label_features], dim=1)
        decoded = self.decoder(combined)
        
        return decoded[:,:,:self.signal_length]

# %%
def load_data(Excitation_signal_path, experimental_signal_path, M):
    Excitation_signals = []  # 存储生成信号
    labels = []  # 存储标签 (Force_label, HI_label, Distance_label, Time_label)
    experimental_signals = []  # 存储输出参数

    # 加载生成信号数据
    Excitation_dataPaths = sorted(glob.glob(os.path.join(Excitation_signal_path, '**', '*.csv'), recursive=True))
    for dataPath in Excitation_dataPaths:
        filename = os.path.basename(dataPath)
        parts = filename.split('_')

        Temperature_label = float(parts[0])
        Time_label = float(parts[1])
        Distance_label = float(parts[4])
        amp_part = parts[5].replace('.csv', '')
        Amp_label = float(amp_part)    

        data_1 = pd.read_csv(dataPath)
        # 找到第一个非0值的位置
        for N in range(len(data_1)):
            if data_1.iloc[N, 1] != 0:
                break
        # 截取长度为M的信号段
        if N + M <= len(data_1):  # 避免越界
            Excitation_signal = data_1.iloc[N:N+M, 1].values*Amp_label
        else:
            continue

        # 分别存储 Excitation_signal 和 labels
        Excitation_signals.append(Excitation_signal)
        labels.append([Temperature_label, Time_label, Distance_label])

    # 加载实验信号数据
    experimental_dataPaths = sorted(glob.glob(os.path.join(experimental_signal_path, '**', '*.csv'), recursive=True))
    for dataPath in experimental_dataPaths:
        data_1 = pd.read_csv(dataPath)
        # 找到第一个非0值的位置
        for N in range(len(data_1)):
            if data_1.iloc[N, 1] != 0:
                break
        # 截取长度为M的信号段（避免越界）
        if N + M <= len(data_1):
            experimental_signal = data_1.iloc[N:N+M, 1].values
            experimental_signals.append(experimental_signal)
        else:
            # 如果长度不足，跳过该样本（也可根据需求补0）
            continue

    # 确保 Excitation_signals、labels 和 experimental_signals 的长度一致
    if len(Excitation_signals) != len(experimental_signals) or len(labels) != len(experimental_signals):
        print(f"Error: 输入输出数量不匹配！生成信号数:{len(Excitation_signals)}, 实验信号数:{len(experimental_signals)}, 标签数:{len(labels)}")
        return None, None, None, None, None

    # 转换为 NumPy 数组
    Excitation_signals = np.array(Excitation_signals, dtype=float)
    labels = np.array(labels, dtype=float)
    experimental_signals = np.array(experimental_signals, dtype=float)

    return Excitation_signals, labels, experimental_signals

# %%
# 2. 一次性加载全部数据
excitation_signals, labels, experimental_signal= load_data(
    Excitation_signal_path, experimental_signal_path, M)

# 3. 第一次划分：先劈出test_size测试集，剩下 1-test_size留给训练+验证
gen_train_val, gen_test, lab_train_val, lab_test, exp_train_val, exp_test = train_test_split(
    excitation_signals, labels, experimental_signal,
    test_size=8/10, random_state=42, shuffle=True)

# 4. 第二次划分：test_size为验证集数据占比，1-test_size为训练集数据占比
gen_train, gen_val, lab_train, lab_val, exp_train, exp_val = train_test_split(
    gen_train_val, lab_train_val, exp_train_val,
    test_size=1/2, random_state=42, shuffle=True)

# 增加通道维度 [batch, 1, N]
gen_train = np.expand_dims(gen_train, axis=1)
exp_train = np.expand_dims(exp_train, axis=1)

gen_val   = np.expand_dims(gen_val,   axis=1)
exp_val   = np.expand_dims(exp_val,   axis=1)

gen_test  = np.expand_dims(gen_test,  axis=1)
exp_test  = np.expand_dims(exp_test,  axis=1)

# 6. 打印形状确认
print('gen_train:', gen_train.shape)
print('gen_val:  ', gen_val.shape)
print('gen_test: ', gen_test.shape)

# 7. 组装 Dataset / DataLoader
train_dataset = SignalDataset(gen_train, lab_train, exp_train)
val_dataset   = SignalDataset(gen_val,   lab_val,   exp_val)
test_dataset  = SignalDataset(gen_test,  lab_test,  exp_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size, shuffle=False)
# Out:
# gen_train: (86, 1, 9900)
# gen_val:   (86, 1, 9900)
# gen_test:  (692, 1, 9900)

# %%
Excitation_signals_train_1 = gen_train.reshape(-1,M,1)
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(Excitation_signals_train_1[10],linewidth=1.5)
plt.xlabel('Sampling point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{save_path}Excitation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
experimental_signal_train_1 = exp_train.reshape(-1,M,1)
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(experimental_signal_train_1[35],linewidth=1.5)
plt.xlabel('Sampling point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{save_path}Experiment_signal.jpg', dpi=600, bbox_inches='tight')

# %%
def calculate_pcc(x, y):
    """
    计算两个信号的皮尔逊相关系数(PCC)。

    参数:
        x (torch.Tensor): 第一个信号，假定在 CUDA 上。
        y (torch.Tensor): 第二个信号，假定在 CUDA 上。

    返回:
        float: 皮尔逊相关系数。
    """
    
    # 计算均值
    mean_x = torch.mean(x)
    mean_y = torch.mean(y)
    
    # 计算协方差
    covariance = torch.mean((x - mean_x) * (y - mean_y))
    
    # 计算标准差
    std_x = torch.std(x)
    std_y = torch.std(y)
    
    # 计算皮尔逊相关系数
    if std_x == 0 or std_y == 0:
        raise ValueError("标准差不能为零，这可能导致除以零的错误。")
    
    pcc = covariance / (std_x * std_y)

    pcc_1 = pcc.to(device)

    return pcc_1.item()  # 将结果转换为 Python 标量

# %%
def FFT_Complex_Loss(x, x_hat):
    """
    FFT2损失函数（实部和虚部损失）
    按照公式: J_FFT2 = ||Re(X_hat - X)||^2 + ||Im(X_hat - X)||^2
    
    参数:
    x: 原始信号 [batch_size, channels, length]
    x_hat: 重建信号 [batch_size, channels, length]
    
    返回:
    loss: FFT2损失值
    """
    # 计算FFT
    fft_x = torch.fft.fft(x, dim=-1)          # 原始信号的FFT
    fft_x_hat = torch.fft.fft(x_hat, dim=-1)  # 重建信号的FFT
    
    # 计算频域差异
    fft_diff = fft_x_hat - fft_x
    
    # 提取实部和虚部
    real_diff = torch.real(fft_diff)  # 实部差异
    imag_diff = torch.imag(fft_diff)  # 虚部差异
    
    # 计算L2损失（均方误差）
    real_loss = torch.mean(real_diff ** 2)
    imag_loss = torch.mean(imag_diff ** 2)
    
    # 总损失 = 实部损失 + 虚部损失
    loss = real_loss + imag_loss
    
    return loss.item()

# %%
def FFT_NP_loss(x, x_hat, fs=2.5e7):
    """
    提取两个频带的最大幅值差异作为损失
    
    参数:
    x: 原始信号 [batch_size, channels, length]
    x_hat: 重建信号 [batch_size, channels, length]
    fs: 采样率,默认为2.5e7 Hz
    
    返回:
    loss: 两个频带最大幅值差异的均方损失
    """
    # 计算FFT
    fft_x = torch.fft.fft(x, dim=-1)
    fft_x_hat = torch.fft.fft(x_hat, dim=-1)
    
    # 获取信号长度
    n_samples = x.shape[-1]
    
    # 计算频率轴
    freqs = torch.fft.fftfreq(n_samples, 1/fs)
    
    # 找到频带对应的索引
    mask_band1 = (freqs >= 48000) & (freqs <= 52000)
    mask_band2 = (freqs >= 95000) & (freqs <= 105000)
    
    # 提取第一个频带(45kHz-55kHz)的最大幅值
    fft_abs_x_band1 = torch.abs(fft_x[..., mask_band1])
    fft_abs_x_hat_band1 = torch.abs(fft_x_hat[..., mask_band1])
    
    # 取最大值
    A1_orig = torch.max(fft_abs_x_band1, dim=-1)[0]
    A1_recon = torch.max(fft_abs_x_hat_band1, dim=-1)[0]
    
    # 提取第二个频带(90kHz-110kHz)的最大幅值
    fft_abs_x_band2 = torch.abs(fft_x[..., mask_band2])
    fft_abs_x_hat_band2 = torch.abs(fft_x_hat[..., mask_band2])
    
    # 取最大值
    A2_orig = torch.max(fft_abs_x_band2, dim=-1)[0]
    A2_recon = torch.max(fft_abs_x_hat_band2, dim=-1)[0]
    
    # 计算幅值差异
    diff_A1 = A1_recon - A1_orig
    diff_A2 = A2_recon - A2_orig
    
    # 计算损失（均方误差）
    loss = torch.mean(diff_A1 ** 2) + torch.mean(diff_A2 ** 2)
    
    return loss.item()

# %%
A = 1

# 定义训练和验证函数
def train_model(model, train_loader, valid_loader, epochs, learning_rate, patience):
    
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    # 添加学习率调度器，每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用valid_loss_FFT_Amp作为监控指标
    best_val = float('inf')  # 更改为监控FFT幅度损失
    patience_counter = 0
    best_model_state = None
    
    train_losses = []
    val_losses = []

    train_PCC=[]
    valid_PCC=[]

    train_FFT_NP=[]
    valid_FFT_NP=[]

    train_FFT_Complex=[]
    valid_FFT_Complex=[]

    train_time =[]
    valid_time =[]

    for epoch in range(epochs):

        train_PCC_2 = 0.0
        train_FFT_2 = 0.0
        train_FFT_3 = 0.0
        train_time_2 = 0.0

        model.train()
        running_loss = 0.0
        for batch in train_loader:
            excitation_signal = batch['Excitation_signal'].to(device)
            labels = batch['labels'].to(device)
            experimental_signal = batch['experimental_signal'].to(device)

            optimizer.zero_grad()
            experimental_signal_pred = model(excitation_signal, labels)            

            FFT_NP = FFT_NP_loss(experimental_signal_pred,experimental_signal)
            train_FFT_2 += FFT_NP

            FFT_Complex = FFT_Complex_Loss(experimental_signal_pred,experimental_signal)
            train_FFT_3 += FFT_Complex

            PCC_1 = calculate_pcc(experimental_signal_pred,experimental_signal)
            train_PCC_2 += PCC_1 

            time_loss = criterion(experimental_signal_pred, experimental_signal)
            train_time_2 += time_loss.item()

            loss = A*time_loss

            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            
        # 更新学习率
        scheduler.step()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        train_mean_loss = train_time_2 / len(train_loader)
        train_time.append(train_mean_loss)

        train_mean_PCC = train_PCC_2/len(train_loader)
        train_PCC.append(train_mean_PCC)

        train_loss_FFT_NP = train_FFT_2/len(train_loader)
        train_FFT_NP.append(train_loss_FFT_NP)

        train_loss_FFT_Complex = train_FFT_3/len(train_loader)
        train_FFT_Complex.append(train_loss_FFT_Complex)

        model.eval()

        running_loss = 0.0
        valid_PCC_2 = 0.0
        valid_FFT_2 = 0.0
        valid_FFT_3 = 0.0
        valid_time_2=0.0

        with torch.no_grad():
            for batch in valid_loader:
                excitation_signal = batch['Excitation_signal'].to(device)
                labels = batch['labels'].to(device)
                experimental_signal = batch['experimental_signal'].to(device)

                experimental_signal_pred = model(excitation_signal, labels)

                PCC_1 = calculate_pcc(experimental_signal_pred,experimental_signal)
                valid_PCC_2 += PCC_1 

                FFT_NP = FFT_NP_loss(experimental_signal_pred,experimental_signal)
                valid_FFT_2 += FFT_NP

                FFT_Complex = FFT_Complex_Loss(experimental_signal_pred,experimental_signal)
                valid_FFT_3 += FFT_Complex

                time_loss = criterion(experimental_signal_pred, experimental_signal)
                valid_time_2 += time_loss.item()

                loss = A*time_loss

                running_loss += loss.item()
        val_loss = running_loss / len(valid_loader)
        val_losses.append(val_loss)

        val_mean_loss = valid_time_2 / len(valid_loader)
        valid_time.append(val_mean_loss)

        valid_mean_PCC = valid_PCC_2/len(valid_loader)
        valid_PCC.append(valid_mean_PCC)

        valid_loss_FFT_NP = valid_FFT_2/len(valid_loader)
        valid_FFT_NP.append(valid_loss_FFT_NP)

        valid_loss_FFT_Complex = valid_FFT_3/len(valid_loader)
        valid_FFT_Complex.append(valid_loss_FFT_Complex)

        # 早停检查 - 使用valid_loss_FFT_Amp作为监控指标
        if val_mean_loss < best_val:
            best_val = val_mean_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            print(f"Epoch {epoch+1}: 验证Time损失改善 ({val_mean_loss:.6f} -> {best_val:.6f})，保存最佳模型")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"\n早停触发!连续 {patience} 个epoch验证Time损失未改善")
                print(f"最佳验证Time损失: {best_val:.6f} (epoch {epoch+1-patience})")
                break

        if epoch % (epochs // 100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"Epoch: {epoch + 1}/{epochs}, LR: {current_lr:.6f}, Train Loss: {train_mean_loss:.6f}, Val Loss: {val_mean_loss:.6f}")
            print(f"train_loss_FFT_NP: {train_loss_FFT_NP:.4f}, valid_loss_FFT_NP: {valid_loss_FFT_NP:.4f}")
            print(f"train_loss_FFT_Complex: {train_loss_FFT_Complex:.6f}, valid_loss_FFT_Complex: {valid_loss_FFT_Complex:.6f}")
            print(f"train_mean_PCC: {train_mean_PCC:.4f}, valid_mean_PCC: {valid_mean_PCC:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控Time损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成, 加载最佳模型(验证Time损失: {best_val:.4f})")
    else:
        print("\n训练完成, 但未找到最佳模型")
    
    return (train_time, valid_time, train_PCC, valid_PCC, 
            train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP)

# %%
# 训练模型
epochs = 3000 
lr = 1e-3
model = ConvAutoencoder(signal_length = M, label_dim = label_dim, hidden_dim = 16, dropout = 0).to(device)
train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP = train_model(
    model, train_loader, valid_loader, epochs=epochs, learning_rate=lr, patience=500)
# Out:
# Epoch 1: 验证Time损失改善 (0.013888 -> 0.013888)，保存最佳模型
# Epoch: 1/3000, LR: 0.001000, Train Loss: 0.030142, Val Loss: 0.013888
# train_loss_FFT_NP: 229230.8073, valid_loss_FFT_NP: 195311.1979
# train_loss_FFT_Complex: 298.402761, valid_loss_FFT_Complex: 137.491002
# train_mean_PCC: -0.0000, valid_mean_PCC: 0.0000
# 早停计数器: 0/500 (监控Time损失)
# Epoch 2: 验证Time损失改善 (0.007476 -> 0.007476)，保存最佳模型
# Epoch 3: 验证Time损失改善 (0.006688 -> 0.006688)，保存最佳模型
# Epoch 4: 验证Time损失改善 (0.006156 -> 0.006156)，保存最佳模型
# Epoch 5: 验证Time损失改善 (0.006078 -> 0.006078)，保存最佳模型
# Epoch 6: 验证Time损失改善 (0.005788 -> 0.005788)，保存最佳模型
# Epoch 7: 验证Time损失改善 (0.005561 -> 0.005561)，保存最佳模型
# Epoch 8: 验证Time损失改善 (0.005295 -> 0.005295)，保存最佳模型
# Epoch 9: 验证Time损失改善 (0.005019 -> 0.005019)，保存最佳模型
# Epoch 11: 验证Time损失改善 (0.004909 -> 0.004909)，保存最佳模型
# Epoch 13: 验证Time损失改善 (0.004902 -> 0.004902)，保存最佳模型
# Epoch 14: 验证Time损失改善 (0.004861 -> 0.004861)，保存最佳模型
# Epoch 15: 验证Time损失改善 (0.004746 -> 0.004746)，保存最佳模型
# Epoch 17: 验证Time损失改善 (0.004717 -> 0.004717)，保存最佳模型
# Epoch 19: 验证Time损失改善 (0.004538 -> 0.004538)，保存最佳模型
# Epoch 20: 验证Time损失改善 (0.004169 -> 0.004169)，保存最佳模型
# Epoch 25: 验证Time损失改善 (0.003667 -> 0.003667)，保存最佳模型
# Epoch 27: 验证Time损失改善 (0.003310 -> 0.003310)，保存最佳模型
# Epoch 28: 验证Time损失改善 (0.002651 -> 0.002651)，保存最佳模型
# Epoch 31: 验证Time损失改善 (0.002343 -> 0.002343)，保存最佳模型
# Epoch: 31/3000, LR: 0.001000, Train Loss: 0.002696, Val Loss: 0.002343
# train_loss_FFT_NP: 53174.9766, valid_loss_FFT_NP: 37179.9557
# train_loss_FFT_Complex: 26.687305, valid_loss_FFT_Complex: 23.191799
# train_mean_PCC: 0.8030, valid_mean_PCC: 0.7923
# 早停计数器: 0/500 (监控Time损失)
# Epoch 32: 验证Time损失改善 (0.002276 -> 0.002276)，保存最佳模型
# Epoch 33: 验证Time损失改善 (0.002172 -> 0.002172)，保存最佳模型
# Epoch 34: 验证Time损失改善 (0.002072 -> 0.002072)，保存最佳模型
# Epoch 35: 验证Time损失改善 (0.001984 -> 0.001984)，保存最佳模型
# Epoch 36: 验证Time损失改善 (0.001770 -> 0.001770)，保存最佳模型
# Epoch 37: 验证Time损失改善 (0.001660 -> 0.001660)，保存最佳模型
# Epoch 40: 验证Time损失改善 (0.001548 -> 0.001548)，保存最佳模型
# Epoch 41: 验证Time损失改善 (0.001451 -> 0.001451)，保存最佳模型
# Epoch 42: 验证Time损失改善 (0.001351 -> 0.001351)，保存最佳模型
# Epoch 43: 验证Time损失改善 (0.001254 -> 0.001254)，保存最佳模型
# Epoch 44: 验证Time损失改善 (0.001162 -> 0.001162)，保存最佳模型
# Epoch 45: 验证Time损失改善 (0.001096 -> 0.001096)，保存最佳模型
# Epoch 47: 验证Time损失改善 (0.001025 -> 0.001025)，保存最佳模型
# Epoch 49: 验证Time损失改善 (0.000891 -> 0.000891)，保存最佳模型
# Epoch 50: 验证Time损失改善 (0.000785 -> 0.000785)，保存最佳模型
# Epoch 51: 验证Time损失改善 (0.000674 -> 0.000674)，保存最佳模型
# Epoch 54: 验证Time损失改善 (0.000570 -> 0.000570)，保存最佳模型
# Epoch 57: 验证Time损失改善 (0.000563 -> 0.000563)，保存最佳模型
# Epoch 58: 验证Time损失改善 (0.000412 -> 0.000412)，保存最佳模型
# Epoch 59: 验证Time损失改善 (0.000323 -> 0.000323)，保存最佳模型
# Epoch 60: 验证Time损失改善 (0.000307 -> 0.000307)，保存最佳模型
# Epoch 61: 验证Time损失改善 (0.000257 -> 0.000257)，保存最佳模型
# Epoch: 61/3000, LR: 0.001000, Train Loss: 0.000290, Val Loss: 0.000257
# train_loss_FFT_NP: 1875.7917, valid_loss_FFT_NP: 3879.2636
# train_loss_FFT_Complex: 2.871208, valid_loss_FFT_Complex: 2.546129
# train_mean_PCC: 0.9827, valid_mean_PCC: 0.9797
# 早停计数器: 0/500 (监控Time损失)
# Epoch 62: 验证Time损失改善 (0.000240 -> 0.000240)，保存最佳模型
# Epoch 63: 验证Time损失改善 (0.000211 -> 0.000211)，保存最佳模型
# Epoch 64: 验证Time损失改善 (0.000206 -> 0.000206)，保存最佳模型
# Epoch 65: 验证Time损失改善 (0.000180 -> 0.000180)，保存最佳模型
# Epoch 66: 验证Time损失改善 (0.000174 -> 0.000174)，保存最佳模型
# Epoch 67: 验证Time损失改善 (0.000150 -> 0.000150)，保存最佳模型
# Epoch 68: 验证Time损失改善 (0.000147 -> 0.000147)，保存最佳模型
# Epoch 79: 验证Time损失改善 (0.000144 -> 0.000144)，保存最佳模型
# Epoch 80: 验证Time损失改善 (0.000106 -> 0.000106)，保存最佳模型
# Epoch 81: 验证Time损失改善 (0.000099 -> 0.000099)，保存最佳模型
# Epoch 82: 验证Time损失改善 (0.000094 -> 0.000094)，保存最佳模型
# Epoch 83: 验证Time损失改善 (0.000091 -> 0.000091)，保存最佳模型
# Epoch 85: 验证Time损失改善 (0.000078 -> 0.000078)，保存最佳模型
# Epoch 86: 验证Time损失改善 (0.000069 -> 0.000069)，保存最佳模型
# Epoch 87: 验证Time损失改善 (0.000061 -> 0.000061)，保存最佳模型
# Epoch 88: 验证Time损失改善 (0.000059 -> 0.000059)，保存最佳模型
# Epoch: 91/3000, LR: 0.001000, Train Loss: 0.000054, Val Loss: 0.000060
# train_loss_FFT_NP: 593.9760, valid_loss_FFT_NP: 663.8684
# train_loss_FFT_Complex: 0.531902, valid_loss_FFT_Complex: 0.593564
# train_mean_PCC: 0.9970, valid_mean_PCC: 0.9960
# 早停计数器: 3/500 (监控Time损失)
# Epoch 93: 验证Time损失改善 (0.000048 -> 0.000048)，保存最佳模型
# Epoch 96: 验证Time损失改善 (0.000047 -> 0.000047)，保存最佳模型
# Epoch 97: 验证Time损失改善 (0.000040 -> 0.000040)，保存最佳模型
# Epoch 103: 验证Time损失改善 (0.000039 -> 0.000039)，保存最佳模型
# Epoch 104: 验证Time损失改善 (0.000036 -> 0.000036)，保存最佳模型
# Epoch 105: 验证Time损失改善 (0.000034 -> 0.000034)，保存最佳模型
# Epoch 107: 验证Time损失改善 (0.000033 -> 0.000033)，保存最佳模型
# Epoch 110: 验证Time损失改善 (0.000031 -> 0.000031)，保存最佳模型
# Epoch 117: 验证Time损失改善 (0.000030 -> 0.000030)，保存最佳模型
# Epoch 118: 验证Time损失改善 (0.000027 -> 0.000027)，保存最佳模型
# Epoch 120: 验证Time损失改善 (0.000025 -> 0.000025)，保存最佳模型
# Epoch: 121/3000, LR: 0.000800, Train Loss: 0.000020, Val Loss: 0.000030
# train_loss_FFT_NP: 149.8866, valid_loss_FFT_NP: 551.3051
# train_loss_FFT_Complex: 0.197258, valid_loss_FFT_Complex: 0.299560
# train_mean_PCC: 0.9987, valid_mean_PCC: 0.9979
# 早停计数器: 1/500 (监控Time损失)
# Epoch 123: 验证Time损失改善 (0.000024 -> 0.000024)，保存最佳模型
# Epoch 125: 验证Time损失改善 (0.000023 -> 0.000023)，保存最佳模型
# Epoch 129: 验证Time损失改善 (0.000023 -> 0.000023)，保存最佳模型
# Epoch 130: 验证Time损失改善 (0.000021 -> 0.000021)，保存最佳模型
# Epoch 135: 验证Time损失改善 (0.000020 -> 0.000020)，保存最佳模型
# Epoch 138: 验证Time损失改善 (0.000020 -> 0.000020)，保存最佳模型
# Epoch 140: 验证Time损失改善 (0.000018 -> 0.000018)，保存最佳模型
# Epoch 143: 验证Time损失改善 (0.000018 -> 0.000018)，保存最佳模型
# Epoch 147: 验证Time损失改善 (0.000018 -> 0.000018)，保存最佳模型
# Epoch: 151/3000, LR: 0.000800, Train Loss: 0.000017, Val Loss: 0.000023
# train_loss_FFT_NP: 252.5463, valid_loss_FFT_NP: 467.0667
# train_loss_FFT_Complex: 0.169781, valid_loss_FFT_Complex: 0.228434
# train_mean_PCC: 0.9992, valid_mean_PCC: 0.9986
# 早停计数器: 4/500 (监控Time损失)
# Epoch 165: 验证Time损失改善 (0.000016 -> 0.000016)，保存最佳模型
# Epoch 168: 验证Time损失改善 (0.000016 -> 0.000016)，保存最佳模型
# Epoch 177: 验证Time损失改善 (0.000015 -> 0.000015)，保存最佳模型
# Epoch 181: 验证Time损失改善 (0.000015 -> 0.000015)，保存最佳模型
# Epoch: 181/3000, LR: 0.000800, Train Loss: 0.000009, Val Loss: 0.000015
# train_loss_FFT_NP: 79.0945, valid_loss_FFT_NP: 235.8653
# train_loss_FFT_Complex: 0.092955, valid_loss_FFT_Complex: 0.145402
# train_mean_PCC: 0.9994, valid_mean_PCC: 0.9988
# 早停计数器: 0/500 (监控Time损失)
# Epoch 206: 验证Time损失改善 (0.000014 -> 0.000014)，保存最佳模型
# Epoch 207: 验证Time损失改善 (0.000014 -> 0.000014)，保存最佳模型
# Epoch 209: 验证Time损失改善 (0.000013 -> 0.000013)，保存最佳模型
# Epoch: 211/3000, LR: 0.000640, Train Loss: 0.000008, Val Loss: 0.000014
# train_loss_FFT_NP: 64.7651, valid_loss_FFT_NP: 247.3929
# train_loss_FFT_Complex: 0.079144, valid_loss_FFT_Complex: 0.134668
# train_mean_PCC: 0.9995, valid_mean_PCC: 0.9989
# 早停计数器: 2/500 (监控Time损失)
# Epoch 212: 验证Time损失改善 (0.000013 -> 0.000013)，保存最佳模型
# Epoch 213: 验证Time损失改善 (0.000012 -> 0.000012)，保存最佳模型
# Epoch 214: 验证Time损失改善 (0.000012 -> 0.000012)，保存最佳模型
# Epoch 215: 验证Time损失改善 (0.000012 -> 0.000012)，保存最佳模型
# Epoch 216: 验证Time损失改善 (0.000011 -> 0.000011)，保存最佳模型
# Epoch 219: 验证Time损失改善 (0.000011 -> 0.000011)，保存最佳模型
# Epoch 220: 验证Time损失改善 (0.000011 -> 0.000011)，保存最佳模型
# Epoch 223: 验证Time损失改善 (0.000011 -> 0.000011)，保存最佳模型
# Epoch 230: 验证Time损失改善 (0.000010 -> 0.000010)，保存最佳模型
# Epoch 237: 验证Time损失改善 (0.000010 -> 0.000010)，保存最佳模型
# Epoch: 241/3000, LR: 0.000640, Train Loss: 0.000007, Val Loss: 0.000011
# train_loss_FFT_NP: 67.9540, valid_loss_FFT_NP: 213.2524
# train_loss_FFT_Complex: 0.066342, valid_loss_FFT_Complex: 0.112322
# train_mean_PCC: 0.9996, valid_mean_PCC: 0.9991
# 早停计数器: 4/500 (监控Time损失)
# Epoch: 271/3000, LR: 0.000640, Train Loss: 0.000023, Val Loss: 0.000017
# train_loss_FFT_NP: 220.5374, valid_loss_FFT_NP: 266.0608
# train_loss_FFT_Complex: 0.227607, valid_loss_FFT_Complex: 0.172248
# train_mean_PCC: 0.9994, valid_mean_PCC: 0.9989
# 早停计数器: 34/500 (监控Time损失)
# Epoch 286: 验证Time损失改善 (0.000010 -> 0.000010)，保存最佳模型
# Epoch 287: 验证Time损失改善 (0.000010 -> 0.000010)，保存最佳模型
# Epoch: 301/3000, LR: 0.000512, Train Loss: 0.000007, Val Loss: 0.000011
# train_loss_FFT_NP: 88.1552, valid_loss_FFT_NP: 198.0874
# train_loss_FFT_Complex: 0.071199, valid_loss_FFT_Complex: 0.105202
# train_mean_PCC: 0.9997, valid_mean_PCC: 0.9992
# 早停计数器: 14/500 (监控Time损失)
# Epoch 316: 验证Time损失改善 (0.000010 -> 0.000010)，保存最佳模型
# Epoch 318: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 326: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 327: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 328: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch: 331/3000, LR: 0.000512, Train Loss: 0.000004, Val Loss: 0.000009
# train_loss_FFT_NP: 11.4031, valid_loss_FFT_NP: 191.0117
# train_loss_FFT_Complex: 0.035361, valid_loss_FFT_Complex: 0.093223
# train_mean_PCC: 0.9998, valid_mean_PCC: 0.9992
# 早停计数器: 3/500 (监控Time损失)
# Epoch 335: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 336: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 338: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 342: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 345: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 353: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 354: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch 361: 验证Time损失改善 (0.000009 -> 0.000009)，保存最佳模型
# Epoch: 361/3000, LR: 0.000512, Train Loss: 0.000004, Val Loss: 0.000009
# train_loss_FFT_NP: 13.0576, valid_loss_FFT_NP: 180.9442
# train_loss_FFT_Complex: 0.034722, valid_loss_FFT_Complex: 0.084899
# train_mean_PCC: 0.9998, valid_mean_PCC: 0.9993
# 早停计数器: 0/500 (监控Time损失)
# Epoch 376: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch: 391/3000, LR: 0.000512, Train Loss: 0.000003, Val Loss: 0.000009
# train_loss_FFT_NP: 7.9890, valid_loss_FFT_NP: 195.9306
# train_loss_FFT_Complex: 0.033534, valid_loss_FFT_Complex: 0.086060
# train_mean_PCC: 0.9998, valid_mean_PCC: 0.9993
# 早停计数器: 15/500 (监控Time损失)
# Epoch 400: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 401: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 409: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 410: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 411: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 419: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch: 421/3000, LR: 0.000410, Train Loss: 0.000002, Val Loss: 0.000008
# train_loss_FFT_NP: 8.4009, valid_loss_FFT_NP: 190.8098
# train_loss_FFT_Complex: 0.024568, valid_loss_FFT_Complex: 0.081618
# train_mean_PCC: 0.9998, valid_mean_PCC: 0.9993
# 早停计数器: 2/500 (监控Time损失)
# Epoch 428: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 433: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 444: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 448: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 449: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch: 451/3000, LR: 0.000410, Train Loss: 0.000002, Val Loss: 0.000008
# train_loss_FFT_NP: 5.9785, valid_loss_FFT_NP: 185.8631
# train_loss_FFT_Complex: 0.021593, valid_loss_FFT_Complex: 0.077487
# train_mean_PCC: 0.9998, valid_mean_PCC: 0.9994
# 早停计数器: 2/500 (监控Time损失)
# Epoch 466: 验证Time损失改善 (0.000008 -> 0.000008)，保存最佳模型
# Epoch 470: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 481/3000, LR: 0.000410, Train Loss: 0.000004, Val Loss: 0.000017
# train_loss_FFT_NP: 10.1711, valid_loss_FFT_NP: 172.6923
# train_loss_FFT_Complex: 0.043420, valid_loss_FFT_Complex: 0.168713
# train_mean_PCC: 0.9998, valid_mean_PCC: 0.9993
# 早停计数器: 11/500 (监控Time损失)
# Epoch 496: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 499: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 511/3000, LR: 0.000328, Train Loss: 0.000002, Val Loss: 0.000008
# train_loss_FFT_NP: 7.2412, valid_loss_FFT_NP: 190.5457
# train_loss_FFT_Complex: 0.021662, valid_loss_FFT_Complex: 0.078381
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9994
# 早停计数器: 12/500 (监控Time损失)
# Epoch 516: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 518: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 520: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 524: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 533: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 541: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 541/3000, LR: 0.000328, Train Loss: 0.000002, Val Loss: 0.000007
# train_loss_FFT_NP: 6.5176, valid_loss_FFT_NP: 172.0923
# train_loss_FFT_Complex: 0.018271, valid_loss_FFT_Complex: 0.069320
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9994
# 早停计数器: 0/500 (监控Time损失)
# Epoch 549: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 552: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 560: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 571/3000, LR: 0.000328, Train Loss: 0.000002, Val Loss: 0.000007
# train_loss_FFT_NP: 6.5712, valid_loss_FFT_NP: 184.3458
# train_loss_FFT_Complex: 0.017648, valid_loss_FFT_Complex: 0.072885
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9994
# 早停计数器: 11/500 (监控Time损失)
# Epoch: 601/3000, LR: 0.000262, Train Loss: 0.000002, Val Loss: 0.000007
# train_loss_FFT_NP: 7.3693, valid_loss_FFT_NP: 180.4531
# train_loss_FFT_Complex: 0.016578, valid_loss_FFT_Complex: 0.069920
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9994
# 早停计数器: 41/500 (监控Time损失)
# Epoch 623: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 631/3000, LR: 0.000262, Train Loss: 0.000002, Val Loss: 0.000008
# train_loss_FFT_NP: 10.6862, valid_loss_FFT_NP: 193.2701
# train_loss_FFT_Complex: 0.016729, valid_loss_FFT_Complex: 0.075018
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9994
# 早停计数器: 8/500 (监控Time损失)
# Epoch 650: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 656: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 657: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 661: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 661/3000, LR: 0.000262, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 5.1434, valid_loss_FFT_NP: 171.2981
# train_loss_FFT_Complex: 0.013988, valid_loss_FFT_Complex: 0.065705
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 0/500 (监控Time损失)
# Epoch 675: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch: 691/3000, LR: 0.000262, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 4.9152, valid_loss_FFT_NP: 171.6823
# train_loss_FFT_Complex: 0.013585, valid_loss_FFT_Complex: 0.065530
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 16/500 (监控Time损失)
# Epoch 711: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 715: 验证Time损失改善 (0.000007 -> 0.000007)，保存最佳模型
# Epoch 716: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 721/3000, LR: 0.000210, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 4.5450, valid_loss_FFT_NP: 176.3971
# train_loss_FFT_Complex: 0.013028, valid_loss_FFT_Complex: 0.066298
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9994
# 早停计数器: 5/500 (监控Time损失)
# Epoch: 751/3000, LR: 0.000210, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 5.1225, valid_loss_FFT_NP: 173.8953
# train_loss_FFT_Complex: 0.013517, valid_loss_FFT_Complex: 0.065405
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 35/500 (监控Time损失)
# Epoch 755: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 781/3000, LR: 0.000210, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 4.6426, valid_loss_FFT_NP: 175.9748
# train_loss_FFT_Complex: 0.012238, valid_loss_FFT_Complex: 0.065745
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 26/500 (监控Time损失)
# Epoch 798: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 808: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 811/3000, LR: 0.000168, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 4.2415, valid_loss_FFT_NP: 174.1261
# train_loss_FFT_Complex: 0.011824, valid_loss_FFT_Complex: 0.064659
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 3/500 (监控Time损失)
# Epoch 813: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 841/3000, LR: 0.000168, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 4.3674, valid_loss_FFT_NP: 173.6637
# train_loss_FFT_Complex: 0.011987, valid_loss_FFT_Complex: 0.064450
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 28/500 (监控Time损失)
# Epoch 858: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 871/3000, LR: 0.000168, Train Loss: 0.000001, Val Loss: 0.000007
# train_loss_FFT_NP: 4.1978, valid_loss_FFT_NP: 174.0066
# train_loss_FFT_Complex: 0.011966, valid_loss_FFT_Complex: 0.064937
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 13/500 (监控Time损失)
# Epoch 883: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 887: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 888: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 901/3000, LR: 0.000134, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 4.3399, valid_loss_FFT_NP: 175.5000
# train_loss_FFT_Complex: 0.011090, valid_loss_FFT_Complex: 0.064316
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 13/500 (监控Time损失)
# Epoch: 931/3000, LR: 0.000134, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.3716, valid_loss_FFT_NP: 172.0371
# train_loss_FFT_Complex: 0.010563, valid_loss_FFT_Complex: 0.062875
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 43/500 (监控Time损失)
# Epoch: 961/3000, LR: 0.000134, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 5.2767, valid_loss_FFT_NP: 177.1071
# train_loss_FFT_Complex: 0.011117, valid_loss_FFT_Complex: 0.064200
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 73/500 (监控Time损失)
# Epoch 973: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 980: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 988: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 991/3000, LR: 0.000134, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.3587, valid_loss_FFT_NP: 167.8742
# train_loss_FFT_Complex: 0.010335, valid_loss_FFT_Complex: 0.061125
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 3/500 (监控Time损失)
# Epoch 1005: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1021/3000, LR: 0.000107, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.9465, valid_loss_FFT_NP: 169.2849
# train_loss_FFT_Complex: 0.009796, valid_loss_FFT_Complex: 0.061225
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 16/500 (监控Time损失)
# Epoch: 1051/3000, LR: 0.000107, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.8770, valid_loss_FFT_NP: 170.9463
# train_loss_FFT_Complex: 0.010047, valid_loss_FFT_Complex: 0.061578
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 46/500 (监控Time损失)
# Epoch 1052: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1056: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1071: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1079: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1081/3000, LR: 0.000107, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.7684, valid_loss_FFT_NP: 170.0224
# train_loss_FFT_Complex: 0.009577, valid_loss_FFT_Complex: 0.061221
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 2/500 (监控Time损失)
# Epoch 1097: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1100: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1101: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1111/3000, LR: 0.000086, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 4.9439, valid_loss_FFT_NP: 168.3556
# train_loss_FFT_Complex: 0.009998, valid_loss_FFT_Complex: 0.060458
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 10/500 (监控Time损失)
# Epoch: 1141/3000, LR: 0.000086, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.8806, valid_loss_FFT_NP: 169.2541
# train_loss_FFT_Complex: 0.009320, valid_loss_FFT_Complex: 0.060591
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 40/500 (监控Time损失)
# Epoch: 1171/3000, LR: 0.000086, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.0344, valid_loss_FFT_NP: 165.6565
# train_loss_FFT_Complex: 0.009222, valid_loss_FFT_Complex: 0.059359
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 70/500 (监控Time损失)
# Epoch 1192: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1193: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1201/3000, LR: 0.000069, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.7741, valid_loss_FFT_NP: 163.2938
# train_loss_FFT_Complex: 0.009230, valid_loss_FFT_Complex: 0.058578
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 8/500 (监控Time损失)
# Epoch: 1231/3000, LR: 0.000069, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.8107, valid_loss_FFT_NP: 166.8145
# train_loss_FFT_Complex: 0.008970, valid_loss_FFT_Complex: 0.059492
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 38/500 (监控Time损失)
# Epoch: 1261/3000, LR: 0.000069, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.2547, valid_loss_FFT_NP: 163.3969
# train_loss_FFT_Complex: 0.008793, valid_loss_FFT_Complex: 0.058290
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 68/500 (监控Time损失)
# Epoch: 1291/3000, LR: 0.000069, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5057, valid_loss_FFT_NP: 165.3932
# train_loss_FFT_Complex: 0.008462, valid_loss_FFT_Complex: 0.058804
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 98/500 (监控Time损失)
# Epoch: 1321/3000, LR: 0.000055, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.6677, valid_loss_FFT_NP: 163.6828
# train_loss_FFT_Complex: 0.008867, valid_loss_FFT_Complex: 0.058219
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 128/500 (监控Time损失)
# Epoch 1331: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1342: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1351/3000, LR: 0.000055, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.4948, valid_loss_FFT_NP: 164.8968
# train_loss_FFT_Complex: 0.008678, valid_loss_FFT_Complex: 0.058434
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 9/500 (监控Time损失)
# Epoch: 1381/3000, LR: 0.000055, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.0443, valid_loss_FFT_NP: 166.0281
# train_loss_FFT_Complex: 0.008439, valid_loss_FFT_Complex: 0.058725
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 39/500 (监控Time损失)
# Epoch: 1411/3000, LR: 0.000044, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5497, valid_loss_FFT_NP: 163.5855
# train_loss_FFT_Complex: 0.008215, valid_loss_FFT_Complex: 0.057887
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 69/500 (监控Time损失)
# Epoch: 1441/3000, LR: 0.000044, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4235, valid_loss_FFT_NP: 164.6613
# train_loss_FFT_Complex: 0.008112, valid_loss_FFT_Complex: 0.058154
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 99/500 (监控Time损失)
# Epoch 1470: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1471/3000, LR: 0.000044, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.3716, valid_loss_FFT_NP: 167.6426
# train_loss_FFT_Complex: 0.008401, valid_loss_FFT_Complex: 0.058911
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 1/500 (监控Time损失)
# Epoch 1490: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1497: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1501/3000, LR: 0.000035, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5205, valid_loss_FFT_NP: 165.1312
# train_loss_FFT_Complex: 0.008255, valid_loss_FFT_Complex: 0.058178
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 4/500 (监控Time损失)
# Epoch 1515: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1531/3000, LR: 0.000035, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.9901, valid_loss_FFT_NP: 162.8052
# train_loss_FFT_Complex: 0.008114, valid_loss_FFT_Complex: 0.057457
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 16/500 (监控Time损失)
# Epoch 1535: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1541: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1561/3000, LR: 0.000035, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 3.0051, valid_loss_FFT_NP: 163.3131
# train_loss_FFT_Complex: 0.008096, valid_loss_FFT_Complex: 0.057517
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 20/500 (监控Time损失)
# Epoch: 1591/3000, LR: 0.000035, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 4.0542, valid_loss_FFT_NP: 166.5263
# train_loss_FFT_Complex: 0.008283, valid_loss_FFT_Complex: 0.058315
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 50/500 (监控Time损失)
# Epoch: 1621/3000, LR: 0.000028, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.6505, valid_loss_FFT_NP: 163.8574
# train_loss_FFT_Complex: 0.007788, valid_loss_FFT_Complex: 0.057461
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 80/500 (监控Time损失)
# Epoch 1624: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1651/3000, LR: 0.000028, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5035, valid_loss_FFT_NP: 164.5665
# train_loss_FFT_Complex: 0.007766, valid_loss_FFT_Complex: 0.057719
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 27/500 (监控Time损失)
# Epoch 1660: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1681/3000, LR: 0.000028, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.7614, valid_loss_FFT_NP: 162.1635
# train_loss_FFT_Complex: 0.007806, valid_loss_FFT_Complex: 0.056868
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 21/500 (监控Time损失)
# Epoch 1690: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1711/3000, LR: 0.000023, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3367, valid_loss_FFT_NP: 162.2148
# train_loss_FFT_Complex: 0.007596, valid_loss_FFT_Complex: 0.056822
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 21/500 (监控Time损失)
# Epoch: 1741/3000, LR: 0.000023, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5137, valid_loss_FFT_NP: 161.7558
# train_loss_FFT_Complex: 0.007717, valid_loss_FFT_Complex: 0.056640
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 51/500 (监控Time损失)
# Epoch: 1771/3000, LR: 0.000023, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4743, valid_loss_FFT_NP: 162.1139
# train_loss_FFT_Complex: 0.007574, valid_loss_FFT_Complex: 0.056692
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 81/500 (监控Time损失)
# Epoch: 1801/3000, LR: 0.000018, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3716, valid_loss_FFT_NP: 163.6652
# train_loss_FFT_Complex: 0.007519, valid_loss_FFT_Complex: 0.057147
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 111/500 (监控Time损失)
# Epoch: 1831/3000, LR: 0.000018, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.6855, valid_loss_FFT_NP: 160.7733
# train_loss_FFT_Complex: 0.007499, valid_loss_FFT_Complex: 0.056203
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 141/500 (监控Time损失)
# Epoch: 1861/3000, LR: 0.000018, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3102, valid_loss_FFT_NP: 162.4174
# train_loss_FFT_Complex: 0.007437, valid_loss_FFT_Complex: 0.056657
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 171/500 (监控Time损失)
# Epoch 1862: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1867: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1891/3000, LR: 0.000018, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1711, valid_loss_FFT_NP: 163.4660
# train_loss_FFT_Complex: 0.007349, valid_loss_FFT_Complex: 0.056939
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 24/500 (监控Time损失)
# Epoch: 1921/3000, LR: 0.000014, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2915, valid_loss_FFT_NP: 161.5592
# train_loss_FFT_Complex: 0.007282, valid_loss_FFT_Complex: 0.056333
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 54/500 (监控Time损失)
# Epoch 1923: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 1943: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1951/3000, LR: 0.000014, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2026, valid_loss_FFT_NP: 162.4346
# train_loss_FFT_Complex: 0.007263, valid_loss_FFT_Complex: 0.056598
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 8/500 (监控Time损失)
# Epoch 1962: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 1981/3000, LR: 0.000014, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.6643, valid_loss_FFT_NP: 161.6314
# train_loss_FFT_Complex: 0.007394, valid_loss_FFT_Complex: 0.056275
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 19/500 (监控Time损失)
# Epoch 2011: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2011/3000, LR: 0.000012, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2776, valid_loss_FFT_NP: 160.1611
# train_loss_FFT_Complex: 0.007190, valid_loss_FFT_Complex: 0.055786
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 0/500 (监控Time损失)
# Epoch 2012: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2030: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2041/3000, LR: 0.000012, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1370, valid_loss_FFT_NP: 160.7769
# train_loss_FFT_Complex: 0.007179, valid_loss_FFT_Complex: 0.055945
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 11/500 (监控Time损失)
# Epoch: 2071/3000, LR: 0.000012, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4473, valid_loss_FFT_NP: 162.1987
# train_loss_FFT_Complex: 0.007181, valid_loss_FFT_Complex: 0.056344
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 41/500 (监控Time损失)
# Epoch 2075: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2076: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2101/3000, LR: 0.000009, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2728, valid_loss_FFT_NP: 162.0505
# train_loss_FFT_Complex: 0.007123, valid_loss_FFT_Complex: 0.056275
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 25/500 (监控Time损失)
# Epoch: 2131/3000, LR: 0.000009, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2995, valid_loss_FFT_NP: 161.2303
# train_loss_FFT_Complex: 0.007161, valid_loss_FFT_Complex: 0.056005
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 55/500 (监控Time损失)
# Epoch: 2161/3000, LR: 0.000009, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2828, valid_loss_FFT_NP: 160.6557
# train_loss_FFT_Complex: 0.007075, valid_loss_FFT_Complex: 0.055805
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 85/500 (监控Time损失)
# Epoch 2175: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2176: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2182: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2191/3000, LR: 0.000009, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4937, valid_loss_FFT_NP: 162.4492
# train_loss_FFT_Complex: 0.007197, valid_loss_FFT_Complex: 0.056318
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 9/500 (监控Time损失)
# Epoch: 2221/3000, LR: 0.000007, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4920, valid_loss_FFT_NP: 160.9697
# train_loss_FFT_Complex: 0.007163, valid_loss_FFT_Complex: 0.055844
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 39/500 (监控Time损失)
# Epoch: 2251/3000, LR: 0.000007, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.7206, valid_loss_FFT_NP: 161.9973
# train_loss_FFT_Complex: 0.007131, valid_loss_FFT_Complex: 0.056131
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 69/500 (监控Time损失)
# Epoch: 2281/3000, LR: 0.000007, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2245, valid_loss_FFT_NP: 160.9274
# train_loss_FFT_Complex: 0.006984, valid_loss_FFT_Complex: 0.055787
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 99/500 (监控Time损失)
# Epoch 2290: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2311/3000, LR: 0.000006, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.6018, valid_loss_FFT_NP: 161.5364
# train_loss_FFT_Complex: 0.007101, valid_loss_FFT_Complex: 0.055940
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 21/500 (监控Time损失)
# Epoch: 2341/3000, LR: 0.000006, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5255, valid_loss_FFT_NP: 161.2497
# train_loss_FFT_Complex: 0.007061, valid_loss_FFT_Complex: 0.055840
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 51/500 (监控Time损失)
# Epoch 2359: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2371/3000, LR: 0.000006, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1603, valid_loss_FFT_NP: 160.3809
# train_loss_FFT_Complex: 0.006909, valid_loss_FFT_Complex: 0.055563
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 12/500 (监控Time损失)
# Epoch 2383: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2401/3000, LR: 0.000005, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.5027, valid_loss_FFT_NP: 161.4266
# train_loss_FFT_Complex: 0.007019, valid_loss_FFT_Complex: 0.055857
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 18/500 (监控Time损失)
# Epoch: 2431/3000, LR: 0.000005, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1799, valid_loss_FFT_NP: 160.9661
# train_loss_FFT_Complex: 0.006951, valid_loss_FFT_Complex: 0.055704
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 48/500 (监控Time损失)
# Epoch 2442: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2461/3000, LR: 0.000005, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4162, valid_loss_FFT_NP: 161.2909
# train_loss_FFT_Complex: 0.006965, valid_loss_FFT_Complex: 0.055791
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 19/500 (监控Time损失)
# Epoch: 2491/3000, LR: 0.000005, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1685, valid_loss_FFT_NP: 160.8161
# train_loss_FFT_Complex: 0.006887, valid_loss_FFT_Complex: 0.055627
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 49/500 (监控Time损失)
# Epoch: 2521/3000, LR: 0.000004, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2840, valid_loss_FFT_NP: 160.3619
# train_loss_FFT_Complex: 0.006863, valid_loss_FFT_Complex: 0.055474
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 79/500 (监控Time损失)
# Epoch: 2551/3000, LR: 0.000004, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3916, valid_loss_FFT_NP: 160.8588
# train_loss_FFT_Complex: 0.006899, valid_loss_FFT_Complex: 0.055602
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 109/500 (监控Time损失)
# Epoch: 2581/3000, LR: 0.000004, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.0995, valid_loss_FFT_NP: 160.9155
# train_loss_FFT_Complex: 0.006810, valid_loss_FFT_Complex: 0.055603
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 139/500 (监控Time损失)
# Epoch: 2611/3000, LR: 0.000003, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3574, valid_loss_FFT_NP: 160.5685
# train_loss_FFT_Complex: 0.006878, valid_loss_FFT_Complex: 0.055489
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 169/500 (监控Time损失)
# Epoch: 2641/3000, LR: 0.000003, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.6148, valid_loss_FFT_NP: 160.4319
# train_loss_FFT_Complex: 0.006926, valid_loss_FFT_Complex: 0.055432
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 199/500 (监控Time损失)
# Epoch: 2671/3000, LR: 0.000003, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.2268, valid_loss_FFT_NP: 161.1362
# train_loss_FFT_Complex: 0.006846, valid_loss_FFT_Complex: 0.055632
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 229/500 (监控Time损失)
# Epoch: 2701/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4321, valid_loss_FFT_NP: 161.1265
# train_loss_FFT_Complex: 0.006819, valid_loss_FFT_Complex: 0.055617
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 259/500 (监控Time损失)
# Epoch 2709: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2710: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2722: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch 2723: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2731/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.7205, valid_loss_FFT_NP: 160.9584
# train_loss_FFT_Complex: 0.006983, valid_loss_FFT_Complex: 0.055569
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 8/500 (监控Time损失)
# Epoch: 2761/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1094, valid_loss_FFT_NP: 160.4401
# train_loss_FFT_Complex: 0.006758, valid_loss_FFT_Complex: 0.055389
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 38/500 (监控Time损失)
# Epoch: 2791/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.0438, valid_loss_FFT_NP: 160.7740
# train_loss_FFT_Complex: 0.006752, valid_loss_FFT_Complex: 0.055475
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 68/500 (监控Time损失)
# Epoch: 2821/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.4002, valid_loss_FFT_NP: 160.5966
# train_loss_FFT_Complex: 0.006867, valid_loss_FFT_Complex: 0.055423
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 98/500 (监控Time损失)
# Epoch: 2851/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3637, valid_loss_FFT_NP: 160.1787
# train_loss_FFT_Complex: 0.006737, valid_loss_FFT_Complex: 0.055280
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 128/500 (监控Time损失)
# Epoch: 2881/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.0987, valid_loss_FFT_NP: 160.3420
# train_loss_FFT_Complex: 0.006713, valid_loss_FFT_Complex: 0.055320
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 158/500 (监控Time损失)
# Epoch 2891: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
# Epoch: 2911/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.1707, valid_loss_FFT_NP: 159.9964
# train_loss_FFT_Complex: 0.006723, valid_loss_FFT_Complex: 0.055209
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 20/500 (监控Time损失)
# Epoch: 2941/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.0507, valid_loss_FFT_NP: 160.2242
# train_loss_FFT_Complex: 0.006680, valid_loss_FFT_Complex: 0.055269
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 50/500 (监控Time损失)
# Epoch: 2971/3000, LR: 0.000002, Train Loss: 0.000001, Val Loss: 0.000006
# train_loss_FFT_NP: 2.3679, valid_loss_FFT_NP: 160.2906
# train_loss_FFT_Complex: 0.006799, valid_loss_FFT_Complex: 0.055279
# train_mean_PCC: 0.9999, valid_mean_PCC: 0.9995
# 早停计数器: 80/500 (监控Time损失)
# Epoch 2993: 验证Time损失改善 (0.000006 -> 0.000006)，保存最佳模型
#
# 训练完成, 加载最佳模型(验证Time损失: 0.0000)

# %%
def Forward_Model_Loss(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP, font='Times new roman', font_size=22, line_width=2):
    """
    绘制训练和验证损失函数图,并同时绘制PCC和FFT值。

    参数：
    train_losses (list): 训练损失值列表。
    val_losses (list): 验证损失值列表。
    train_pccs (list): 训练PCC值列表。
    valid_pccs (list): 验证PCC值列表。
    train_ffts (list): 训练FFT值列表。
    valid_ffts (list): 验证FFT值列表。
    font (str): 字体，默认为 'Arial'。
    font_size (int): 字号，默认为 12。
    line_width (float): 线条粗细，默认为 2。
    """

    # 创建主图
    plt.figure(figsize=(12, 8))
    ax1 = plt.gca()  # 获取当前主图的轴对象

    # 绘制损失
    ax1.plot(train_losses, label='Training_Time_domain_Loss', color='red', linewidth=line_width, marker='o')
    ax1.plot(val_losses, label='Validation_Time_domain_Loss', color='red', linewidth=line_width, linestyle='--', marker='s')

    # 设置主图的标签和标题
    ax1.set_xlabel('Epochs', fontname=font, fontsize=font_size)
    ax1.set_ylabel('Time-domain_Loss', fontname=font, fontsize=font_size, color='red')
    ax1.tick_params(axis='both', which='major',labelcolor='red', labelsize=font_size)

    # 创建第二个Y轴
    ax2 = ax1.twinx()
    ax2.plot(train_FFT_Complex, label='Validation_FFT_Complex_Loss', color='green', linewidth=line_width, marker='o')
    ax2.plot(valid_FFT_Complex, label='Validation_FFT_Complex_Loss', color='green', linewidth=line_width, linestyle='--', marker='s')
    ax2.set_ylabel('FFT_Complex_Loss', fontname=font, fontsize=font_size, color='green')
    ax2.tick_params(axis='y', which='major',labelcolor='green', labelsize=font_size)

    # 创建第三个Y轴
    ax3 = ax1.twinx()
    ax3.spines['right'].set_position(('outward', 100))  # 将第三个Y轴向右移动
    ax3.plot(train_FFT_NP, label='Training_FFT_NP_Loss', color='black', linewidth=line_width, marker='o')
    ax3.plot(valid_FFT_NP, label='Validation_FFT_NP_Loss', color='black', linewidth=line_width, linestyle='--', marker='s')
    ax3.set_ylabel('FFT_NP_Loss', fontname=font, fontsize=font_size, color='black')
    ax3.tick_params(axis='y', which='major',labelcolor='black', labelsize=font_size)

    # 创建第四个Y轴
    ax4 = ax1.twinx()
    ax4.spines['right'].set_position(('outward', 200))  # 将第四个Y轴向右移动
    ax4.plot(train_PCC, label='Training_PCC', color='blue', linewidth=line_width, marker='o')
    ax4.plot(valid_PCC, label='Validation_PCC', color='blue', linewidth=line_width, linestyle='--', marker='s')
    ax4.set_ylabel('PCC', fontname=font, fontsize=font_size, color='blue')
    ax4.tick_params(axis='y', which='major',labelcolor='blue', labelsize=font_size)

    # 将图例放在一起
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    lines3, labels3 = ax3.get_legend_handles_labels()
    lines4, labels4 = ax4.get_legend_handles_labels()
    ax1.legend(lines + lines2 + lines3 + lines4, labels + labels2 + labels3 + labels4, loc=(0.1,0.2), fontsize=font_size)

    # 保存图像
    plt.savefig(f'{save_path}Forward_Model_PDD_Loss.jpg', dpi=300, bbox_inches='tight')
    plt.show()

# 调用函数，传入你的数据
Forward_Model_Loss(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP)

# %%
torch.save(model, f'{save_path}Forward_Model_PDD.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
def Model_Loss_Enlargement_Time(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP, font='Times new roman', font_size=22, line_width=2):
    """
    绘制训练和验证损失函数图,并同时绘制PCC和FFT值。

    参数：
    train_losses (list): 训练损失值列表。
    val_losses (list): 验证损失值列表。
    train_pccs (list): 训练PCC值列表。
    valid_pccs (list): 验证PCC值列表。
    train_ffts (list): 训练FFT值列表。
    valid_ffts (list): 验证FFT值列表。
    font (str): 字体，默认为 'Arial'。
    font_size (int): 字号，默认为 12。
    line_width (float): 线条粗细，默认为 2。
    """
    # 创建主图
    plt.figure(figsize=(12, 8))
    ax1 = plt.gca()  # 获取当前主图的轴对象

    # 绘制损失
    ax1.plot(train_losses, label='Training_Time-domain Loss', color='red', linewidth=line_width, marker='o')
    ax1.plot(val_losses, label='Validation_Time-domain Loss', color='red', linewidth=line_width, linestyle='--', marker='s')

    # 设置主图的标签和标题
    ax1.set_xlabel('Epochs', fontname=font, fontsize=font_size)
    ax1.set_ylabel('Time_domain_Loss', fontname=font, fontsize=font_size, color='red')
    ax1.tick_params(axis='both', which='major',labelcolor='red', labelsize=font_size)
    plt.xlim(epochs*0.8,epochs)
    plt.ylim(1e-7,0.8e-5)

    # 保存图像
    plt.savefig(f'{save_path}Time_Loss_Enlargement_PDD.jpg', dpi=300, bbox_inches='tight')
    plt.show()

# 调用函数，传入你的数据
Model_Loss_Enlargement_Time(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP)

# %%
def Model_Loss_Enlargement_Frequency(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP, font='Times new roman', font_size=22, line_width=2):
    """
    绘制训练和验证损失函数图,并同时绘制PCC和FFT值。

    参数：
    train_losses (list): 训练损失值列表。
    val_losses (list): 验证损失值列表。
    train_pccs (list): 训练PCC值列表。
    valid_pccs (list): 验证PCC值列表。
    train_ffts (list): 训练FFT值列表。
    valid_ffts (list): 验证FFT值列表。
    font (str): 字体，默认为 'Arial'。
    font_size (int): 字号，默认为 12。
    line_width (float): 线条粗细，默认为 2。
    """
    # 创建主图
    plt.figure(figsize=(12, 8))
    ax1 = plt.gca()  # 获取当前主图的轴对象
    ax1.plot(train_FFT_Complex, label='Training_FFT_Complex_Loss', color='green', linewidth=line_width, marker='o')
    ax1.plot(valid_FFT_Complex, label='Validation_FFT_Complex_Loss', color='green', linewidth=line_width, linestyle='--', marker='s')
    ax1.set_ylabel('FFT_Complex_Loss', fontname=font, fontsize=font_size, color='green')
    ax1.tick_params(axis='x', which='major',labelcolor='green', labelsize=font_size)
    ax1.tick_params(axis='y', which='major',labelcolor='green', labelsize=font_size)
    plt.xlim(epochs*0.8,epochs)
    plt.ylim(0,0.6e-1)

    ax2 = ax1.twinx()
    ax2.plot(train_FFT_NP, label='Training_FFT_NP_Loss', color='black', linewidth=line_width, marker='o')
    ax2.plot(valid_FFT_NP, label='Validation_FFT_NP_Loss', color='black', linewidth=line_width, linestyle='--', marker='s')
    ax2.set_ylabel('FFT_NP_Loss', fontname=font, fontsize=font_size, color='black')
    ax2.tick_params(axis='y', which='major',labelcolor='black', labelsize=font_size)
    plt.xlim(epochs*0.8,epochs)
    plt.ylim(0,2e2)

    # 保存图像
    plt.savefig(f'{save_path}FFT_Loss_Enlargement_PDD.jpg', dpi=300, bbox_inches='tight')
    plt.show()

# 调用函数，传入你的数据
Model_Loss_Enlargement_Frequency(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP)

# %%
def Model_Loss_Enlargement_PCC(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP, font='Times new roman', font_size=22, line_width=2):
    """
    绘制训练和验证损失函数图,并同时绘制PCC和FFT值。

    参数：
    train_losses (list): 训练损失值列表。
    val_losses (list): 验证损失值列表。
    train_pccs (list): 训练PCC值列表。
    valid_pccs (list): 验证PCC值列表。
    train_ffts (list): 训练FFT值列表。
    valid_ffts (list): 验证FFT值列表。
    font (str): 字体，默认为 'Arial'。
    font_size (int): 字号，默认为 12。
    line_width (float): 线条粗细，默认为 2。
    """
    # 创建主图
    plt.figure(figsize=(12, 8))
    ax1 = plt.gca()  # 获取当前主图的轴对象
    ax1.plot(train_PCC, label='Training PCC', color='black', linewidth=line_width, marker='o')
    ax1.plot(valid_PCC, label='Validation PCC', color='black', linewidth=line_width, linestyle='--', marker='s')
    ax1.set_ylabel('PCC', fontname=font, fontsize=font_size, color='black')
    ax1.tick_params(axis='x', which='major',labelcolor='black', labelsize=font_size)
    ax1.tick_params(axis='y', which='major',labelcolor='black', labelsize=font_size)

    plt.xlim(epochs*0.8,epochs)
    #plt.ylim(0.9998,1)

    # 保存图像
    plt.savefig(f'{save_path}PCC_Loss_Enlargement_PDD.jpg', dpi=300, bbox_inches='tight')
    plt.show()

# 调用函数，传入你的数据
Model_Loss_Enlargement_PCC(train_losses, val_losses, train_PCC, valid_PCC, train_FFT_Complex, valid_FFT_Complex, train_FFT_NP, valid_FFT_NP)
