# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pandas as pd
import pywt
import torch.optim as optim
import glob
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
# 检查CUDA是否可用
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

Main_path = 'D:\\Desktop\\Desktop\\Python\\Forward_and_Inverse_problem\\'
Data_path = f'{Main_path}Data\\'
Save_path = f'{Main_path}Nonlinear_verification\\Python_nonlinear_verification4\\'
# Out:
# Using device: cuda:0

# %%
M = 9900
A = 1
data = []
labels = []
skipped_files = []  # 记录跳过的文件

# 拿到数据路径，方便后续读取
dir_path = f'{Data_path}Experiment_signal'
dataPaths = sorted(glob.glob(os.path.join(dir_path, '**', '*.csv'), recursive=True))
random.seed(42)
random.shuffle(dataPaths)

# 遍历读取数据
for dataPath in dataPaths:
    # 读取数据（先读取，后验证）
    data_1 = pd.read_csv(dataPath)
    
    # 检查第一列的每一行，找到第一个大于0的值的位置N
    N = 0
    for i in range(len(data_1)):
        if data_1.iloc[i, 1] != 0:
            N = i
            break
    
    # 【关键修复】先验证数据长度，不够就跳过整个文件
    if N >= len(data_1) - M + 1:
        filename = os.path.basename(dataPath)
        print(f"警告：跳过 {filename} - 数据不足(可用{len(data_1)-N}点，需要{M}点)")
        skipped_files.append(filename)
        continue  # 跳过这个文件，data和labels都不添加
    
    # 只有数据足够时，才提取数据和标签
    data.append(data_1.iloc[N:N+M, 1].values)
    
    # 提取标签（移到验证之后）
    filename = os.path.basename(dataPath)
    parts = filename.split('_')
    label1 = float(parts[2])
    label2 = float(parts[3])
    labels.append([label1, label2])

print(f"\n处理完成：成功{len(data)}个，跳过{len(skipped_files)}个")

# 转换为numpy数组
all_datas = np.array(data, dtype="float")
all_labels = np.array(labels)

# 划分数据集（现在不会报错了）
train_datas, temp_datas, train_labels, temp_labels = train_test_split(
    all_datas, all_labels, test_size=0.3, random_state=42
)

validation_datas, test_datas, validation_labels, test_labels = train_test_split(
    temp_datas, temp_labels, test_size=2/3, random_state=42
)

print("训练集数据形状:", train_datas.shape)
print("验证集数据形状:", validation_datas.shape)
print("测试集数据形状:", test_datas.shape)
# Out:
# 处理完成：成功864个，跳过0个
# 训练集数据形状: (604, 9900)
# 验证集数据形状: (86, 9900)
# 测试集数据形状: (174, 9900)

# %%
train_datas = train_datas.reshape(-1,train_datas.shape[1],1)
validation_datas = validation_datas.reshape(-1,validation_datas.shape[1],1)

print(f'train_datas.shape:{train_datas.shape}')
print(f'validation_datas.shape:{validation_datas.shape}')
# Out:
# train_datas.shape:(604, 9900, 1)
# validation_datas.shape:(86, 9900, 1)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(train_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}train_signal.jpg', dpi=600, bbox_inches='tight')

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
plt.rcParams['font.family'] = ['Times New Roman']
plt.plot(validation_datas[1],linewidth=1.5)
plt.xlabel('Sample point',fontdict={'weight': 'normal', 'size': 18})
plt.ylabel('Amplitude(V)',fontdict={'weight': 'normal', 'size': 18})
#坐标轴刻度大小设置s
plt.tick_params(axis='both', which='major', labelsize=15)
plt.xlim([0,M])
plt.savefig(f'{Save_path}validation_signal.jpg', dpi=600, bbox_inches='tight')

# %%
BATCH_SIZE = 32
input_size = 625
hidden_size = 64
num_layers = 2
output_size = 2
EPOCH = 1000
learning_rate = 1e-3

# %%
# 准备数据
#torch.from_numpy将 NumPy 数组转换为 PyTorch 张量
#TensorDataset用于将张量数据和标签组合成一个数据集
#DataLoader用于从数据集中加载批次数据，并进行训练或测试

train_dataset = TensorDataset(torch.from_numpy(train_datas),torch.from_numpy(train_labels))
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_dataset = TensorDataset(torch.from_numpy(validation_datas),torch.from_numpy(validation_labels))
validation_loader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
class ConvAutoencoderPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout_rate):
        super().__init__()
        self.input_size = input_size
        self.device = device
        
        # ---------- 卷积编码器 ----------
        self.encoder = nn.Sequential(
            nn.Conv1d(input_size, hidden_size*4, 5, stride=2, padding=2),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Conv1d(hidden_size*4, hidden_size*2, 3, stride=2, padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Conv1d(hidden_size*2, hidden_size, 3, stride=1, padding=1),
            nn.BatchNorm1d(hidden_size), nn.ReLU(), nn.Dropout(dropout_rate),
        )

        # ---------- 卷积解码器 ----------
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(hidden_size, hidden_size*2, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*2), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(hidden_size*2, hidden_size*4, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm1d(hidden_size*4), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(hidden_size*4, input_size, 5, stride=1, padding=2),
        )

        # ---------- 2 层双向 LSTM ----------
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            bidirectional=True,
                            dropout=dropout_rate if num_layers > 1 else 0,
                            batch_first=False)
        
        self.dropout_layer = nn.Dropout(dropout_rate)
        self.regressor = nn.Linear(2 * hidden_size, output_size)

    def forward(self, x):
        wavelet = 'db4'
        # 将张量移动至CPU上面
        x1 = x.cpu()

        # 将CPU张量转化为numpy
        x2 = x1.numpy()
        # 离散小波分解
        coeffs = pywt.wavedec(x2, wavelet, level=6)
        xh1 = coeffs[6]
        xh2 = coeffs[5]
        xh3 = coeffs[4]
        xh4 = coeffs[3]
        xh5 = coeffs[2]
        xh6 = coeffs[1]
        xl6 = coeffs[0]
        # 连接分解后的序列
        x3 = xh4

        x4 = torch.from_numpy(x3)
        x5 = x4.to(device)
        
        x_conv = x5.permute(0, 2, 1)
        encoded = self.encoder(x_conv)
        decoded = self.decoder(encoded)

        out = decoded.view(decoded.size(0), -1)
        out = out.view(out.size(0), -1, self.input_size)

        lstm_out, _ = self.lstm(out) 
        lstm_out = lstm_out[:, -1, :]

        out = self.dropout_layer(lstm_out)
        out = self.regressor(out)  
        return out

# %%
#模型实例化
model = ConvAutoencoderPredictor(input_size, hidden_size, output_size, num_layers,dropout_rate = 0.0)
model.to(device)
loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
#两个空列表用于存储训练和验证中的损失值
train_loss_force_epoch = []
train_loss_HI_epoch = []

#两个空列表用于存储训练和验证中的损失值
validation_loss_force_epoch = []
validation_loss_HI_epoch = []

# %%
def train_and_validate(model, train_loader, validation_loader, optimizer, loss, device, EPOCH, A, patience=500):
    """
    训练和验证模型的函数

    参数:
    model: 要训练的模型
    train_loader: 训练数据加载器
    validation_loader: 验证数据加载器
    optimizer: 优化器
    loss: 损失函数
    device: 运行设备（如 'cuda' 或 'cpu')
    EPOCH: 训练的总轮数
    A: HI 损失的权重系数
    patience: 早停的耐心值，即在多少个epoch内验证损失没有改善时停止训练
    """
    # 添加学习率调度器 - 每100个epoch衰减为原来的0.8
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
    
    # 早停相关变量 - 使用总验证损失作为监控指标
    best_val_total_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    # 记录各项损失
    train_loss_force_epoch = []
    train_loss_HI_epoch = []
    validation_loss_force_epoch = []
    validation_loss_HI_epoch = []
    
    # 记录各个指标的列表
    train_force_losses = []
    train_HI_losses = []
    val_force_losses = []
    val_HI_losses = []
    
    for epoch in range(EPOCH):
        # 训练步骤开始
        model.train()
        train_force_epoch = 0.0
        train_HI_epoch = 0.0
        train_force_batch = 0.0
        train_HI_batch = 0.0
        
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()

            x1 = x.type(torch.FloatTensor)
            x2 = x1.permute(0, 2, 1)

            force1 = y[:, 0].type(torch.FloatTensor)
            HI1 = y[:, 1].type(torch.FloatTensor)

            x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

            force_hat = model(x3)[:, 0]
            HI_hat = model(x3)[:, 1]

            train_loss_force = loss(force_hat.flatten(), force2.flatten())
            train_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

            train_loss_force.backward()
            train_loss_HI.backward()

            optimizer.step()

            train_force_epoch += train_loss_force.item() * x3.size(0)
            train_HI_epoch += train_loss_HI.item() * x3.size(0)
            train_force_batch += train_loss_force.item()
            train_HI_batch += train_loss_HI.item()

        # 更新学习率
        scheduler.step()
        
        # 计算平均训练损失
        train_mean_force = train_force_epoch / len(train_loader.dataset)
        train_loss_force_epoch.append(train_mean_force)
        train_force_losses.append(train_force_batch / len(train_loader))

        train_mean_HI = train_HI_epoch / len(train_loader.dataset)
        train_loss_HI_epoch.append(train_mean_HI)
        train_HI_losses.append(train_HI_batch / len(train_loader))

        # 验证步骤开始
        model.eval()
        validation_force_epoch = 0.0
        validation_HI_epoch = 0.0
        val_force_batch = 0.0
        val_HI_batch = 0.0

        with torch.no_grad():
            for i, (x, y) in enumerate(validation_loader):
                x1 = x.type(torch.FloatTensor)
                x2 = x1.permute(0, 2, 1)

                force1 = y[:, 0].type(torch.FloatTensor)
                HI1 = y[:, 1].type(torch.FloatTensor)

                x3, force2, HI2 = x2.to(device), force1.to(device), HI1.to(device)

                force_hat = model(x3)[:, 0]
                HI_hat = model(x3)[:, 1]

                validation_loss_force = loss(force_hat.flatten(), force2.flatten())
                validation_loss_HI = A * loss(HI_hat.flatten(), HI2.flatten())

                validation_force_epoch += validation_loss_force.item() * x3.size(0)
                validation_HI_epoch += validation_loss_HI.item() * x3.size(0)
                val_force_batch += validation_loss_force.item()
                val_HI_batch += validation_loss_HI.item()

        # 计算平均验证损失
        validation_mean_force = validation_force_epoch / len(validation_loader.dataset)
        validation_loss_force_epoch.append(validation_mean_force)
        val_force_losses.append(val_force_batch / len(validation_loader))

        validation_mean_HI = validation_HI_epoch / len(validation_loader.dataset)
        validation_loss_HI_epoch.append(validation_mean_HI)
        val_HI_losses.append(val_HI_batch / len(validation_loader))
        
        # 计算总验证损失用于早停监控
        total_val_loss = validation_mean_force

        # 早停检查 - 使用总验证损失作为监控指标
        if total_val_loss < best_val_total_loss:
            best_val_total_loss = total_val_loss
            patience_counter = 0
            # 保存最佳模型状态
            best_model_state = model.state_dict().copy()
            # 仅在验证损失改善时打印信息
            if epoch % (EPOCH//100) == 0:
                print(f"Epoch {epoch+1}: 验证总损失改善 ({total_val_loss:.4f} -> {best_val_total_loss:.4f})，保存最佳模型")
        else:
            patience_counter += 1
            
            # 检查是否触发早停
            if patience_counter >= patience:
                print(f"\n早停触发！连续 {patience} 个epoch验证总损失未改善")
                print(f"最佳验证总损失: {best_val_total_loss:.4f} (epoch {epoch+1-patience})")
                break

        # 每10个epoch打印一次训练信息
        if epoch % (EPOCH//100) == 0:
            current_lr = scheduler.get_last_lr()[0]
            print(f"\nEpoch {epoch+1}/{EPOCH}, LR: {current_lr:.6f}")
            print(f"Train - Force Loss: {train_mean_force:.4f}, HI Loss: {train_mean_HI:.4f}")
            print(f"Valid - Force Loss: {validation_mean_force:.4f}, HI Loss: {validation_mean_HI:.4f}")
            print(f"Valid Total Loss: {total_val_loss:.4f}, Best: {best_val_total_loss:.4f}")
            print(f"早停计数器: {patience_counter}/{patience} (监控总验证损失)")

    # 加载最佳模型
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n训练完成，加载最佳模型（验证总损失: {best_val_total_loss:.4f})")
    else:
        print("\n训练完成，但未找到最佳模型")
    
    return train_force_losses, train_HI_losses, val_force_losses, val_HI_losses

# %%
# 假设你已经定义了模型、数据加载器、优化器、损失函数、设备等
train_loss_force, train_loss_HI, validation_loss_force, validation_loss_HI = train_and_validate(
    model=model,
    train_loader = train_loader,
    validation_loader = validation_loader,
    optimizer = optimizer,
    loss = loss,
    device = device,
    EPOCH = EPOCH,
    A = A,
    patience = 500  # 早停耐心值设为500个epoch
)
# Out:
# Epoch 1: 验证总损失改善 (50.2798 -> 50.2798)，保存最佳模型
#
# Epoch 1/1000, LR: 0.001000
# Train - Force Loss: 85.9303, HI Loss: 0.0572
# Valid - Force Loss: 50.2798, HI Loss: 0.0382
# Valid Total Loss: 50.2798, Best: 50.2798
# 早停计数器: 0/500 (监控总验证损失)
# Epoch 11: 验证总损失改善 (24.2948 -> 24.2948)，保存最佳模型
#
# Epoch 11/1000, LR: 0.001000
# Train - Force Loss: 25.3965, HI Loss: 0.0268
# Valid - Force Loss: 24.2948, HI Loss: 0.0237
# Valid Total Loss: 24.2948, Best: 24.2948
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 21/1000, LR: 0.001000
# Train - Force Loss: 15.1433, HI Loss: 0.0095
# Valid - Force Loss: 19.3790, HI Loss: 0.0233
# Valid Total Loss: 19.3790, Best: 19.3554
# 早停计数器: 3/500 (监控总验证损失)
#
# Epoch 31/1000, LR: 0.001000
# Train - Force Loss: 2.8331, HI Loss: 0.0049
# Valid - Force Loss: 4.4363, HI Loss: 0.0054
# Valid Total Loss: 4.4363, Best: 4.2125
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 41/1000, LR: 0.001000
# Train - Force Loss: 2.3899, HI Loss: 0.0038
# Valid - Force Loss: 4.0568, HI Loss: 0.0034
# Valid Total Loss: 4.0568, Best: 3.9226
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 51/1000, LR: 0.001000
# Train - Force Loss: 3.0208, HI Loss: 0.0046
# Valid - Force Loss: 7.6240, HI Loss: 0.0107
# Valid Total Loss: 7.6240, Best: 2.4637
# 早停计数器: 5/500 (监控总验证损失)
# Epoch 61: 验证总损失改善 (1.3926 -> 1.3926)，保存最佳模型
#
# Epoch 61/1000, LR: 0.001000
# Train - Force Loss: 1.8545, HI Loss: 0.0023
# Valid - Force Loss: 1.3926, HI Loss: 0.0020
# Valid Total Loss: 1.3926, Best: 1.3926
# 早停计数器: 0/500 (监控总验证损失)
#
# Epoch 71/1000, LR: 0.001000
# Train - Force Loss: 2.2585, HI Loss: 0.0026
# Valid - Force Loss: 19.5727, HI Loss: 0.0171
# Valid Total Loss: 19.5727, Best: 1.3926
# 早停计数器: 10/500 (监控总验证损失)
#
# Epoch 81/1000, LR: 0.001000
# Train - Force Loss: 2.1672, HI Loss: 0.0029
# Valid - Force Loss: 9.0166, HI Loss: 0.0071
# Valid Total Loss: 9.0166, Best: 1.3926
# 早停计数器: 20/500 (监控总验证损失)
#
# Epoch 91/1000, LR: 0.001000
# Train - Force Loss: 2.0089, HI Loss: 0.0030
# Valid - Force Loss: 6.6855, HI Loss: 0.0066
# Valid Total Loss: 6.6855, Best: 1.3926
# 早停计数器: 30/500 (监控总验证损失)
#
# Epoch 101/1000, LR: 0.000800
# Train - Force Loss: 2.1578, HI Loss: 0.0026
# Valid - Force Loss: 2.0627, HI Loss: 0.0022
# Valid Total Loss: 2.0627, Best: 1.3926
# 早停计数器: 40/500 (监控总验证损失)
#
# Epoch 111/1000, LR: 0.000800
# Train - Force Loss: 1.8699, HI Loss: 0.0027
# Valid - Force Loss: 2.1608, HI Loss: 0.0018
# Valid Total Loss: 2.1608, Best: 1.1865
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 121/1000, LR: 0.000800
# Train - Force Loss: 2.1100, HI Loss: 0.0025
# Valid - Force Loss: 1.8391, HI Loss: 0.0017
# Valid Total Loss: 1.8391, Best: 1.1865
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 131/1000, LR: 0.000800
# Train - Force Loss: 1.8826, HI Loss: 0.0021
# Valid - Force Loss: 5.7822, HI Loss: 0.0061
# Valid Total Loss: 5.7822, Best: 1.1865
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 141/1000, LR: 0.000800
# Train - Force Loss: 1.7150, HI Loss: 0.0020
# Valid - Force Loss: 4.5180, HI Loss: 0.0038
# Valid Total Loss: 4.5180, Best: 1.1865
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 151/1000, LR: 0.000800
# Train - Force Loss: 1.9039, HI Loss: 0.0022
# Valid - Force Loss: 2.4964, HI Loss: 0.0042
# Valid Total Loss: 2.4964, Best: 1.1865
# 早停计数器: 46/500 (监控总验证损失)
#
# Epoch 161/1000, LR: 0.000800
# Train - Force Loss: 2.8574, HI Loss: 0.0037
# Valid - Force Loss: 3.7699, HI Loss: 0.0034
# Valid Total Loss: 3.7699, Best: 1.1865
# 早停计数器: 56/500 (监控总验证损失)
#
# Epoch 171/1000, LR: 0.000800
# Train - Force Loss: 2.5733, HI Loss: 0.0033
# Valid - Force Loss: 2.9524, HI Loss: 0.0056
# Valid Total Loss: 2.9524, Best: 1.1865
# 早停计数器: 66/500 (监控总验证损失)
#
# Epoch 181/1000, LR: 0.000800
# Train - Force Loss: 2.9961, HI Loss: 0.0043
# Valid - Force Loss: 1.7767, HI Loss: 0.0044
# Valid Total Loss: 1.7767, Best: 1.1865
# 早停计数器: 76/500 (监控总验证损失)
#
# Epoch 191/1000, LR: 0.000800
# Train - Force Loss: 2.3717, HI Loss: 0.0031
# Valid - Force Loss: 3.5305, HI Loss: 0.0023
# Valid Total Loss: 3.5305, Best: 1.1865
# 早停计数器: 86/500 (监控总验证损失)
#
# Epoch 201/1000, LR: 0.000640
# Train - Force Loss: 2.2361, HI Loss: 0.0026
# Valid - Force Loss: 3.2147, HI Loss: 0.0057
# Valid Total Loss: 3.2147, Best: 1.1865
# 早停计数器: 96/500 (监控总验证损失)
#
# Epoch 211/1000, LR: 0.000640
# Train - Force Loss: 2.1587, HI Loss: 0.0023
# Valid - Force Loss: 1.6620, HI Loss: 0.0023
# Valid Total Loss: 1.6620, Best: 1.1865
# 早停计数器: 106/500 (监控总验证损失)
#
# Epoch 221/1000, LR: 0.000640
# Train - Force Loss: 2.0432, HI Loss: 0.0026
# Valid - Force Loss: 1.4533, HI Loss: 0.0015
# Valid Total Loss: 1.4533, Best: 1.1865
# 早停计数器: 116/500 (监控总验证损失)
#
# Epoch 231/1000, LR: 0.000640
# Train - Force Loss: 2.0593, HI Loss: 0.0024
# Valid - Force Loss: 1.2981, HI Loss: 0.0014
# Valid Total Loss: 1.2981, Best: 1.1381
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 241/1000, LR: 0.000640
# Train - Force Loss: 2.0670, HI Loss: 0.0024
# Valid - Force Loss: 1.8791, HI Loss: 0.0014
# Valid Total Loss: 1.8791, Best: 1.1381
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 251/1000, LR: 0.000640
# Train - Force Loss: 2.5880, HI Loss: 0.0039
# Valid - Force Loss: 1.7605, HI Loss: 0.0025
# Valid Total Loss: 1.7605, Best: 1.1381
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 261/1000, LR: 0.000640
# Train - Force Loss: 1.7395, HI Loss: 0.0020
# Valid - Force Loss: 1.9541, HI Loss: 0.0031
# Valid Total Loss: 1.9541, Best: 1.1381
# 早停计数器: 31/500 (监控总验证损失)
#
# Epoch 271/1000, LR: 0.000640
# Train - Force Loss: 1.7816, HI Loss: 0.0020
# Valid - Force Loss: 1.1942, HI Loss: 0.0014
# Valid Total Loss: 1.1942, Best: 1.1381
# 早停计数器: 41/500 (监控总验证损失)
#
# Epoch 281/1000, LR: 0.000640
# Train - Force Loss: 2.2748, HI Loss: 0.0024
# Valid - Force Loss: 2.2408, HI Loss: 0.0020
# Valid Total Loss: 2.2408, Best: 1.1381
# 早停计数器: 51/500 (监控总验证损失)
#
# Epoch 291/1000, LR: 0.000640
# Train - Force Loss: 1.7390, HI Loss: 0.0020
# Valid - Force Loss: 1.6897, HI Loss: 0.0019
# Valid Total Loss: 1.6897, Best: 1.1381
# 早停计数器: 61/500 (监控总验证损失)
#
# Epoch 301/1000, LR: 0.000512
# Train - Force Loss: 1.9135, HI Loss: 0.0023
# Valid - Force Loss: 1.2691, HI Loss: 0.0016
# Valid Total Loss: 1.2691, Best: 1.1381
# 早停计数器: 71/500 (监控总验证损失)
#
# Epoch 311/1000, LR: 0.000512
# Train - Force Loss: 2.0759, HI Loss: 0.0022
# Valid - Force Loss: 1.6530, HI Loss: 0.0034
# Valid Total Loss: 1.6530, Best: 1.1381
# 早停计数器: 81/500 (监控总验证损失)
#
# Epoch 321/1000, LR: 0.000512
# Train - Force Loss: 2.0026, HI Loss: 0.0024
# Valid - Force Loss: 1.2174, HI Loss: 0.0016
# Valid Total Loss: 1.2174, Best: 1.1381
# 早停计数器: 91/500 (监控总验证损失)
#
# Epoch 331/1000, LR: 0.000512
# Train - Force Loss: 1.9557, HI Loss: 0.0025
# Valid - Force Loss: 2.3436, HI Loss: 0.0015
# Valid Total Loss: 2.3436, Best: 1.1381
# 早停计数器: 101/500 (监控总验证损失)
#
# Epoch 341/1000, LR: 0.000512
# Train - Force Loss: 2.2738, HI Loss: 0.0038
# Valid - Force Loss: 1.5241, HI Loss: 0.0040
# Valid Total Loss: 1.5241, Best: 1.1381
# 早停计数器: 111/500 (监控总验证损失)
#
# Epoch 351/1000, LR: 0.000512
# Train - Force Loss: 1.7059, HI Loss: 0.0019
# Valid - Force Loss: 1.2538, HI Loss: 0.0020
# Valid Total Loss: 1.2538, Best: 1.1381
# 早停计数器: 121/500 (监控总验证损失)
#
# Epoch 361/1000, LR: 0.000512
# Train - Force Loss: 2.2197, HI Loss: 0.0025
# Valid - Force Loss: 1.5866, HI Loss: 0.0016
# Valid Total Loss: 1.5866, Best: 1.0946
# 早停计数器: 6/500 (监控总验证损失)
#
# Epoch 371/1000, LR: 0.000512
# Train - Force Loss: 1.6655, HI Loss: 0.0018
# Valid - Force Loss: 1.4024, HI Loss: 0.0019
# Valid Total Loss: 1.4024, Best: 1.0946
# 早停计数器: 16/500 (监控总验证损失)
#
# Epoch 381/1000, LR: 0.000512
# Train - Force Loss: 1.8602, HI Loss: 0.0020
# Valid - Force Loss: 1.2822, HI Loss: 0.0018
# Valid Total Loss: 1.2822, Best: 1.0946
# 早停计数器: 26/500 (监控总验证损失)
#
# Epoch 391/1000, LR: 0.000512
# Train - Force Loss: 1.6710, HI Loss: 0.0021
# Valid - Force Loss: 1.3076, HI Loss: 0.0018
# Valid Total Loss: 1.3076, Best: 1.0946
# 早停计数器: 36/500 (监控总验证损失)
#
# Epoch 401/1000, LR: 0.000410
# Train - Force Loss: 1.7554, HI Loss: 0.0019
# Valid - Force Loss: 2.3689, HI Loss: 0.0027
# Valid Total Loss: 2.3689, Best: 1.0946
# 早停计数器: 46/500 (监控总验证损失)
#
# Epoch 411/1000, LR: 0.000410
# Train - Force Loss: 1.8859, HI Loss: 0.0020
# Valid - Force Loss: 1.4819, HI Loss: 0.0023
# Valid Total Loss: 1.4819, Best: 1.0946
# 早停计数器: 56/500 (监控总验证损失)
#
# Epoch 421/1000, LR: 0.000410
# Train - Force Loss: 1.8515, HI Loss: 0.0024
# Valid - Force Loss: 1.4994, HI Loss: 0.0021
# Valid Total Loss: 1.4994, Best: 1.0946
# 早停计数器: 66/500 (监控总验证损失)
#
# Epoch 431/1000, LR: 0.000410
# Train - Force Loss: 1.9004, HI Loss: 0.0021
# Valid - Force Loss: 2.4749, HI Loss: 0.0033
# Valid Total Loss: 2.4749, Best: 1.0946
# 早停计数器: 76/500 (监控总验证损失)
#
# Epoch 441/1000, LR: 0.000410
# Train - Force Loss: 1.9909, HI Loss: 0.0023
# Valid - Force Loss: 1.8564, HI Loss: 0.0023
# Valid Total Loss: 1.8564, Best: 1.0946
# 早停计数器: 86/500 (监控总验证损失)
#
# Epoch 451/1000, LR: 0.000410
# Train - Force Loss: 1.8739, HI Loss: 0.0021
# Valid - Force Loss: 1.1908, HI Loss: 0.0013
# Valid Total Loss: 1.1908, Best: 1.0946
# 早停计数器: 96/500 (监控总验证损失)
#
# Epoch 461/1000, LR: 0.000410
# Train - Force Loss: 1.7549, HI Loss: 0.0021
# Valid - Force Loss: 3.9218, HI Loss: 0.0018
# Valid Total Loss: 3.9218, Best: 1.0946
# 早停计数器: 106/500 (监控总验证损失)
#
# Epoch 471/1000, LR: 0.000410
# Train - Force Loss: 2.0888, HI Loss: 0.0029
# Valid - Force Loss: 1.3040, HI Loss: 0.0017
# Valid Total Loss: 1.3040, Best: 1.0946
# 早停计数器: 116/500 (监控总验证损失)
#
# Epoch 481/1000, LR: 0.000410
# Train - Force Loss: 2.1537, HI Loss: 0.0026
# Valid - Force Loss: 1.7169, HI Loss: 0.0013
# Valid Total Loss: 1.7169, Best: 1.0714
# 早停计数器: 1/500 (监控总验证损失)
#
# Epoch 491/1000, LR: 0.000410
# Train - Force Loss: 1.6796, HI Loss: 0.0018
# Valid - Force Loss: 1.8587, HI Loss: 0.0016
# Valid Total Loss: 1.8587, Best: 1.0714
# 早停计数器: 11/500 (监控总验证损失)
#
# Epoch 501/1000, LR: 0.000328
# Train - Force Loss: 1.6433, HI Loss: 0.0020
# Valid - Force Loss: 1.2941, HI Loss: 0.0014
# Valid Total Loss: 1.2941, Best: 1.0714
# 早停计数器: 21/500 (监控总验证损失)
#
# Epoch 511/1000, LR: 0.000328
# Train - Force Loss: 1.8601, HI Loss: 0.0022
# Valid - Force Loss: 1.3296, HI Loss: 0.0012
# Valid Total Loss: 1.3296, Best: 1.0714
# 早停计数器: 31/500 (监控总验证损失)
#
# Epoch 521/1000, LR: 0.000328
# Train - Force Loss: 2.2198, HI Loss: 0.0023
# Valid - Force Loss: 1.2018, HI Loss: 0.0020
# Valid Total Loss: 1.2018, Best: 1.0714
# 早停计数器: 41/500 (监控总验证损失)
#
# Epoch 531/1000, LR: 0.000328
# Train - Force Loss: 1.5755, HI Loss: 0.0017
# Valid - Force Loss: 2.0374, HI Loss: 0.0016
# Valid Total Loss: 2.0374, Best: 1.0714
# 早停计数器: 51/500 (监控总验证损失)
#
# Epoch 541/1000, LR: 0.000328
# Train - Force Loss: 2.0562, HI Loss: 0.0023
# Valid - Force Loss: 1.4003, HI Loss: 0.0031
# Valid Total Loss: 1.4003, Best: 1.0714
# 早停计数器: 61/500 (监控总验证损失)
#
# Epoch 551/1000, LR: 0.000328
# Train - Force Loss: 1.7414, HI Loss: 0.0019
# Valid - Force Loss: 2.2269, HI Loss: 0.0022
# Valid Total Loss: 2.2269, Best: 1.0714
# 早停计数器: 71/500 (监控总验证损失)
#
# Epoch 561/1000, LR: 0.000328
# Train - Force Loss: 1.8639, HI Loss: 0.0020
# Valid - Force Loss: 1.3205, HI Loss: 0.0013
# Valid Total Loss: 1.3205, Best: 1.0714
# 早停计数器: 81/500 (监控总验证损失)
#
# Epoch 571/1000, LR: 0.000328
# Train - Force Loss: 1.5882, HI Loss: 0.0019
# Valid - Force Loss: 1.3475, HI Loss: 0.0014
# Valid Total Loss: 1.3475, Best: 1.0714
# 早停计数器: 91/500 (监控总验证损失)
#
# Epoch 581/1000, LR: 0.000328
# Train - Force Loss: 1.9317, HI Loss: 0.0025
# Valid - Force Loss: 1.5081, HI Loss: 0.0016
# Valid Total Loss: 1.5081, Best: 1.0714
# 早停计数器: 101/500 (监控总验证损失)
#
# Epoch 591/1000, LR: 0.000328
# Train - Force Loss: 1.9037, HI Loss: 0.0020
# Valid - Force Loss: 2.3128, HI Loss: 0.0016
# Valid Total Loss: 2.3128, Best: 1.0714
# 早停计数器: 111/500 (监控总验证损失)
#
# Epoch 601/1000, LR: 0.000262
# Train - Force Loss: 2.0002, HI Loss: 0.0022
# Valid - Force Loss: 1.3238, HI Loss: 0.0014
# Valid Total Loss: 1.3238, Best: 1.0714
# 早停计数器: 121/500 (监控总验证损失)
#
# Epoch 611/1000, LR: 0.000262
# Train - Force Loss: 1.8519, HI Loss: 0.0020
# Valid - Force Loss: 1.5127, HI Loss: 0.0014
# Valid Total Loss: 1.5127, Best: 1.0714
# 早停计数器: 131/500 (监控总验证损失)
#
# Epoch 621/1000, LR: 0.000262
# Train - Force Loss: 1.8059, HI Loss: 0.0020
# Valid - Force Loss: 1.2079, HI Loss: 0.0017
# Valid Total Loss: 1.2079, Best: 1.0714
# 早停计数器: 141/500 (监控总验证损失)
#
# Epoch 631/1000, LR: 0.000262
# Train - Force Loss: 1.7781, HI Loss: 0.0019
# Valid - Force Loss: 1.3970, HI Loss: 0.0014
# Valid Total Loss: 1.3970, Best: 1.0714
# 早停计数器: 151/500 (监控总验证损失)
#
# Epoch 641/1000, LR: 0.000262
# Train - Force Loss: 1.9170, HI Loss: 0.0019
# Valid - Force Loss: 1.3088, HI Loss: 0.0019
# Valid Total Loss: 1.3088, Best: 1.0714
# 早停计数器: 161/500 (监控总验证损失)
#
# Epoch 651/1000, LR: 0.000262
# Train - Force Loss: 1.7624, HI Loss: 0.0020
# Valid - Force Loss: 1.3460, HI Loss: 0.0022
# Valid Total Loss: 1.3460, Best: 1.0714
# 早停计数器: 171/500 (监控总验证损失)
#
# Epoch 661/1000, LR: 0.000262
# Train - Force Loss: 1.8601, HI Loss: 0.0023
# Valid - Force Loss: 1.4266, HI Loss: 0.0013
# Valid Total Loss: 1.4266, Best: 1.0714
# 早停计数器: 181/500 (监控总验证损失)
#
# Epoch 671/1000, LR: 0.000262
# Train - Force Loss: 1.5421, HI Loss: 0.0016
# Valid - Force Loss: 1.3836, HI Loss: 0.0015
# Valid Total Loss: 1.3836, Best: 1.0714
# 早停计数器: 191/500 (监控总验证损失)
#
# Epoch 681/1000, LR: 0.000262
# Train - Force Loss: 1.8591, HI Loss: 0.0022
# Valid - Force Loss: 1.2557, HI Loss: 0.0013
# Valid Total Loss: 1.2557, Best: 1.0714
# 早停计数器: 201/500 (监控总验证损失)
#
# Epoch 691/1000, LR: 0.000262
# Train - Force Loss: 2.1692, HI Loss: 0.0023
# Valid - Force Loss: 1.2298, HI Loss: 0.0019
# Valid Total Loss: 1.2298, Best: 1.0714
# 早停计数器: 211/500 (监控总验证损失)
#
# Epoch 701/1000, LR: 0.000210
# Train - Force Loss: 1.6677, HI Loss: 0.0018
# Valid - Force Loss: 1.2807, HI Loss: 0.0015
# Valid Total Loss: 1.2807, Best: 1.0714
# 早停计数器: 221/500 (监控总验证损失)
#
# Epoch 711/1000, LR: 0.000210
# Train - Force Loss: 1.7908, HI Loss: 0.0020
# Valid - Force Loss: 1.1604, HI Loss: 0.0017
# Valid Total Loss: 1.1604, Best: 1.0714
# 早停计数器: 231/500 (监控总验证损失)
#
# Epoch 721/1000, LR: 0.000210
# Train - Force Loss: 1.7475, HI Loss: 0.0021
# Valid - Force Loss: 1.3990, HI Loss: 0.0014
# Valid Total Loss: 1.3990, Best: 1.0714
# 早停计数器: 241/500 (监控总验证损失)
#
# Epoch 731/1000, LR: 0.000210
# Train - Force Loss: 1.8754, HI Loss: 0.0021
# Valid - Force Loss: 2.3357, HI Loss: 0.0017
# Valid Total Loss: 2.3357, Best: 1.0714
# 早停计数器: 251/500 (监控总验证损失)
#
# Epoch 741/1000, LR: 0.000210
# Train - Force Loss: 1.6611, HI Loss: 0.0019
# Valid - Force Loss: 1.5909, HI Loss: 0.0031
# Valid Total Loss: 1.5909, Best: 1.0714
# 早停计数器: 261/500 (监控总验证损失)
#
# Epoch 751/1000, LR: 0.000210
# Train - Force Loss: 1.8337, HI Loss: 0.0019
# Valid - Force Loss: 1.2641, HI Loss: 0.0014
# Valid Total Loss: 1.2641, Best: 1.0714
# 早停计数器: 271/500 (监控总验证损失)
#
# Epoch 761/1000, LR: 0.000210
# Train - Force Loss: 1.6488, HI Loss: 0.0018
# Valid - Force Loss: 1.3133, HI Loss: 0.0018
# Valid Total Loss: 1.3133, Best: 1.0714
# 早停计数器: 281/500 (监控总验证损失)
#
# Epoch 771/1000, LR: 0.000210
# Train - Force Loss: 1.9109, HI Loss: 0.0022
# Valid - Force Loss: 1.5102, HI Loss: 0.0020
# Valid Total Loss: 1.5102, Best: 1.0714
# 早停计数器: 291/500 (监控总验证损失)
#
# Epoch 781/1000, LR: 0.000210
# Train - Force Loss: 1.9005, HI Loss: 0.0021
# Valid - Force Loss: 1.2979, HI Loss: 0.0017
# Valid Total Loss: 1.2979, Best: 1.0714
# 早停计数器: 301/500 (监控总验证损失)
#
# Epoch 791/1000, LR: 0.000210
# Train - Force Loss: 1.9986, HI Loss: 0.0021
# Valid - Force Loss: 1.3840, HI Loss: 0.0014
# Valid Total Loss: 1.3840, Best: 1.0714
# 早停计数器: 311/500 (监控总验证损失)
#
# Epoch 801/1000, LR: 0.000168
# Train - Force Loss: 1.5604, HI Loss: 0.0016
# Valid - Force Loss: 1.3877, HI Loss: 0.0015
# Valid Total Loss: 1.3877, Best: 1.0714
# 早停计数器: 321/500 (监控总验证损失)
#
# Epoch 811/1000, LR: 0.000168
# Train - Force Loss: 1.8733, HI Loss: 0.0019
# Valid - Force Loss: 1.1753, HI Loss: 0.0012
# Valid Total Loss: 1.1753, Best: 1.0714
# 早停计数器: 331/500 (监控总验证损失)
#
# Epoch 821/1000, LR: 0.000168
# Train - Force Loss: 2.0250, HI Loss: 0.0021
# Valid - Force Loss: 1.3953, HI Loss: 0.0014
# Valid Total Loss: 1.3953, Best: 1.0714
# 早停计数器: 341/500 (监控总验证损失)
#
# Epoch 831/1000, LR: 0.000168
# Train - Force Loss: 1.8269, HI Loss: 0.0022
# Valid - Force Loss: 1.4558, HI Loss: 0.0019
# Valid Total Loss: 1.4558, Best: 1.0714
# 早停计数器: 351/500 (监控总验证损失)
#
# Epoch 841/1000, LR: 0.000168
# Train - Force Loss: 1.6180, HI Loss: 0.0018
# Valid - Force Loss: 1.3302, HI Loss: 0.0014
# Valid Total Loss: 1.3302, Best: 1.0714
# 早停计数器: 361/500 (监控总验证损失)
#
# Epoch 851/1000, LR: 0.000168
# Train - Force Loss: 1.5283, HI Loss: 0.0018
# Valid - Force Loss: 1.4067, HI Loss: 0.0014
# Valid Total Loss: 1.4067, Best: 1.0714
# 早停计数器: 371/500 (监控总验证损失)
#
# Epoch 861/1000, LR: 0.000168
# Train - Force Loss: 1.7820, HI Loss: 0.0019
# Valid - Force Loss: 1.1445, HI Loss: 0.0013
# Valid Total Loss: 1.1445, Best: 1.0714
# 早停计数器: 381/500 (监控总验证损失)
#
# Epoch 871/1000, LR: 0.000168
# Train - Force Loss: 2.0285, HI Loss: 0.0022
# Valid - Force Loss: 1.7434, HI Loss: 0.0017
# Valid Total Loss: 1.7434, Best: 1.0714
# 早停计数器: 391/500 (监控总验证损失)
#
# Epoch 881/1000, LR: 0.000168
# Train - Force Loss: 1.4524, HI Loss: 0.0017
# Valid - Force Loss: 1.5675, HI Loss: 0.0014
# Valid Total Loss: 1.5675, Best: 1.0714
# 早停计数器: 401/500 (监控总验证损失)
#
# Epoch 891/1000, LR: 0.000168
# Train - Force Loss: 1.6448, HI Loss: 0.0017
# Valid - Force Loss: 1.3213, HI Loss: 0.0014
# Valid Total Loss: 1.3213, Best: 1.0714
# 早停计数器: 411/500 (监控总验证损失)
#
# Epoch 901/1000, LR: 0.000134
# Train - Force Loss: 2.1741, HI Loss: 0.0024
# Valid - Force Loss: 1.3467, HI Loss: 0.0014
# Valid Total Loss: 1.3467, Best: 1.0714
# 早停计数器: 421/500 (监控总验证损失)
#
# Epoch 911/1000, LR: 0.000134
# Train - Force Loss: 1.7705, HI Loss: 0.0018
# Valid - Force Loss: 1.3851, HI Loss: 0.0015
# Valid Total Loss: 1.3851, Best: 1.0714
# 早停计数器: 431/500 (监控总验证损失)
#
# Epoch 921/1000, LR: 0.000134
# Train - Force Loss: 1.9333, HI Loss: 0.0023
# Valid - Force Loss: 1.4356, HI Loss: 0.0015
# Valid Total Loss: 1.4356, Best: 1.0714
# 早停计数器: 441/500 (监控总验证损失)
#
# Epoch 931/1000, LR: 0.000134
# Train - Force Loss: 1.6934, HI Loss: 0.0018
# Valid - Force Loss: 1.3780, HI Loss: 0.0017
# Valid Total Loss: 1.3780, Best: 1.0714
# 早停计数器: 451/500 (监控总验证损失)
#
# Epoch 941/1000, LR: 0.000134
# Train - Force Loss: 2.0474, HI Loss: 0.0022
# Valid - Force Loss: 1.2463, HI Loss: 0.0014
# Valid Total Loss: 1.2463, Best: 1.0714
# 早停计数器: 461/500 (监控总验证损失)
#
# Epoch 951/1000, LR: 0.000134
# Train - Force Loss: 2.0381, HI Loss: 0.0022
# Valid - Force Loss: 1.5840, HI Loss: 0.0017
# Valid Total Loss: 1.5840, Best: 1.0714
# 早停计数器: 471/500 (监控总验证损失)
#
# Epoch 961/1000, LR: 0.000134
# Train - Force Loss: 1.8079, HI Loss: 0.0021
# Valid - Force Loss: 1.2293, HI Loss: 0.0015
# Valid Total Loss: 1.2293, Best: 1.0714
# 早停计数器: 481/500 (监控总验证损失)
#
# Epoch 971/1000, LR: 0.000134
# Train - Force Loss: 1.9374, HI Loss: 0.0020
# Valid - Force Loss: 1.4476, HI Loss: 0.0014
# Valid Total Loss: 1.4476, Best: 1.0714
# 早停计数器: 491/500 (监控总验证损失)
#
# 早停触发！连续 500 个epoch验证总损失未改善
# 最佳验证总损失: 1.0714 (epoch 480)
#
# 训练完成，加载最佳模型（验证总损失: 1.0714)

# %%
torch.save(model, f'{Save_path}Inverse_Model_4.pth') 
print("模型已保存")
# Out:
# 模型已保存

# %%
plt.style.use('default')
plt.figure(figsize=(12, 8)) # 创建Figure对象，并指定尺寸
plt.rcParams['font.family'] = ['Times New Roman']

# 设置x轴刻度
epoch = np.arange(0, len(train_loss_force), len(train_loss_force) // 10)
plt.xticks(epoch)

# 创建第一个y轴
ax1 = plt.gca()
ax1.plot(train_loss_force, 'r-', linewidth=2.5)
ax1.plot(train_loss_force, marker='o', markersize=5, color='red', linestyle='None', label='Training loss for PF')
ax1.plot(validation_loss_force, 'r-', linewidth=2.5)
ax1.plot(validation_loss_force, marker='*', markersize=5, color='red', linestyle='None', label='Validation loss for PF')

ax1.set_xlabel('Epoch', fontdict={'weight': 'normal', 'size': 20})
ax1.set_ylabel('Loss for PF', fontdict={'weight': 'normal', 'size': 20}, color='red')

ax1.tick_params(axis='y', labelcolor='red')
ax1.tick_params(axis='both', which='major',labelcolor='black', labelsize=15)

# 添加图例
ax1.legend(loc='upper left', fontsize=20)


max_val = max(
    max(train_loss_force),
    max(validation_loss_force)
)

ax1.set_ylim(0, max_val)

# 创建第二个y轴
ax2 = ax1.twinx()
ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None', label='Training loss for HI')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None', label='Validation loss for HI')

ax2.set_ylabel('Loss for HI', fontdict={'weight': 'normal', 'size': 20}, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major',labelcolor='blue', labelsize=15)

max_val = max(
    max(train_loss_HI),
    max(validation_loss_HI)
)

ax2.set_ylim(0, max_val)
ax2.legend(loc='upper right', fontsize=20)

# 创建放大图的子图（inset）
x1 = int(len(train_loss_force)*0.7)
x2 = int(len(train_loss_force))

ax_inset = plt.axes([0.45, 0.25, 0.4, 0.4])  # [left, bottom, width, height]
ax_inset.plot(train_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(train_loss_force, marker='o', markersize=8, color='red', linestyle='None')
ax_inset.plot(validation_loss_force, 'r-', linewidth=2.5)
ax_inset.plot(validation_loss_force, marker='*', markersize=8, color='red', linestyle='None')

max_val = max(
    max(train_loss_force[x1:x2]),
    max(validation_loss_force[x1:x2])
)

ax_inset.set_xlim(x1, x2)
ax_inset.set_ylim(0, max_val)
ax_inset.tick_params(axis='both', which='major',  labelcolor='red',labelsize=15)

ax2 = ax_inset.twinx()

ax2.plot(train_loss_HI, 'b-', linewidth=2.5)
ax2.plot(train_loss_HI, marker='o', markersize=5, color='blue', linestyle='None')
ax2.plot(validation_loss_HI, 'b-', linewidth=2.5)
ax2.plot(validation_loss_HI, marker='*', markersize=5, color='blue', linestyle='None')

max_val = max(
    max(train_loss_HI[x1:x2]),
    max(validation_loss_HI[x1:x2])
)

ax2.set_ylim(0, max_val)

ax2.tick_params(axis='y', labelcolor='blue')
ax2.tick_params(axis='both', which='major', labelsize=15)

# 保存图像
plt.savefig(f'{Save_path}Inverse_problem_Loss.jpg', dpi=600, bbox_inches='tight')
plt.show()
